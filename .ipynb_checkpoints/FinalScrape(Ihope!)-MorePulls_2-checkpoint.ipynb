# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup 
import re
import pandas as pd 
import os 
import time
import datetime
import csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Introducing Selenium

# %%
#The 7th: http://www.santaanita.com/live-racing/4718/
#The 6th: http://www.santaanita.com/live-racing/4618/

# %% [markdown]
# ## Horses of Interest

# %%
mainpage = "https://www.equibase.com/static/chart/summary/SA040718USA-EQB.html"
horselink = BeautifulSoup(requests.get(mainpage).text, "lxml")

# %%
###New list of horses!! Race 7 and 10.
horsenames = ['Accountability','Avalanche','Fortune of War', 'Mesut','Elwood J','Tartini','Dreams of Valor','Cascade Rock', 'Malibu Music',
              'Beau Recall','Thundering Sky','Madame Stripes','Enola Grey','Sassy Little Lila','Sophie P','Instant Reflex','Midnight Crossing',
              'Mongolian Shopper']

# %%
horselinkdic = {}

for horse in horsenames:
    for a in horselink.find_all("a", text=re.compile(horse)):
        for i in a:
            a = a['href']
            horselinkdic[horse]=a

# %%
print((horselinkdic))
# Out:
# {'Accountability': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9700631&registry=T&rbt=TB', 'Avalanche': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9694429&registry=T&rbt=TB', 'Fortune of War': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9732830&registry=T&rbt=TB', 'Mesut': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9708093&registry=T&rbt=TB', 'Elwood J': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9691578&registry=T&rbt=TB', 'Tartini': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9694778&registry=T&rbt=TB', 'Dreams of Valor': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9649893&registry=T&rbt=TB', 'Cascade Rock': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9789258&registry=T&rbt=TB', 'Malibu Music': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9762146&registry=T&rbt=TB', 'Beau Recall': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9796425&registry=T&rbt=TB', 'Thundering Sky': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9498006&registry=T&rbt=TB', 'Madame Stripes': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9482394&registry=T&rbt=TB', 'Sassy Little Lila': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9473178&registry=T&rbt=TB', 'Sophie P': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9553400&registry=T&rbt=TB', 'Instant Reflex': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9692614&registry=T&rbt=TB', 'Midnight Crossing': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9566712&registry=T&rbt=TB', 'Mongolian Shopper': 'http://www.equibase.com/profiles/Results.cfm?type=Horse&refno=9550853&registry=T&rbt=TB'}

# %% [markdown]
# ## Scraping horsey stats

# %% [markdown]
# ##### Scraping the stats table

# %%
#launch url
chromedriver = "/Users/vicky/Downloads/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
horseywinnings=[]
horseyworkouts=[]

for key, value in horselinkdic.items():   
    
    print(key)
    jesustakethewheel = webdriver.Chrome(chromedriver)
    jesustakethewheel.get(value)
    
    soupresults=BeautifulSoup(requests.get(value).text, "lxml")
    resultstable=soupresults.find_all(class_='table-hover')[1]

    rows=[row for row in resultstable.find_all('tr')]
    rows=rows[1:5]


    horseywins={}
    for row in rows:
        items=row.find_all('td')
        for entries in items:
            splitsies = entries.text.split(':')
            horseywins[splitsies[0]] = (splitsies[1])
            horseywins['Horse Name'] = (key)    
    
    
    horseywinnings.append(horseywins)
    
    time.sleep(1)
    
    python_button_Workouts = jesustakethewheel.find_element_by_id('Hworkouts') 
    python_button_Workouts.click() 
    time.sleep(.5)
    
    python_button_seemore = jesustakethewheel.find_element_by_link_text('SEE MORE WORKOUTS')
    python_button_seemore.click()
    time.sleep(.5)
    
    soupworkout=BeautifulSoup(jesustakethewheel.page_source, "lxml")
    
    workouttable=soupworkout.find(class_='resultTable') 

    #horseyworkouts=[]
    for row in workouttable.find_all('tr')[1:]:
        items=row.find_all('td')
        Track = items[0].text
        Date = items[1].text
        Course = items[2].text
        Distance = items[3].text
        if len(items[4].text) <6:
            tp = datetime.datetime.strptime(items[4].text,'%S.%f')
        else:
            tp = datetime.datetime.strptime(items[4].text,'%M:%S.%f')
        Time = tp.second*10+tp.minute*600+tp.microsecond//100000
        Note = items[5].text
        Rank = items[6].text
        rowdict= {'Horse Name': key,'Course' :Course,'Track' :Track,'Date':Date ,'Course' :Course ,'Distance' :Distance,'Time_tenths_second':Time,'Note':Note,'Rank':Rank}
        horseyworkouts.append(rowdict)
            
    time.sleep(1)
# Out:
# Accountability
# Avalanche
# Fortune of War
# Mesut
# Elwood J
# Tartini
# Dreams of Valor
# Cascade Rock
# Malibu Music
# Beau Recall
# Thundering Sky
# Madame Stripes
# Sassy Little Lila
# Sophie P
# Instant Reflex
# Midnight Crossing
# Mongolian Shopper

# %%
print(horseyworkouts)
# Out:
# [{'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '03/31/2018', 'Distance': '5F', 'Time_tenths_second': 610, 'Note': 'Handily', 'Rank': '\n                                18/70 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '03/25/2018', 'Distance': '5F', 'Time_tenths_second': 620, 'Note': 'Handily', 'Rank': '\n                                62/110 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '03/20/2018', 'Distance': '3F', 'Time_tenths_second': 378, 'Note': 'Handily', 'Rank': '\n                                22/40 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '03/05/2018', 'Distance': '5F', 'Time_tenths_second': 624, 'Note': 'Handily', 'Rank': '\n                                97/114 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '02/25/2018', 'Distance': '6F', 'Time_tenths_second': 766, 'Note': 'Handily', 'Rank': '\n                                8/10 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '02/18/2018', 'Distance': '5F', 'Time_tenths_second': 628, 'Note': 'Handily', 'Rank': '\n                                50/73 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '02/10/2018', 'Distance': '4F', 'Time_tenths_second': 488, 'Note': 'Handily', 'Rank': '\n                                22/67 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '01/21/2018', 'Distance': '5F', 'Time_tenths_second': 622, 'Note': 'Handily', 'Rank': '\n                                72/110 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '01/14/2018', 'Distance': '6F', 'Time_tenths_second': 752, 'Note': 'Handily', 'Rank': '\n                                14/26 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '01/07/2018', 'Distance': '4F', 'Time_tenths_second': 480, 'Note': 'Handily', 'Rank': '\n                                12/73 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '12/21/2017', 'Distance': '4F', 'Time_tenths_second': 508, 'Note': 'Handily', 'Rank': '\n                                39/41 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '12/15/2017', 'Distance': '6F', 'Time_tenths_second': 754, 'Note': 'Handily', 'Rank': '\n                                12/14 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '12/09/2017', 'Distance': '7F', 'Time_tenths_second': 874, 'Note': 'Handily', 'Rank': '\n                                1/2 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '12/03/2017', 'Distance': '6F', 'Time_tenths_second': 752, 'Note': 'Handily', 'Rank': '\n                                6/6 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '11/19/2017', 'Distance': '5F', 'Time_tenths_second': 612, 'Note': 'Handily', 'Rank': '\n                                11/48 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date': '11/12/2017', 'Distance': '4F', 'Time_tenths_second': 498, 'Note': 'Handily', 'Rank': '\n                                26/48 \n                            '}, {'Horse Name': 'Accountability', 'Course': 'Dirt', 'Track': ' Santa Anita', 'Date ...

# %%
df_stats2 = pd.DataFrame(horseywinnings)
dfworkouts2 = pd.DataFrame(horseyworkouts)

# %%
df_stats2.to_csv('stats_csv_2')
dfworkouts2.to_csv('workouts_csv_2')

# %% [markdown]
# ## Cleaning up dfworkouts

# %%
dfworkouts['Course'].unique()

# %%
dfworkouts_clean = dfworkouts.drop('Note', axis=1 ).drop('Rank',axis=1).drop('Track',axis=1)
#new_df = df[df.C != 'XYZ']
#dfworkouts_clean = dfworkouts_clean.drop(dfworkouts_clean.loc[dfworkouts_clean['Course'] == 'Turf'])

# %%
dfworkouts_clean.head(2)

# %% [markdown]
# ### GROUP BY TO AVERAGE

# %%
dfworkouts_clean.groupby

# %% [markdown]
# ## Cleaning up df_stats

# %%
df_stats

# %% [markdown]
# ## Race times

# %%
resultsofinterest = ['{Horse Name:  , Final_Time}',
                    'http://tnetwork.trakus.com/tnet/t_SantaAnita.aspx?EventID=133974&Date=4/14/2018&Type=TBRED&Venue=4&DisplayType=1',
                    'http://tnetwork.trakus.com/tnet/t_SantaAnita.aspx?EventID=133976&Date=4/14/2018&Type=TBRED&Venue=4&DisplayType=1']

# %%
timesdic = [{'Horse Name' : 'Accountability', 'Final_Time':'1:34.39'},
           {'Horse Name' :'Avalanche','Final_Time': '1:34.47'},
           {'Horse Name' :'Fortune of War','Final_Time': '1:34.54'},
           {'Horse Name' :'Mesut','Final_Time': '1:34.77'},
           {'Horse Name' :'Elwood J','Final_Time':'1:34.91'},
           {'Horse Name' :'Tartini','Final_Time': '1:35.06'},
           {'Horse Name' :'Dreams of Valor','Final_Time': '1:35.16'},
           {'Horse Name' :'Cascade Rock','Final_Time': '1:35.45'},
           {'Horse Name' :'Malibu Music','Final_Time': '1:36.85'},
           {'Horse Name' :'Beau Recall','Final_Time': '1:34.52'},
           {'Horse Name' :'Thundering Sky','Final_Time':'1:34.64'},
           {'Horse Name' :'Madame Stripes','Final_Time': '1:34.68'},
           {'Horse Name' :'Enola Gray','Final_Time': '1:34.86'},
           {'Horse Name' :'Sassy Little Lila','Final_Time':'1:34.99'},
           {'Horse Name' :'Sophie P','Final_Time': '1:35.03'},
           {'Horse Name' :'Instant Reflex','Final_Time':'1:35.16'},
           {'Horse Name' :'Midnight Crossing','Final_Time': '1:35.17'},
           {'Horse Name' :'Mongolian Shopper','Final_Time': '1:36.33'}]

# %%
for row in timesdic:
    for k,v in row.items():
        if k == 'Final_Time':
            timing = datetime.datetime.strptime(v,'%M:%S.%f')
            value = timing.second*100+timing.minute*6000+timing.microsecond//10000
        
    
    row['Final_Time_Hund'] = value 

print(timesdic)
# Out:
# [{'Horse Name': 'Accountability', 'Final_Time': '1:34.39', 'Final_Time_Hund': 9439}, {'Horse Name': 'Avalanche', 'Final_Time': '1:34.47', 'Final_Time_Hund': 9447}, {'Horse Name': 'Fortune of War', 'Final_Time': '1:34.54', 'Final_Time_Hund': 9454}, {'Horse Name': 'Mesut', 'Final_Time': '1:34.77', 'Final_Time_Hund': 9477}, {'Horse Name': 'Elwood J', 'Final_Time': '1:34.91', 'Final_Time_Hund': 9491}, {'Horse Name': 'Tartini', 'Final_Time': '1:35.06', 'Final_Time_Hund': 9506}, {'Horse Name': 'Dreams of Valor', 'Final_Time': '1:35.16', 'Final_Time_Hund': 9516}, {'Horse Name': 'Cascade Rock', 'Final_Time': '1:35.45', 'Final_Time_Hund': 9545}, {'Horse Name': 'Malibu Music', 'Final_Time': '1:36.85', 'Final_Time_Hund': 9685}, {'Horse Name': 'Beau Recall', 'Final_Time': '1:34.52', 'Final_Time_Hund': 9452}, {'Horse Name': 'Thundering Sky', 'Final_Time': '1:34.64', 'Final_Time_Hund': 9464}, {'Horse Name': 'Madame Stripes', 'Final_Time': '1:34.68', 'Final_Time_Hund': 9468}, {'Horse Name': 'Enola Gray', 'Final_Time': '1:34.86', 'Final_Time_Hund': 9486}, {'Horse Name': 'Sassy Little Lila', 'Final_Time': '1:34.99', 'Final_Time_Hund': 9499}, {'Horse Name': 'Sophie P', 'Final_Time': '1:35.03', 'Final_Time_Hund': 9503}, {'Horse Name': 'Instant Reflex', 'Final_Time': '1:35.16', 'Final_Time_Hund': 9516}, {'Horse Name': 'Midnight Crossing', 'Final_Time': '1:35.17', 'Final_Time_Hund': 9517}, {'Horse Name': 'Mongolian Shopper', 'Final_Time': '1:36.33', 'Final_Time_Hund': 9633}]

# %%
dffinaltime2 = pd.DataFrame.from_dict(timesdic)

#dfpract = dfpract.transpose()
dffinaltime2
# Out:
#    Final_Time  Final_Time_Hund         Horse Name
# 0     1:34.39             9439     Accountability
# 1     1:34.47             9447          Avalanche
# 2     1:34.54             9454     Fortune of War
# 3     1:34.77             9477              Mesut
# 4     1:34.91             9491           Elwood J
# 5     1:35.06             9506            Tartini
# 6     1:35.16             9516    Dreams of Valor
# 7     1:35.45             9545       Cascade Rock
# 8     1:36.85             9685       Malibu Music
# 9     1:34.52             9452        Beau Recall
# 10    1:34.64             9464     Thundering Sky
# 11    1:34.68             9468     Madame Stripes
# 12    1:34.86             9486         Enola Gray
# 13    1:34.99             9499  Sassy Little Lila
# 14    1:35.03             9503           Sophie P
# 15    1:35.16             9516     Instant Reflex
# 16    1:35.17             9517  Midnight Crossing
# 17    1:36.33             9633  Mongolian Shopper

# %%
finalmerged2 = pd.merge(dffinaltime2,df_stats2,on='Horse Name', how = 'left')

# %%
finalmerged2
# Out:
#    Final_Time  Final_Time_Hund         Horse Name Firsts Seconds Starts Thirds
# 0     1:34.39             9439     Accountability      3       0     14      3
# 1     1:34.47             9447          Avalanche      1       2      8      1
# 2     1:34.54             9454     Fortune of War      1       3     16      4
# 3     1:34.77             9477              Mesut      1       3      7      0
# 4     1:34.91             9491           Elwood J      2       1     16      5
# 5     1:35.06             9506            Tartini      1       1      9      1
# 6     1:35.16             9516    Dreams of Valor      1       0     10      0
# 7     1:35.45             9545       Cascade Rock      1       3     10      1
# 8     1:36.85             9685       Malibu Music      1       2     13      1
# 9     1:34.52             9452        Beau Recall      3       4     12      0
# 10    1:34.64             9464     Thundering Sky      3       6     20      4
# 11    1:34.68             9468     Madame Stripes      4       7     19      3
# 12    1:34.86             9486         Enola Gray    NaN     NaN    NaN    NaN
# 13    1:34.99             9499  Sassy Little Lila      3       5     14      1
# 14    1:35.03             9503           Sophie P      4       5     20      1
# 15    1:35.16             9516     Instant Reflex      2       0      8      1
# 16    1:35.17             9517  Midnight Crossing      3       3     21      1
# 17    1:36.33             9633  Mongolian Shopper      7       3     26      1

# %%
finalmerged2.to_csv('final_merged2')
