# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Directory_Of_Homeless_Population_By_Year.csv')

# %%
grp = df.groupby(['Year']).agg("sum")

# %%
grp.head(10)
# Out:
#       Homeless Estimates
# Year
# 2009                6016
# 2010                8256
# 2011                6669
# 2012                8152

# %%
NYCHA = pd.read_csv('NYCHA_Resident_Data_Book_Summary.csv')

# %%
NYCHA.head(10)
# Out:
#                          PROGRAM          STATECITY_SECTION8_FLAG  \
# 0                        FEDERAL                 TOTAL HOUSEHOLDS
# 1          FORMER NEW YORK STATE                 TOTAL HOUSEHOLDS
# 2          FORMER NEW YORK STATE        PUBLIC HOUSING HOUSEHOLDS
# 3          FORMER NEW YORK STATE  SECTION 8 TRANSITION HOUSEHOLDS
# 4           FORMER NEW YORK CITY                 TOTAL HOUSEHOLDS
# 5           FORMER NEW YORK CITY        PUBLIC HOUSING HOUSEHOLDS
# 6           FORMER NEW YORK CITY  SECTION 8 TRANSITION HOUSEHOLDS
# 7  MIXED FINANCE (LLC1 AND LLC2)                 TOTAL HOUSEHOLDS
# 8  MIXED FINANCE (LLC1 AND LLC2)        PUBLIC HOUSING HOUSEHOLDS
# 9  MIXED FINANCE (LLC1 AND LLC2)  SECTION 8 TRANSITION HOUSEHOLDS
#
#    White Families  Black Families  Hispanic Families  Asian Families  \
# 0            7149           69577              69711            7291
# 1             933            5054               5251             795
# ...

# %%
NYCHAT = NYCHA.transpose()

# %%
NYCHAG = NYCHA.groupby(['STATECITY_SECTION8_FLAG']).agg('sum')

# %%
NYCHAG.head(10)
# Out:
#                                  White Families  Black Families  \
# STATECITY_SECTION8_FLAG
# PUBLIC HOUSING HOUSEHOLDS                 18409          169148
# SECTION 8 HOUSEHOLDS                        206            4544
# SECTION 8 TRANSITION HOUSEHOLDS             309            6816
# TOTAL HOUSEHOLDS                          35963          349974
#
#                                  Hispanic Families  Asian Families  \
# STATECITY_SECTION8_FLAG
# PUBLIC HOUSING HOUSEHOLDS                   167536           17486
# SECTION 8 HOUSEHOLDS                          2234              60
# SECTION 8 TRANSITION HOUSEHOLDS               3351              90
# TOTAL HOUSEHOLDS                            337132           34505
#
#                                  Other Races Families  Total Families  \
# STATECITY_SECTION8_FLAG
# PUBLIC HOUSING HOUSEHOLDS                        1890          374469
# SECTION 8 HOUSEHOLDS                               44            7088
# ...

# %%
NYCHAGG = NYCHA.groupby(['PROGRAM']).agg('sum')

# %%
NYCHAGG.head(10)
# Out:
#                                White Families  Black Families  \
# PROGRAM
# ALL PROGRAMS                            16644          159312
# ALL PROGRAMS + KRAUS                     8343           80078
# BRONX                                    1448           32892
# BROOKLYN                                 7040           66328
# FEDERAL                                  7149           69577
# FORMER NEW YORK CITY                      480           10050
# FORMER NEW YORK STATE                    1866           10108
# MANHATTAN                                3930           37980
# MIXED FINANCE (LLC1 AND LLC2)            2346           20158
# MIXED FINANCE/LLC1                       1100           13656
#
#                                Hispanic Families  Asian Families  \
# PROGRAM
# ALL PROGRAMS                              155110           16230
# ALL PROGRAMS + KRAUS                       78272            8153
# BRONX                                      51564             248
# ...

# %%
dr = pd.read_csv('New_York_City_Leading_Causes_of_Death.csv')

# %%
dr.head(10)
# Out:
#    Year                                      Leading Cause Sex  \
# 0  2010                 Assault (Homicide: Y87.1, X85-Y09)   M
# 1  2011  Mental and Behavioral Disorders due to Acciden...   M
# 2  2011     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 3  2008  Certain Conditions originating in the Perinata...   F
# 4  2014  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 5  2007    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 6  2012  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 7  2009                                   All Other Causes   M
# 8  2013     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 9  2014  Accidents Except Drug Posioning (V01-X39, X43,...   M
#
#                Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 0          Black Non-Hispanic    299       35.1                    35.5
# 1          Not Stated/Unknown      5          .                       .
# ...

# %%
sorted_dr_year_gender_deathcause = dr.sort_values(by=['Year','Leading Cause','Sex'])

# %%
sorted_dr_year_gender_deathcause
# Out:
#       Year                                      Leading Cause Sex  \
# 198   2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 466   2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 480   2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 582   2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 709   2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 990   2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 59    2007  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 418   2007  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 502   2007  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 654   2007  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 1038  2007  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 1053  2007  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 28    2007                                   All Other Causes   F
# ...
