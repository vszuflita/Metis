# %%
import pandas as pd
import csv
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error as MSE
import matplotlib.pyplot as plt
# %matplotlib inline
# from paramsearch import paramsearch
from itertools import product,chain

# %% [markdown]
# ### Data Aggregation

# %% [markdown]
# #### Prepping Files

# %% [markdown]
# Reading the CSV files

# %%
hm2016 = pd.read_csv('federalelections2016 (2).csv')
hm2014 = pd.read_csv('federalelections2014.csv')
hm2012 = pd.read_csv('Senate_Primary_2012.csv')
hm2010 = pd.read_csv('Primary2010.csv')
hm2008 = pd.read_csv('Primary2008.csv')
hm2006 = pd.read_csv('Primary2006.csv')
hm2004 = pd.read_csv('FederalElection2004.csv')


### Add back incumbent column!!

# %% [markdown]
# **Adding the year to each CSV for easier analysis**

# %%
hm2016['YEAR'] = '2016'
hm2014['YEAR'] = '2014'
hm2012['YEAR'] = '2012'
hm2010['YEAR'] = '2010'
hm2008['YEAR'] = '2008'
hm2006['YEAR'] = '2006'
hm2004['YEAR'] = '2004'

# %% [markdown]
# **Creating IDs I will later merge on**

# %%
hm2016["ID"] = hm2016["STATE"].map(str) + hm2016["YEAR"] +hm2016["PARTY"]
hm2016["ID2"] = hm2016["STATE"].map(str) + hm2016["YEAR"]

hm2014["ID"] = hm2014["STATE"].map(str) + hm2014["YEAR"] +hm2014["PARTY"]
hm2014["ID2"] = hm2014["STATE"].map(str) + hm2014["YEAR"]

hm2012["ID"] = hm2012["STATE"].map(str) + hm2012["YEAR"] +hm2012["PARTY"]
hm2012["ID2"] = hm2012["STATE"].map(str) + hm2012["YEAR"]

hm2010["ID"] = hm2010["STATE"].map(str) + hm2010["YEAR"] +hm2010["PARTY"]
hm2010["ID2"] = hm2010["STATE"].map(str) + hm2010["YEAR"]

hm2008["ID"] = hm2008["STATE"].map(str) + hm2008["YEAR"] +hm2008["PARTY"]
hm2008["ID2"] = hm2008["STATE"].map(str) + hm2008["YEAR"]

hm2006["ID"] = hm2006["STATE"].map(str) + hm2006["YEAR"] +hm2006["PARTY"]
hm2006["ID2"] = hm2006["STATE"].map(str) + hm2006["YEAR"]

hm2004["ID"] = hm2004["STATE"].map(str) + hm2004["YEAR"] +hm2004["PARTY"]
hm2004["ID2"] = hm2004["STATE"].map(str) + hm2004["YEAR"]

# %% [markdown]
# **Dropping weird columns & fixing weird merging errors**

# %%
hm2014 = hm2014.drop('Unnamed: 8', axis=1).drop('Unnamed: 9',axis=1)

# %%
# hm2012 = hm2012.drop('Unnamed: 9', axis=1)

# %%
# hm2010.columns = [col.strip() for col in hm2010.columns]

# %%
hm2012.columns = [col.strip() for col in hm2012.columns]

# %%
hm2014.columns = [col.strip() for col in hm2014.columns]

# %%
hm2016.columns = [col.strip() for col in hm2016.columns]

# %% [markdown]
# **Append files together**

# %%
hm = hm2016.append(hm2012).append(hm2004).append(hm2006).append(hm2008).append(hm2010).append(hm2014)

# %%
# ## Want to make "Incument" versus not a binary count.  
# hm = hm.replace(to_replace = 'FULL TERM',value='(I)').replace(to_replace = 'UNEXPIRED TERM ',value='(I)').replace(to_replace=' (I)',value='(I)').replace(to_replace='UNEXPIRED TERM',value='(I)')

# %% [markdown]
# #### Party data

# %% [markdown]
# **Removing all third party candidates**

# %%
hm = hm.replace(to_replace = 'R*',value='R').replace(to_replace = 'R ',value='R').replace(to_replace = 'D*',value='D').replace(to_replace = 'D* ',value='D').replace(to_replace = 'D ',value='D')

# %%
hm_party = hm[hm['PARTY'].isin(['R','D'])]

# %% [markdown]
# **Throwing out rows that are interupting analysis**

# %%
hm_party2 = hm_party[~hm_party['PRIMARY VOTES'].isin(['Unopposed','*','#','14*','20*','1,040*','1,616**','Loser','Winner','Withdrew','Unoppsed'])]

# %%
hm_party2 = hm_party2[~hm_party2['TOTAL VOTES'].isin(['Party Votes:','Total State Votes:'])]

# %%
hm_party2 = hm_party2[~hm_party2['ID'].isin(['South Carolina2014R','Wyoming2008R'])]

# %% [markdown]
# **Find total votes for each party, each state **

# %%
#Didn't work :( It's missing a few states.
# hm_partytotal = hm_party[hm_party['TOTAL VOTES'].isin(['Party Votes:'])]
# hm_partytotal = hm_partytotal[['ID','PRIMARY VOTES']]

# %%
hm_partytotal = hm_party2[['ID','PRIMARY VOTES']]

# %%
hm_partytotal = hm_partytotal.dropna()

# %%
hm_partytotal["PRIMARY VOTES"]=hm_partytotal["PRIMARY VOTES"].astype(float)

# %%
hm_partytotal = hm_partytotal.groupby(['ID']).sum().reset_index()

# %%
hm_partytotal = hm_partytotal.rename(columns = {'PRIMARY VOTES':'Total Party Votes'})

# %% [markdown]
# **Finding How many people ran in the primary**

# %%
NumRunning = hm_party2.groupby(['ID']).count().reset_index()

# %%
NumRunning = NumRunning[['ID','PRIMARY VOTES','(I)']]

# %%
NumRunning['(I)'].value_counts()
# Out:
# 0    259
# 1    145
# Name: (I), dtype: int64

# %%
NumRunning = NumRunning.rename(columns = {'PRIMARY VOTES':'Candidate Count'})

# %% [markdown]
# **Finding max vote for each party, each state**

# %%
PartyWin = hm_party2[['ID','PRIMARY VOTES','STATE','YEAR','PARTY']]

# %%
PartyWin = PartyWin.dropna()

# %%
PartyWin["PRIMARY VOTES"]= PartyWin["PRIMARY VOTES"].astype(float)

# %%
PartyWin = PartyWin.groupby(['ID']).max().reset_index()

# %%
PartyWin = PartyWin.rename(columns = {'PRIMARY VOTES':'Primary Winner'})

# %% [markdown]
# -Group by state and party
# -Tuple of the candidates aggregated
# -Winner, candidates, number of columns

# %% [markdown]
# **Merging Columns Back Together**

# %%
votes_merged = hm_partytotal.merge(NumRunning, left_on='ID', right_on='ID', how='left')

# %%
votes_merged = votes_merged.merge(PartyWin, left_on='ID', right_on='ID', how = 'left')

# %% [markdown]
# **Calcuating the total number of votes by losers**

# %%
votes_merged['Primary Loser Vote'] = votes_merged['Total Party Votes'] - votes_merged['Primary Winner']

# %% [markdown]
# #### Final Results Data

# %% [markdown]
# Creating column with final election results numbers

# %%
hm_finals = hm[hm['PARTY'].isin(['R','D'])]

# %%
hm_finals = hm_finals[['GENERAL VOTES','ID','ID2']]

# %%
hm_finals = hm_finals.dropna()

# %% [markdown]
# #### 3rd Party Data #Not Including this anymore

# %% [markdown]
# Creating column with how many people showed up to vote for the third party candidate in the primaries.

# %%
hm_third = hm[~hm['PARTY'].isin(['R','D'])]

# %%
hm_third = hm_third[hm_third['TOTAL VOTES'].isin(['Party Votes:'])]

# %%
hm_third = hm_third[['PRIMARY VOTES','ID2']]

# %%
hm_third = hm_third.groupby(['ID2'])
hm_third = hm_third['PRIMARY VOTES'].agg([np.sum]).reset_index()

# %%
hm_third = hm_third.rename(columns = {'sum':'Third Party Votes'})

# %% [markdown]
# #### Merging

# %% [markdown]
# Merging the final results data and the third party data to the original dataframe.

# %%
hm_merged = hm_finals.merge(votes_merged, left_on='ID', right_on='ID', how='left')

# %%
# hm_merged = hm_merged.merge(hm_third, left_on='ID2', right_on='ID2', how='left')

# %%
# hm_merged['Third Party Votes'] = hm_merged['Third Party Votes'].fillna(value=0)

# %% [markdown]
# ** Throwing out NaNs for races that didn't have primary data**

# %%
hm_merged = hm_merged.dropna()

# %% [markdown]
# **Making a loop for whether or not a candidate's party is in the oval office.**

# %%
Republican = ['2008','2006','2004','2002','1992','1990']

OfficeParty = []


for year in hm_merged['YEAR']:
    if year in Republican:
        OfficeParty.append('R')
        
    else:
        OfficeParty.append('D')
    
hm_merged['OFFICE PARTY'] = OfficeParty

# %% [markdown]
# ** Create Column for whether or not the party is in office**

# %%
hm_merged['Party In House'] = np.where(hm_merged['PARTY']== hm_merged['OFFICE PARTY'], 1,0)

# %%
hm_model_ready = hm_merged.drop('ID',axis=1).drop('ID2',axis=1).drop('OFFICE PARTY',axis=1)

# %%
# hm_model_ready = hm_merged.drop('ID',axis=1).drop('ID2',axis=1).drop('Total Party Votes',axis=1).drop('YEAR',axis=1).drop('OFFICE PARTY',axis=1)

# %%
hm_model_ready = hm_model_ready[~hm_model_ready['GENERAL VOTES'].isin(['#'])]

# %%
hm_model_ready
# Out:
#     GENERAL VOTES  Total Party Votes  Candidate Count  (I)  Primary Winner  \
# 0      1.3351e+06           778851.0              5.0  1.0        505586.0
# 1          748709           274423.0              2.0  0.0        153897.0
# 2          138149            55293.0              4.0  1.0         39545.0
# 3           36200            25318.0              2.0  0.0         15228.0
# 4     1.35927e+06           591155.0              4.0  1.0        302532.0
# 5     1.03124e+06           333586.0              1.0  0.0        333586.0
# 6          661984           389834.0              2.0  1.0        298039.0
# 8     7.54276e+06          4811300.0              7.0  0.0       3000689.0
# 9     4.70142e+06          4811300.0              7.0  0.0       3000689.0
# 10    1.37071e+06           262344.0              1.0  1.0        262344.0
# 11    1.21532e+06           347471.0              5.0  0.0        131125.0
# 14    4.83519e+06          1430492.0              4.0  1.0       1029830.0
# 15    4.12209e+06          1129781.0              5.0  0.0        665985.0
# 16    2.13581e+06           577660.0              3.0  1.0        447661.0
# 17    1.59973e+06           310053.0              3.0  0.0        166627.0
# 18         306604           189059.0              5.0  1.0        162905.0
# 19          92653            35865.0              4.0  0.0         26749.0
# 20         449017           119633.0              1.0  1.0        119633.0
# 22         Illinois  2016     D            675015.0               1
# 23         Illinois  2016     R            388571.0               0
# 24          Indiana  2016     R            324429.0               0
# 25          Indiana  2016     D                 0.0               1
# 26             Iowa  2016     R                 0.0               0
# 27             Iowa  2016     D             50799.0               1
# 28         Kentucky  2016     R             30339.0               0
# 29         Kentucky  2016     D            169045.0               1
# 46         Maryland  2016     D            414024.0               1
# 47         Maryland  2016     R            244494.0               0
# 48         Missouri  2016     R            182142.0               0
# ..              ...   ...   ...                 ...             ...
# 380         Montana  2014     R             22060.0               0
# 381         Montana  2014     D             27326.0               1
# 382        Nebraska  2014     R            110436.0               0
# 383        Nebraska  2014     D             21483.0               1
# 384   New Hampshire  2014     D                 0.0               1
# 385   New Hampshire  2014     R             59087.0               0
# 386      New Jersey  2014     D                 0.0               1
# 387      New Jersey  2014     R            102579.0               0
# 388      New Mexico  2014     D                 0.0               1
# 389      New Mexico  2014     R             24413.0               0
# 390  North Carolina  2014     R            265381.0               0
# 391  North Carolina  2014     D            110160.0               1
# 392        Oklahoma  2014     R            299342.0               0
# 393        Oklahoma  2014     D             91541.0               1
# 394        Oklahoma  2014     R            299342.0               0
# 395        Oklahoma  2014     D             91541.0               1
# 396          Oregon  2014     R            133789.0               0
# 397    Rhode Island  2014     D                 0.0               1
# 398    Rhode Island  2014     R                 0.0               0
# 400  South Carolina  2014     D            138115.0               1
# 402  South Carolina  2014     D            138115.0               1
# 403    South Dakota  2014     R             33121.0               0
# 405       Tennessee  2014     R            332968.0               0
# 406       Tennessee  2014     D            153120.0               1
# 407           Texas  2014     R            533297.0               0
# 408           Texas  2014     D            270095.0               1
# 411   West Virginia  2014     R             10667.0               0
# 412   West Virginia  2014     D             29590.0               1
# 413         Wyoming  2014     R             16977.0               0
# 414         Wyoming  2014     D              7670.0               1
#
# [337 rows x 10 columns]

# %%
hm_model_ready["GENERAL VOTES"]= hm_model_ready["GENERAL VOTES"].astype(float)
# hm_model_ready["Third Party Votes"]= hm_model_ready["Third Party Votes"].astype(float)
hm_model_ready["Party In House"]= hm_model_ready["Party In House"].astype(float)

# %% [markdown]
# ### Modeling (All 50 States)

# %% [markdown]
# #### EDA & Futhur Cleaning

# %%
hm_model_ready.describe()
# Out:
#        GENERAL VOTES  Total Party Votes  Candidate Count         (I)  \
# count   3.370000e+02       3.370000e+02       337.000000  337.000000
# mean    1.121743e+06       4.248368e+05         3.424332    0.370920
# std     1.195753e+06       5.607719e+05         2.572936    0.483769
# min     2.937700e+04       6.934000e+03         1.000000    0.000000
# 25%     2.864090e+05       1.017280e+05         2.000000    0.000000
# 50%     8.067870e+05       2.479020e+05         3.000000    0.000000
# 75%     1.479471e+06       5.619520e+05         5.000000    1.000000
# max     7.864624e+06       4.811300e+06        18.000000    1.000000
#
#        Primary Winner  Primary Loser Vote  Party In House
# count    3.370000e+02        3.370000e+02      337.000000
# mean     2.959091e+05        1.289277e+05        0.492582
# std      3.958044e+05        2.233261e+05        0.500688
# min      6.110000e+03        0.000000e+00        0.000000
# 25%      7.042400e+04        3.773000e+03        0.000000
# 9      California  2016     D           1810611.0             1.0
# 82     California  2012     R           1293553.0             0.0
# 14        Florida  2016     R            400662.0             0.0
# 214    California  2006     D            326481.0             0.0
# 282    California  2010     D            462015.0             1.0
# 208    Washington  2004     D             60017.0             0.0
# 150    California  2004     D                 0.0             0.0
# 8      California  2016     D           1810611.0             1.0
# 81     California  2012     D            350114.0             1.0
#
# [337 rows x 10 columns]

# %%
#Looks like there are some rogue additional states...
len(hm_model_ready['STATE'].value_counts())
# Out:
# 51

# %%
hm_model_ready['STATE'].unique()

##Virgin Islands not in state list
##Missouri counted twice due to space error
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois',
#        'Indiana', 'Iowa', 'Kentucky', 'Maryland', 'Missouri', 'Nevada',
#        'New Hampshire', 'North Carolina', 'North Dakota', 'Ohio',
#        'Oregon', 'Pennsylvania', 'Utah', 'Vermont', 'Washington',
#        'Wisconsin', 'Connecticut', 'Delaware', 'Maine', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri ', 'Montana',
#        'Nebraska', 'New Jersey', 'New Mexico', 'New York', 'Rhode Island',
#        'Tennessee', 'Texas', 'Virginia', 'West Virginia', 'Wyoming',
#        'Kansas', 'Oklahoma', 'South Carolina', 'Louisiana',
#        'South Dakota'], dtype=object)

# %%
#Dropping VI
hm_model_ready2 = hm_model_ready[~hm_model_ready['STATE'].isin(['Virgin Islands'])]

# %%
#Removing spaces

hm_model_ready2 = hm_model_ready2.replace(to_replace = 'Missouri ',value='Missouri')

# %%
len(hm_model_ready2['STATE'].unique())
# Out:
# 50

# %%
hm_model_ready2['(I)'].value_counts()
# Out:
# 0.0    212
# 1.0    125
# Name: (I), dtype: int64

# %%
hm_model_ready2.groupby(['STATE']).sum().sort_values(['GENERAL VOTES'])
# Out:
#                 GENERAL VOTES  Total Party Votes  Candidate Count  (I)  \
# STATE
# South Dakota         140741.0            74498.0              5.0  0.0
# Delaware             557025.0           143109.0              8.0  1.0
# Wyoming              582045.0           311266.0             17.0  3.0
# North Dakota         771729.0           350801.0              6.0  1.0
# Alaska               880306.0           460223.0             23.0  3.0
# Vermont              970052.0           278217.0             14.0  3.0
# Kansas              1091200.0           438904.0              4.0  1.0
# Rhode Island        1118726.0           339786.0              9.0  3.0
# Louisiana           1191987.0           207481.0              6.0  1.0
# Montana             1212195.0           641718.0             18.0  3.0
# Utah                1349647.0           482393.0              6.0  2.0
# Maine               1426620.0           327124.0             15.0  2.0
# New Mexico          1820674.0           585058.0             11.0  2.0
# Nebraska            1898651.0           913258.0             22.0  1.0
# Idaho               2006242.0           622873.0             11.0  4.0
# West Virginia       2043555.0           928403.0             30.0  2.0
# Mississippi         2044013.0           882052.0             17.0  2.0
# Hawaii              2268968.0          1509002.0             46.0  5.0
# New Hampshire       2291971.0           639043.0             29.0  3.0
# Connecticut         2346737.0           445795.0              6.0  0.0
# Arkansas            2440767.0          1193537.0             18.0  3.0
# Minnesota           2553854.0           467713.0             11.0  0.0
# Virginia            2961148.0           412264.0              6.0  0.0
# Nevada              3450892.0          1068742.0             58.0  3.0
# Missouri             3548442.0           1188045.0             5.0
# Georgia              2506786.0           1501782.0             4.0
# Wisconsin            2602450.0            807985.0             5.0
# Texas                2666615.0           2190033.0             3.0
# Washington           6285504.0            964435.0             5.0
# Illinois             5439749.0           4157823.0             5.0
# Ohio                 6698730.0           2196959.0             5.0
# Pennsylvania         6435961.0           2767160.0             5.0
# Florida              6312910.0           3711936.0             5.0
# California          19600567.0           8323223.0             6.0

# %% [markdown]
# **Seeing if we throw out the rest of the unopposed if our score gets better...**
# It doesn't!

# %%
# moreopp = hm_model_ready2[hm_model_ready2['Primary Loser Vote'] == 0]

# %%
# #Dropping Unnopposed to see if it makes it better...
# hm_model_ready2 = hm_model_ready2[~hm_model_ready['Primary Loser Vote'].isin([0])]

# %% [markdown]
# #### Catboost (With All Inputs Included) ***THIS ONE PREVAILS!! :)

# %% [markdown]
# ** Splitting x&y **

# %%
hm_model_ready2
# Out:
#      GENERAL VOTES  Total Party Votes  Candidate Count  (I)  Primary Winner  \
# 0        1335104.0           778851.0              5.0  1.0        505586.0
# 1         748709.0           274423.0              2.0  0.0        153897.0
# 2         138149.0            55293.0              4.0  1.0         39545.0
# 3          36200.0            25318.0              2.0  0.0         15228.0
# 4        1359267.0           591155.0              4.0  1.0        302532.0
# 5        1031245.0           333586.0              1.0  0.0        333586.0
# 6         661984.0           389834.0              2.0  1.0        298039.0
# 8        7542759.0          4811300.0              7.0  0.0       3000689.0
# 9        4701417.0          4811300.0              7.0  0.0       3000689.0
# 10       1370710.0           262344.0              1.0  1.0        262344.0
# 11       1215318.0           347471.0              5.0  0.0        131125.0
# 14       4835191.0          1430492.0              4.0  1.0       1029830.0
# 15       4122088.0          1129781.0              5.0  0.0        665985.0
# 16       2135806.0           577660.0              3.0  1.0        447661.0
# 17       1599726.0           310053.0              3.0  0.0        166627.0
# 18        306604.0           189059.0              5.0  1.0        162905.0
# 19         92653.0            35865.0              4.0  0.0         26749.0
# 20        449017.0           119633.0              1.0  1.0        119633.0
# 21        188249.0            26471.0              1.0  0.0         26471.0
# 22       3012940.0          1895143.0              3.0  0.0       1220128.0
# 23       2184692.0          1320190.0              2.0  1.0        931619.0
# 24       1423991.0           985565.0              2.0  0.0        661136.0
# 25       1158947.0           516183.0              1.0  0.0        516183.0
# 26        926007.0            90089.0              1.0  1.0         90089.0
# 27        549460.0            97121.0              4.0  0.0         46322.0
# 28       1090177.0           199519.0              3.0  1.0        169180.0
# 29        813246.0           409643.0              7.0  0.0        240598.0
# 46       1659907.0           884344.0             10.0  0.0        470320.0
# 47        972557.0           379831.0             14.0  0.0        135337.0
# 48       1378458.0           663586.0              4.0  1.0        481444.0
# ..             ...                ...              ...  ...             ...
# 380       213709.0           132625.0              3.0  0.0        110565.0
# 381       148184.0            75991.0              3.0  1.0         48665.0
# 382       347636.0           218879.0              5.0  0.0        108443.0
# 383       170127.0            65970.0              2.0  0.0         44487.0
# 384       251184.0            39282.0              1.0  1.0         39282.0
# 385       235347.0           118234.0             10.0  0.0         59147.0
# 387      New Jersey  2014     R            102579.0             0.0
# 388      New Mexico  2014     D                 0.0             1.0
# 389      New Mexico  2014     R             24413.0             0.0
# 390  North Carolina  2014     R            265381.0             0.0
# 391  North Carolina  2014     D            110160.0             1.0
# 392        Oklahoma  2014     R            299342.0             0.0
# 393        Oklahoma  2014     D             91541.0             1.0
# 394        Oklahoma  2014     R            299342.0             0.0
# 395        Oklahoma  2014     D             91541.0             1.0
# 396          Oregon  2014     R            133789.0             0.0
# 397    Rhode Island  2014     D                 0.0             1.0
# 398    Rhode Island  2014     R                 0.0             0.0
# 400  South Carolina  2014     D            138115.0             1.0
# 402  South Carolina  2014     D            138115.0             1.0
# 403    South Dakota  2014     R             33121.0             0.0
# 405       Tennessee  2014     R            332968.0             0.0
# 406       Tennessee  2014     D            153120.0             1.0
# 407           Texas  2014     R            533297.0             0.0
# 408           Texas  2014     D            270095.0             1.0
# 411   West Virginia  2014     R             10667.0             0.0
# 412   West Virginia  2014     D             29590.0             1.0
# 413         Wyoming  2014     R             16977.0             0.0
# 414         Wyoming  2014     D              7670.0             1.0
#
# [337 rows x 10 columns]

# %%
ycat = hm_model_ready2['GENERAL VOTES'] 
Xcat = hm_model_ready2.drop('GENERAL VOTES',axis = 1)

# %% [markdown]
# ** Splitting for T-T-S **

# %%
X_trainc, X_testc, y_trainc, y_testc = train_test_split(Xcat, ycat, test_size=0.3, random_state=42)

# %%
X_trainc.columns
# Out:
# Index(['Total Party Votes', 'Candidate Count', '(I)', 'Primary Winner',
#        'STATE', 'YEAR', 'PARTY', 'Primary Loser Vote', 'Party In House'],
#       dtype='object')

# %% [markdown]
# ** Running Catboost **

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_trainc.dtypes != np.float)[0]
train_pool = Pool(X_trainc, y_trainc, cat_features=categorical_features_indices)
test_pool = Pool(X_testc, y_testc, cat_features=categorical_features_indices)


Catset=CatBoostRegressor(learning_rate = 0.01, depth = 10)
Cat = Catset.fit(X_trainc, y_trainc, cat_features=categorical_features_indices, plot=True, use_best_model=True)
# Out:
# You should provide test set for use best model. use_best_model parameter swiched to false value.
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# 0:	learn: 1686834.8391308	total: 14.7ms	remaining: 14.7s
# 1:	learn: 1674869.7549455	total: 17.2ms	remaining: 8.58s
# 2:	learn: 1663986.3509863	total: 47.9ms	remaining: 15.9s
# 3:	learn: 1655140.2014902	total: 74ms	remaining: 18.4s
# 4:	learn: 1644948.2314753	total: 87.1ms	remaining: 17.3s
# 5:	learn: 1633024.0415823	total: 90.8ms	remaining: 15s
# 6:	learn: 1623073.0224543	total: 101ms	remaining: 14.4s
# 7:	learn: 1612080.8830805	total: 103ms	remaining: 12.8s
# 8:	learn: 1600380.3156420	total: 106ms	remaining: 11.7s
# 9:	learn: 1590739.2289843	total: 111ms	remaining: 11s
# 10:	learn: 1580853.7157839	total: 136ms	remaining: 12.2s
# 11:	learn: 1569956.4167775	total: 137ms	remaining: 11.3s
# 12:	learn: 1559610.2344647	total: 140ms	remaining: 10.6s
# 13:	learn: 1548889.6310343	total: 144ms	remaining: 10.1s
# 14:	learn: 1538590.7810845	total: 148ms	remaining: 9.74s
# 15:	learn: 1529946.0206747	total: 175ms	remaining: 10.8s
# 16:	learn: 1519848.4614129	total: 178ms	remaining: 10.3s
# 17:	learn: 1509501.8871486	total: 180ms	remaining: 9.81s
# 18:	learn: 1499436.4975078	total: 182ms	remaining: 9.38s
# 19:	learn: 1489644.3849022	total: 184ms	remaining: 9.04s
# 20:	learn: 1480094.0563351	total: 187ms	remaining: 8.73s
# 21:	learn: 1470197.9953560	total: 190ms	remaining: 8.45s
# 22:	learn: 1461241.2878530	total: 196ms	remaining: 8.34s
# 23:	learn: 1452747.8499342	total: 224ms	remaining: 9.09s
# 24:	learn: 1443409.2712232	total: 226ms	remaining: 8.8s
# 25:	learn: 1434597.6864251	total: 230ms	remaining: 8.63s
# 26:	learn: 1425587.0073146	total: 237ms	remaining: 8.55s
# 27:	learn: 1416039.8724687	total: 239ms	remaining: 8.31s
# 28:	learn: 1406681.7531638	total: 242ms	remaining: 8.09s
;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(data={'catboost_info': {'path': 'catboost_info', 'name': 'catboost_info', 'content': {'passed_iterations': 999, 'total_iterations': 1000, 'data': {'iterations': [{'iteration': 0, 'eval_dataset': [1479183.95]}, {'iteration': 1, 'eval_dataset': [1469548.22]}, {'iteration': 2, 'eval_dataset': [1461288.93]}, {'iteration': 3, 'eval_dataset': [1454962.055]}, {'iteration': 4, 'eval_dataset': [1447695.421]}, {'iteration': 5, 'eval_dataset': [1438172.404]}, {'iteration': 6, 'eval_dataset': [1430640.386]}, {'iteration': 7, 'eval_dataset': [1421532.867]}, {'iteration': 8, 'eval_dataset': [1411911.42]}, {'iteration': 9, 'eval_dataset': [1404422.41]}, {'iteration': 10, 'eval_dataset': [1397504.992]}, {'iteration': 11, 'eval_dataset': [1388477.609]}, {'iteration': 12, 'eval_dataset': [1380168.387]}, {'iteration': 13, 'eval_dataset': [1372068.237]}, {'iteration': 14, 'eval_dataset': [1363878.302]}, {'iteration': 15, 'eval_dataset': [1357584.603]}, {'iteration': 16, 'eval_dataset': [1349481.817]}, {'iteration': 17, 'eval_dataset': [1341806.332]}, {'iteration': 18, 'eval_dataset': [1333233.76]}, {'iteration': 19, 'eval_dataset': [1325263.554]}, {'iteration': 20, 'eval_dataset': [1317366.896]}, {'iteration': 21, 'eval_dataset': [1308935.86]}, {'iteration': 22, 'eval_dataset': [1301667.287]}, {'iteration
#   0.823641172024022,
#   0.823662048038476,
#   0.8235613237427037,
#   0.823688003881372,
#   0.8237007103389471,
#   0.823771890462305,
#   0.8237636692997051,
#   0.8237230109990947,
#   0.8238327798463492,
#   0.8239143464590974,
#   0.8240382426851655,
#   0.8240602483806393,
#   0.8240382339241135,
#   0.8239318640596932,
#   0.8239302813081627,
#   0.8239394320383183,
#   0.8239698235805801,
#   0.8239945365801733,
#   0.8240842991836967,
#   0.8242072906931711,
#   0.8243600038703907,
#   0.8243341032937263,
#   0.8242646575837959,
#   0.8243317104570653,
#   0.8244428382392375,
#   0.8246231865561022,
#   0.8247480398987149,
#   0.824867602813486,
#   0.8249435288185296,
#   0.8250148903433692,
#   0.824985865119297,
#   0.8250935023398841,
#   0.8250321191041492,
#   0.8249522206624393,
#   0.8249737387308743,
#   0.8250263126123608,
#   0.8249548931590791,
#   0.8250193848205783,
#   0.8249544023571354,
#   0.8249936528720716,
#   0.8251004464775629,
#   0.8250927383188345,
#   0.824981266350205,
#   0.824950796081681,
#   0.8249556821779236,
#   0.824961629795031,
#   0.8249658708861718,
#   0.8249474136081345,
#   0.8248222002462505,
#   0.8247008245360489,
#   0.8245899916365607,
#   0.8246410601993961,
#   0.8245956879324781,
#   0.8244473701981707,
#   0.8245273755833428,
#   0.8245084018158665,
#   0.8245553273840013,
#   0.8246216476803062,
#   0.824696238016039,
#   0.8247406505692555,
#   0.8247042550888859,
#   0.8246579029355873,
#   0.8245961017905205,
#   0.8246764985650742,
#   0.824765495455425,
#   0.8248555086471367,
#   0.8249892509484756,
#   0.8249719858640298,
#   0.8249283599721573,
#   0.8249925974304408,
#   0.8249608345649198,
#   0.8251197365585377,
#   0.825038897041309,
#   0.8251654688554457,
#   0.8251726960832271,
#   0.8251271496578414,
#   0.8251899547733006,
#   0.8252678360760624,
#   0.8252818978607186,
#   0.8251821707501965,
#   0.825277040069045,
#   0.8252302708368504,
#   0.8253932125257778,
#   0.8254642074947167,
#   0.8255538708270577,
#   0.8255662936195728]}
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(data={'catboost_info': {'path': 'catboost_info', 'name': 'catboost_info', 'content': {'passed_iterations': 999, 'total_iterations': 1000, 'data': {'iterations': [{'iteration': 0, 'eval_dataset': [0.005726788016]}, {'iteration': 1, 'eval_dataset': [0.01035305687]}, {'iteration': 2, 'eval_dataset': [0.01457113637]}, {'iteration': 3, 'eval_dataset': [0.01842184938]}, {'iteration': 4, 'eval_dataset': [0.0232808514]}, {'iteration': 5, 'eval_dataset': [0.02919458862]}, {'iteration': 6, 'eval_dataset': [0.03354869699]}, {'iteration': 7, 'eval_dataset': [0.03814562871]}, {'iteration': 8, 'eval_dataset': [0.04441323756]}, {'iteration': 9, 'eval_dataset': [0.04866133331]}, {'iteration': 10, 'eval_dataset': [0.05287361942]}, {'iteration': 11, 'eval_dataset': [0.05779438113]}, {'iteration': 12, 'eval_dataset': [0.06245828353]}, {'iteration': 13, 'eval_dataset': [0.06753598271]}, {'iteration': 14, 'eval_dataset': [0.07296208719]}, {'iteration': 15, 'eval_dataset': [0.07739445436]}, {'iteration': 16, 'eval_dataset': [0.08225500178]}, {'iteration': 17, 'eval_dataset': [0.08646426463]}, {'iteration': 18, 'eval_dataset': [0.09158135897]}, {'iteration': 19, 'eval_dataset': [0.09653973627]}, {'iteration': 20, 'eval_dataset': [0.1013535057]}, {'iteration': 21, 'eval_dataset': [0.1070543368]}, {'iteration': 22, 'eval_dataset': [0.111852327]}, {'iteration': 23, 'eval_dataset': [0.1161343786]}, {'iteration': 24, 'eval_dataset': [0.121074358]}, {'iteration': 25, 'eval_dataset': [0.1251902905]}, {'iteration': 26, 'eval_dataset': [0.1307231757]}, {'iteration': 27, 'eval_dataset': [0.1362195767]}, {'iteration': 28, 'eval_dataset': [0.1412548391]}, {'iteration': 29, 'eval_dataset': [0.1453568867]}, {'iteration': 30, 'eval_dataset': [0.1497616107]}, {'iteration': 31, 'eval_dataset': [0.1541821197]}, {'iteration': 32, 'eval_dataset': [0.1585950433]}, {'iteration': 33, 'eval_dataset': [0.1636216087]}, {'iteration': 34, 'eval_dataset': [0.1688126558]}, {'iteration': 35, 'eval_dataset': [0.1739181068]}, {'iteration': 36, 'eval_dataset': [0.1781235202]}, {'iteration': 37, 'eval_dataset': [0.183152274]}, {'iteration': 38, 'eval_dataset': [0.1891109876]}, {'iteration': 39, 'eval_dataset': [0.1940518143]}, {'iteration': 40, 'eval_dataset': [0.1997274405]}, {'iteration': 41, 'eval_dataset': [0.2048362781]}, {'iteration': 42, 'eval_dataset': [0.2086048022]}, {'iteration': 43, 'eval_dataset': [0.2143670971]}, {'iteration': 44, 'eval_dataset': [0.2187691683]}, {'iteration': 45, 'eval_dataset': [0.2226872857]}, {'iteration': 46, 'eval_dataset': [0.2266474536]}, {'iteration': 47, 'eval_dataset': [0.2314474341]}, {'iteration': 48, 'eval_dataset': [0.235512777]}, {'iteration': 49, 'eval_dataset': [0.240603095]}, {'iteration': 50, 'eval_dataset': [0.2462022475]}, {'iteration': 51, 'eval_dataset': [0.2511693125]}, {'iteration': 52, 'eval_dataset': [0.255037618]}, {'iteration': 53, 'eval_dataset': [0.2600173406]}, {'iteration': 54, 'eval_dataset': [0.2625023248]}, {'iteration': 55, 'eval_dataset': [0.2671658648]}, {'iteration': 56, 'eval_dataset': [0.2715978158]}, {'iteration': 57, 'eval_dataset': [0.2764769845]}, {'iteration': 58, 'eval_dataset': [0.2787487969]}, {'iteration': 59, 'eval_dataset': [0.2837085299]}, {'iteration': 60, 'eval_dataset': [0.2885656928]}, {'iteration': 61, 'eval_dataset': [0.2923110604]}, {'iteration': 62, 'eval_dataset': [0.2963625274]}, {'iteration': 63, 'eval_dataset': [0.3013804531]}, {'iteration': 64, 'eval_dataset': [0.3042591401]}, {'iteration': 65, 'eval_dataset': [0.3078263456]}, {'iteration': 66, 'eval_dataset': [0.3130726093]}, {'iteration': 67, 'eval_dataset': [0.317346251]}, {'iteration': 68, 'eval_dataset': [0.3225124081]}, {'iteration': 69, 'eval_dataset': [0.3278126077]}, {'iteration': 70, 'eval_dataset': [0.3314684037]}, {'iteration': 71, 'eval_dataset': [0.336181336]}, {'iteration': 72, 'eval_dataset': [0.337444743]}, {'iteration': 73, 'eval_dataset': [0.3417989716]}, {'iteration': 74, 'eval_dataset': [0.346010084 ...

# %%
Cat.score(X_testc,y_testc)
# Out:
# 483101.7167516251

# %% [markdown]
# #### Catboost (Testing changing inputs)

# %% [markdown]
# **...Don't think it makes a difference because full list just crunches down unecessary inputs.**

# %%
hm_model_ready2.columns

# %%
ycat2 = hm_model_ready2['GENERAL VOTES'] 
Xcat2 = hm_model_ready2[['Primary Winner','Primary Loser Vote','STATE','PARTY']]

# %%
X_trainc2, X_testc2, y_trainc2, y_testc2 = train_test_split(Xcat2, ycat2, test_size=0.2, random_state=42)

# %%
categorical_features_indices = np.where(X_trainc2.dtypes != np.float)[0]
train_pool = Pool(X_trainc2, y_trainc2, cat_features=categorical_features_indices)
test_pool = Pool(X_testc2, y_testc2, cat_features=categorical_features_indices)


Cat = Catset.fit(X_trainc2, y_trainc2, cat_features=categorical_features_indices);

# %%
Cat.score(X_testc2, y_testc2)

# %%
Cat.eval_metrics(data = test_pool, metrics =['R2'], plot = True)

# %% [markdown]
# #### Linear Regression

# %%
sns.pairplot(hm_model_ready, size = 1.2, aspect=1.5)

# %%
ylr = hm_model_ready['GENERAL VOTES'] 
Xlr = hm_model_ready[['Primary Winner','Primary Loser Vote','Party In House','(I)']]

# %%
Xlr

# %%
X_trainlr, X_testlr, y_trainlr, y_testlr = train_test_split(Xlr, ylr, test_size=0.3, random_state=42)

# %%
#Checking the predictability of the model with this alpha = 1
EN = ElasticNet(1, l1_ratio=.5)
LR = EN.fit(X_trainlr, y_trainlr)
rsq = LR.score(X_testlr, y_testlr)
adj_rsq = 1 - (1-rsq)*(len(ylr)-1)/(len(ylr)-Xlr.shape[1]-1)

preds = LR.predict(X_testlr)
rmse = np.sqrt(MSE(preds, y_testlr))

print(rsq)
print(adj_rsq)
print(rmse)

# %% [markdown]
# #### Linear Regression (Logged)

# %%
hm_model_log = hm_model_ready

hm_model_log['Primary Winner']=np.log(hm_model_log['Primary Winner'])
hm_model_log['Primary Loser Vote']=np.log(hm_model_log['Primary Loser Vote'])
hm_model_log['Third Party Votes']=np.log(hm_model_log['Third Party Votes'])
hm_model_log['GENERAL VOTES']=np.log(hm_model_log['GENERAL VOTES'])

# %%
ylr2 = hm_model_log['GENERAL VOTES'] 
Xlr2 = hm_model_log[['Primary Winner','Primary Loser Vote','Third Party Votes','Party In House','(I)']]

# %%
ylr2

# %%
Xlr2 = Xlr2.replace([np.inf, -np.inf], 0).fillna(0)

# %%
X_trainlr2, X_testlr2, y_trainlr2, y_testlr2 = train_test_split(Xlr2, ylr2, test_size=0.2, random_state=42)

# %%
#Checking the predictability of the model with this alpha = 1
EN = ElasticNet(1, l1_ratio=.5)
LR = EN.fit(X_trainlr2, y_trainlr2)
rsq = LR.score(X_testlr2, y_testlr2)
adj_rsq = 1 - (1-rsq)*(len(ylr2)-1)/(len(ylr2)-Xlr2.shape[1]-1)

preds = LR.predict(X_testlr2)
rmse = np.sqrt(MSE(preds, y_testlr2))

print(rsq)
print(adj_rsq)
print(rmse)

# %% [markdown]
# ### Modeling (Splitting by state-size)

# %% [markdown]
# *Didn't end up helping much. Let's just go back to the one with the full train set*
#
# **Grouped states by electoral college vote:**<br>
#
# **Smallest:** <br>
# - *3 Electoral votes:* Alaska, Delaware, Montana, North Dakota, South Dakota, Vermont, Wyoming
# - *4 Electoral votes:* Hawaii, Idaho, Maine, New Hampshire, Rhode Island
# - *5 Electoral votes:* Nebraska, New Mexico, West Virginia
#
# **Medium:** <br>
# - *6 Electoral votes:* Arkansas, Iowa ,Kansas, Mississippi, Nevada, Utah
# - *7 Electoral votes:* Connecticut, Oklahoma, Oregon
# - *8 Electoral votes:* Kentucky, Louisiana
# - *9 Electoral votes:* Alabama, Colorado, South Carolina
# - *10 Electoral votes:* Maryland, Minnesota, Missouri, Wisconsin
# - *11 Electoral votes:* Arizona, Indiana, Massachusetts, Tennessee
#
# **Medium-Large:** <br>
# - *12 Electoral votes:* Washington
# - *13 Electoral votes:* Virginia
# - *14 Electoral votes:* New Jersey
# - *15 Electoral votes:* North Carolina
# - *16 Electoral votes:* Georgia, Michigan
# - *18 Electoral votes:* Ohio
#
# **Large:** <br>
# - *20 Electoral votes:* Illinois, Pennsylvania
# - *29 Electoral votes:* Florida, New York
# - *38 Electoral votes:* Texas
# - *55 Electoral votes:* California

# %% [markdown]
# #### Small States

# %%
low_density = ['Alaska', 'Delaware', 'Montana', 'North Dakota', 'South Dakota', 'Vermont', 'Wyoming', 'Hawaii', 'Idaho', 'Maine', 'New Hampshire', 'Rhode Island', 'Nebraska', 'New Mexico', 'West Virginia']

small = hm_model_ready2[hm_model_ready2['STATE'].isin(low_density)].drop('Third Party Votes',axis = 1)

# %%
# small = small.drop(small[small['Primary Loser Vote'] < 1].index)

# %%
small.describe()

# %% [markdown]
# **Splitting X&y**

# %%
ysmall = small['GENERAL VOTES'] 
Xsmall = small.drop('GENERAL VOTES',axis = 1)

# %% [markdown]
# **Splitting for T-T-S**

# %%
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(Xsmall, ysmall, test_size=0.3)

# %% [markdown]
# **Running Catboost**

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_train_s.dtypes != np.float)[0]
train_pool = Pool(X_train_s, y_train_s, cat_features=categorical_features_indices)
test_pool = Pool(X_test_s, y_test_s, cat_features=categorical_features_indices)


Cat_s = Catset.fit(X_train_s, y_train_s, cat_features=categorical_features_indices , use_best_model=True);

# %%
#Would like to get it down to less than 20,000...
Cat_s.score(X_test_s, y_test_s)

# %%
## Checking out feature importance for this model. 

feature_importances = Cat_s.get_feature_importance(train_pool)
feature_names = X_train_s.columns
for score, name in sorted(zip(feature_importances, feature_names), reverse=True):
    print('{}: {}'.format(name, score))

# %%
Cat_s.eval_metrics(data = test_pool, metrics =['R2'], plot = True)

# %% [markdown]
# #### Medium States

# %%
med_density = ['Arkansas', 'Iowa', 'Kansas', 'Mississippi', 'Nevada', 'Utah', 'Connecticut', 'Oklahoma', 'Oregon','Kentucky', 'Louisiana','Alabama', 'Colorado', 'South Carolina', 'Maryland', 'Minnesota','Missouri', 'Wisconsin','Arizona','Indiana', 'Massachusetts', 'Tennessee']

med = hm_model_ready2[hm_model_ready2['STATE'].isin(med_density)].drop('Third Party Votes',axis = 1)

# %%
med.describe()

# %%
ymed = med['GENERAL VOTES'] 
Xmed = med.drop('GENERAL VOTES',axis = 1)

# %%
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(Xmed, ymed, test_size=0.3)

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_train_m.dtypes != np.float)[0]
train_pool = Pool(X_train_m, y_train_m, cat_features=categorical_features_indices)
test_pool = Pool(X_test_m, y_test_m, cat_features=categorical_features_indices)

Cat_m = Catset.fit(X_train_m, y_train_m, cat_features=categorical_features_indices , use_best_model=True);

# %%
#Would like to get it down to less than 20,000...
Cat_m.score(X_test_m, y_test_m)

# %% [markdown]
# #### Medium-Large State

# %%
medlar_density = ['Washington','Virginia','New Jersey','North Carolina','Georgia','Michigan','Ohio']

medlar = hm_model_ready2[hm_model_ready2['STATE'].isin(medlar_density)].drop('Third Party Votes',axis = 1)

# %%
medlar.describe()

# %%
ymedlar = medlar['GENERAL VOTES'] 
Xmedlar = medlar.drop('GENERAL VOTES',axis = 1)

# %%
X_train_ml, X_test_ml, y_train_ml, y_test_ml = train_test_split(Xmedlar, ymedlar, test_size=0.3)

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_train_m.dtypes != np.float)[0]
train_pool = Pool(X_train_ml, y_train_ml, cat_features=categorical_features_indices)
test_pool = Pool(X_test_m, y_test_m, cat_features=categorical_features_indices)

Cat_ml = Catset.fit(X_train_ml, y_train_ml, cat_features=categorical_features_indices , use_best_model=True);

# %%
Cat_ml.score(X_test_ml, y_test_ml)

# %%
Cat_ml.eval_metrics(data = test_pool, metrics =['R2'], plot = True)

# %% [markdown]
# ### Breaking down by average voter turnout of the past 10 years

# %%
voter_turnout = hm_model_ready2.groupby(['STATE']).mean().reset_index()
voter_turnout = voter_turnout.sort_values(by=['GENERAL VOTES'])

# %%
voter_turnout

# %%
plt.barh(voter_turnout['STATE'],voter_turnout['GENERAL VOTES'], color = '#1A62A5')
plt.ylabel('State', fontsize=14)
plt.xlabel('General Election Votes', fontsize=14)
plt.title('Voter Turnout Per State', fontsize=20)

# %% [markdown]
# **Grouped states by voter turnout from the past ten years:**<br>
#
# **Smallest:** <br>
# - Wyoming, Alaska, Vermont, Delaware, South Dakota, North Dakota, Hawaii, Rhode Island,
#
# **Medium:** <br>
# - *6 Electoral votes:* Arkansas, Iowa ,Kansas, Mississippi, Nevada, Utah
# - *7 Electoral votes:* Connecticut, Oklahoma, Oregon
# - *8 Electoral votes:* Kentucky, Louisiana
# - *9 Electoral votes:* Alabama, Colorado, South Carolina
# - *10 Electoral votes:* Maryland, Minnesota, Missouri, Wisconsin

# %%
low_turnout = ['Wyoming', 'Alaska', 'Vermont', 'Delaware', 'South Dakota', 'North Dakota', 'Hawaii', 'Rhode Island']

low = hm_model_ready2[hm_model_ready2['STATE'].isin(low_turnout)].drop('Third Party Votes',axis = 1)

# %%
low.describe()

# %% [markdown]
# **Splitting X&y**

# %%
ylow = low['GENERAL VOTES'] 
Xlow = low.drop('GENERAL VOTES',axis = 1)

# %% [markdown]
# **T-T-S**

# %%
X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(Xlow, ylow, test_size=0.3)

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_train_l.dtypes != np.float)[0]
train_pool = Pool(X_train_l, y_train_l, cat_features=categorical_features_indices)

Cat_l = Catset.fit(X_train_l, y_train_l, cat_features=categorical_features_indices , use_best_model=True);

# %%
#Would like to get it down to less than 20,000...
Cat_l.score(X_test_l, y_test_l)

# %% [markdown]
# ### Pipeline for Prediction

# %%
# submission = pd.DataFrame()
# submission['Item_Identifier'] = test['Item_Identifier']
# submission['Outlet_Identifier'] = test['Outlet_Identifier']
# submission['Item_Outlet_Sales'] = model.predict(test)
# 408           Texas  2014     D            270095.0             1.0
# 411   West Virginia  2014     R             10667.0             0.0
# 412   West Virginia  2014     D             29590.0             1.0
# 413         Wyoming  2014     R             16977.0             0.0
# 414         Wyoming  2014     D              7670.0             1.0
#
# [337 rows x 10 columns]

# %%
Cat.predict([['10000', '3', '1', 7000, 'Alaska','2014', 'R',3000,1]])
# Out:
# array([93024.73064843])

# %%
#Read in CSV
Primaries_2018 = pd.read_csv('Primary_Results_Predicting.csv')

# %%
#Assigning a year
Primaries_2018['YEAR'] = '2018'

# %%
#IDs to merge on later
Primaries_2018["ID"] = Primaries_2018["State"].map(str) + Primaries_2018["YEAR"] +Primaries_2018["Party"]

# %%
Primaries_party = Primaries_2018[Primaries_2018['Party'].isin(['R','D'])]

# %%
Primaries_party
# Out:
#        Date          State         Candidate Name  Number of Votes Percentage  \
# 0     6-Mar          Texas          Beto O'Rourke         641324.0     61.80%
# 1     6-Mar          Texas         Sema Hernandez         246308.0       23.7
# 2     6-Mar          Texas       Edward Kimbrough         150147.0       14.5
# 3     6-Mar          Texas              Ted Cruz*        1317450.0     85.30%
# 4     6-Mar          Texas            Mary Miller          94451.0        6.1
# 5     6-Mar          Texas         Bruce Jacobson          64604.0        4.2
# 6     6-Mar          Texas     Stefano de Stefano          44327.0        2.9
# 7     6-Mar          Texas          Geraldine Sam          22842.0        1.5
# 8     8-May        Indiana            Joe Donelly              0.0          0
# 9     8-May        Indiana             Mike Braun         208505.0     41.20%
# 10    8-May        Indiana            Todd Rokita         151906.0         30
# 11    8-May        Indiana            Luke Messer         146081.0       28.8
# 12    8-May           Ohio          Sherrod Brown              0.0          0
# 13    8-May           Ohio       James B. Renacci         360475.0     47.40%
# 14    8-May           Ohio           Mike Gibbons         241109.0       31.7
# 15    8-May           Ohio        Melissa Ackison          99455.0       13.1
# 16    8-May           Ohio              Dan Kiley          30323.0          4
# 17    8-May           Ohio            Don Eckhart          29446.0        3.9
# 18    8-May  West Virginia            Joe Manchin         111589.0     69.80%
# 19    8-May  West Virginia  Paula Jean Swearengin          48302.0       30.2
# 20    8-May  West Virginia       Patrick Morrisey          47571.0     34.90%
# 21    8-May  West Virginia           Evan Jenkins          39888.0       29.3
# 22    8-May  West Virginia        Don Blankenship          27153.0       19.9
# 23    8-May  West Virginia          Thomas Willis          13322.0        9.8
# 24    8-May  West Virginia              Bo Copley           4206.0        3.1
# 25    8-May  West Virginia         Jack Newbrough           4080.0          3
# 26   15-May   Pennsylvania              Bob Casey              0.0          0
# 27   15-May   Pennsylvania           Lou Barletta         429888.0     63.10%
# 28   15-May   Pennsylvania         Jim Christiana         251446.0       36.9
# 29   15-May       Nebraska          Jane Raybould          57654.0     63.70%
# ..      ...            ...                    ...              ...        ...
# 105  12-Jun   North Dakota           Kevin Cramer          60998.0     87.80%
# 106  12-Jun   North Dakota         Thomas O'Neill           8449.0       12.2
# 107  12-Jun       Virginia              Tim Kaine              0.0          0
# 108  12-Jun       Virginia          Corey Stewart         136544.0     44.90%
# 109  12-Jun       Virginia           Nick Freitas         131267.0       43.1
# 26     1     D         NaN         NaN  2018   Pennsylvania2018D
# 27     0     R         NaN         NaN  2018   Pennsylvania2018R
# 28     0     R         NaN         NaN  2018   Pennsylvania2018R
# 29     0     D         NaN         NaN  2018       Nebraska2018D
# ..   ...   ...         ...         ...   ...                 ...
# 105    0     R         NaN         NaN  2018   North Dakota2018R
# 106    0     R         NaN         NaN  2018   North Dakota2018R
# 107    1     D         NaN         NaN  2018       Virginia2018D
# 108    0     R         NaN         NaN  2018       Virginia2018R
# 109    0     R         NaN         NaN  2018       Virginia2018R
# 110    0     R         NaN         NaN  2018       Virginia2018R
# 111    1     D         NaN         NaN  2018       New York2018D
# 112    0     R         NaN         NaN  2018       New York2018R
# 113    1     D         NaN         NaN  2018       Maryland2018D
# 114    0     D         NaN         NaN  2018       Maryland2018D
# 115    0     D         NaN         NaN  2018       Maryland2018D
# 116    0     D         NaN         NaN  2018       Maryland2018D
# 117    0     D         NaN         NaN  2018       Maryland2018D
# 118    0     D         NaN         NaN  2018       Maryland2018D
# 119    0     D         NaN         NaN  2018       Maryland2018D
# 120    0     D         NaN         NaN  2018       Maryland2018D
# 121    0     R         NaN         NaN  2018       Maryland2018R
# 122    0     R         NaN         NaN  2018       Maryland2018R
# 123    0     R         NaN         NaN  2018       Maryland2018R
# 124    0     R         NaN         NaN  2018       Maryland2018R
# 125    0     R         NaN         NaN  2018       Maryland2018R
# 126    0     R         NaN         NaN  2018       Maryland2018R
# 127    0     R         NaN         NaN  2018       Maryland2018R
# 128    0     R         NaN         NaN  2018       Maryland2018R
# 129    0     R         NaN         NaN  2018       Maryland2018R
# 130    0     R         NaN         NaN  2018       Maryland2018R
# 131    0     R         NaN         NaN  2018       Maryland2018R
# 132    0     D         NaN         NaN  2018           Utah2018D
# 133    0     R         NaN         NaN  2018           Utah2018R
# 134    0     R         NaN         NaN  2018           Utah2018R
#
# [124 rows x 11 columns]

# %% [markdown]
# ** Totaling the Number of votes in primary **

# %%
primaries_partytotal = Primaries_party[['ID','Number of Votes']]

primaries_partytotal = primaries_partytotal.dropna()

primaries_partytotal["Number of Votes"]= primaries_partytotal["Number of Votes"].astype(float)

primaries_partytotal = primaries_partytotal.groupby(['ID']).sum().reset_index()

primaries_partytotal = primaries_partytotal.rename(columns = {'Number of Votes':'Total Party Votes'})

# %%
primaries_partytotal
# Out:
#                     ID  Total Party Votes
# 0      California2018D          2876479.0
# 1      California2018R          1573388.0
# 2         Indiana2018D                0.0
# 3         Indiana2018R           506492.0
# 4           Maine2018D                0.0
# 5           Maine2018R                0.0
# 6        Maryland2018D           560477.0
# 7        Maryland2018R           169047.0
# 8     Mississippi2018D            85709.0
# 9     Mississippi2018R           155022.0
# 10        Montana2018D                0.0
# 11        Montana2018R           152483.0
# 12       Nebraska2018D            90480.0
# 13       Nebraska2018R           167645.0
# 14         Nevada2018D           143329.0
# 15         Nevada2018R           142175.0
# 16     New Jersey2018D           417858.0
# 17     New Jersey2018R           222395.0
# 18     New Mexico2018D                0.0
# 19     New Mexico2018R                0.0
# 20       New York2018D                0.0
# 21       New York2018R                0.0
# 22   North Dakota2018D                0.0
# 23   North Dakota2018R            69447.0
# 24           Ohio2018D                0.0
# 25           Ohio2018R           760808.0
# 26   Pennsylvania2018D                0.0
# 27   Pennsylvania2018R           681334.0
# 28          Texas2018D          1037779.0
# 29          Texas2018R          1543674.0
# 30           Utah2018D                0.0
# 31           Utah2018R           302671.0
# 32       Virginia2018D                0.0
# 33       Virginia2018R           304435.0
# 34  West Virginia2018D           159891.0
# 35  West Virginia2018R           136220.0

# %% [markdown]
# ** Counting the Number of Candidates **

# %%
NumRunning_p = Primaries_party.groupby(['ID']).count().reset_index()

NumRunning_p = NumRunning_p[['ID','Number of Votes']]

NumRunning_p = NumRunning_p.rename(columns = {'Number of Votes':'Candidate Count'})

# %%
NumRunning_p
# Out:
#                     ID  Candidate Count
# 0      California2018D               10
# 1      California2018R               11
# 2         Indiana2018D                1
# 3         Indiana2018R                3
# 4           Maine2018D                1
# 5           Maine2018R                1
# 6        Maryland2018D                8
# 7        Maryland2018R               11
# 8     Mississippi2018D                6
# 9     Mississippi2018R                2
# 10        Montana2018D                1
# 11        Montana2018R                4
# 12       Nebraska2018D                4
# 13       Nebraska2018R                5
# 14         Nevada2018D                7
# 15         Nevada2018R                6
# 16     New Jersey2018D                2
# 17     New Jersey2018R                2
# 18     New Mexico2018D                1
# 19     New Mexico2018R                1
# 20       New York2018D                1
# 21       New York2018R                1
# 22   North Dakota2018D                1
# 23   North Dakota2018R                2
# 24           Ohio2018D                1
# 25           Ohio2018R                5
# 26   Pennsylvania2018D                1
# 27   Pennsylvania2018R                2
# 28          Texas2018D                3
# 29          Texas2018R                5
# 30           Utah2018D                1
# 31           Utah2018R                2
# 32       Virginia2018D                1
# 33       Virginia2018R                3
# 34  West Virginia2018D                2
# 35  West Virginia2018R                6

# %% [markdown]
# ** Inumbent Log **

# %%
Incumbents = Primaries_party.groupby(['ID']).sum().reset_index()

# %%
Incumbents = Incumbents[['ID','(I)']]

# %% [markdown]
# ** Max votes per party per state **

# %%
PartyWin_p = Primaries_party[['ID','Number of Votes','State','YEAR','Party']]

PartyWin_p = PartyWin_p.dropna()

PartyWin_p["Number of Votes"]= PartyWin_p["Number of Votes"].astype(float)

PartyWin_p = PartyWin_p.groupby(['ID']).max().reset_index()

PartyWin_p = PartyWin_p.rename(columns = {'Number of Votes':'Primary Winner'})

# %%
PartyWin_p
# Out:
#                     ID  Primary Winner          State  YEAR Party
# 0      California2018D       2031967.0     California  2018     D
# 1      California2018R        398477.0     California  2018     R
# 2         Indiana2018D             0.0        Indiana  2018     D
# 3         Indiana2018R        208505.0        Indiana  2018     R
# 4           Maine2018D             0.0          Maine  2018     D
# 5           Maine2018R             0.0          Maine  2018     R
# 6        Maryland2018D        450890.0       Maryland  2018     D
# 7        Maryland2018R         49428.0       Maryland  2018     R
# 8     Mississippi2018D         27358.0    Mississippi  2018     D
# 9     Mississippi2018R        128309.0    Mississippi  2018     R
# 10        Montana2018D             0.0        Montana  2018     D
# 11        Montana2018R         51549.0        Montana  2018     R
# 28          Texas2018D          1037779.0                3        641324.0
# 29          Texas2018R          1543674.0                5       1317450.0
# 30           Utah2018D                0.0                1             0.0
# 31           Utah2018R           302671.0                2        217049.0
# 32       Virginia2018D                0.0                1             0.0
# 33       Virginia2018R           304435.0                3        136544.0
# 34  West Virginia2018D           159891.0                2        111589.0
# 35  West Virginia2018R           136220.0                6         47571.0
#
#             State  YEAR Party  (I)  Primary Loser Vote
# 0      California  2018     D    1            844512.0
# 1      California  2018     R    0           1174911.0
# 2         Indiana  2018     D    1                 0.0
# 3         Indiana  2018     R    0            297987.0
# 4           Maine  2018     D    0                 0.0
# 5           Maine  2018     R    0                 0.0
# 6        Maryland  2018     D    1            109587.0
# 7        Maryland  2018     R    0            119619.0
# 8     Mississippi  2018     D    0             58351.0
# 9     Mississippi  2018     R    1             26713.0
# 10        Montana  2018     D    1                 0.0
# 11        Montana  2018     R    0            100934.0
# 12       Nebraska  2018     D    0             32826.0
# 13       Nebraska  2018     R    1             40562.0
# 14         Nevada  2018     D    0             32799.0
# 15         Nevada  2018     R    1             42703.0
# 16     New Jersey  2018     D    1            157983.0
# 17     New Jersey  2018     R    0             55274.0
# 18     New Mexico  2018     D    1                 0.0
# 19     New Mexico  2018     R    0                 0.0
# 20       New York  2018     D    1                 0.0
# 21       New York  2018     R    0                 0.0
# 22   North Dakota  2018     D    1                 0.0
# 23   North Dakota  2018     R    0              8449.0
# 24           Ohio  2018     D    1                 0.0
# 25           Ohio  2018     R    0            400333.0
# 26   Pennsylvania  2018     D    1                 0.0
# 27   Pennsylvania  2018     R    0            251446.0
# 28          Texas  2018     D    0            396455.0
# 29          Texas  2018     R    0            226224.0
# 30           Utah  2018     D    0                 0.0
# 31           Utah  2018     R    0             85622.0
# 32       Virginia  2018     D    1                 0.0
# 33       Virginia  2018     R    0            167891.0
# 34  West Virginia  2018     D    1             48302.0
# 35  West Virginia  2018     R    0             88649.0

# %% [markdown]
# ** Adding if party is in the white house **

# %%
OP2018 = []

for party in votes_merged_p['Party']:
    if party == 'R':
        OP2018.append(1)
        
    else:
        OP2018.append(0)
    
votes_merged_p['OFFICE PARTY'] = OP2018

# %% [markdown]
# ** Seperating out Unopposed **

# %%
Unopp2018 = votes_merged_p.drop(votes_merged_p[votes_merged_p['Primary Winner'] > 1].index)

# %%
Unopp2018
# Out:
#                    ID  Total Party Votes  Candidate Count  Primary Winner  \
# 2        Indiana2018D                0.0                1             0.0
# 4          Maine2018D                0.0                1             0.0
# 5          Maine2018R                0.0                1             0.0
# 10       Montana2018D                0.0                1             0.0
# 18    New Mexico2018D                0.0                1             0.0
# 19    New Mexico2018R                0.0                1             0.0
# 20      New York2018D                0.0                1             0.0
# 21      New York2018R                0.0                1             0.0
# 22  North Dakota2018D                0.0                1             0.0
# 24          Ohio2018D                0.0                1             0.0
# 26  Pennsylvania2018D                0.0                1             0.0
# 30          Utah2018D                0.0                1             0.0
# 32      Virginia2018D                0.0                1             0.0
#
#            State  YEAR Party  (I)  Primary Loser Vote  OFFICE PARTY
# 2        Indiana  2018     D    1                 0.0             0
# %%
fin2018 = fin2018.rename(index=str, columns={"State": "STATE", "Party": "PARTY","OFFICE PARTY":'Party In House'}).drop("ID",axis=1)

# fin2018['Total Party Votes'] = fin2018['Total Party Votes']
# fin2018['Candidate Count'] = fin2018['Candidate Count']
# fin2018['(I)'] = fin2018['(I)']
# fin2018['Primary Winner'] = fin2018['Primary Winner']
# fin2018['STATE'] = fin2018['State']
# fin2018['YEAR'] = fin2018['YEAR']
# fin2018['PARTY'] = fin2018['Party']
# fin2018['Primary Loser Vote'] = fin2018['Primary Loser Vote']
# fin2018['Party In House'] = fin2018['OFFICE PARTY']

# submission.to_csv("Submission.csv")


# fin2018['Predicted Turnout'] = Cat.predict(fin2018)
# submission.to_csv("Submission.csv")
# Cat.predict([['10000', '3', '1', 7000, 'Alaska','2014', 'R',3000,1]])

# %%
fin2018
# Out:
#     Total Party Votes  Candidate Count  Primary Winner          STATE  YEAR  \
# 0           2876479.0               10       2031967.0     California  2018
# 1           1573388.0               11        398477.0     California  2018
# 3            506492.0                3        208505.0        Indiana  2018
# 6            560477.0                8        450890.0       Maryland  2018
# 7            169047.0               11         49428.0       Maryland  2018
# 8             85709.0                6         27358.0    Mississippi  2018
# 9            155022.0                2        128309.0    Mississippi  2018
# 11           152483.0                4         51549.0        Montana  2018
# 12            90480.0                4         57654.0       Nebraska  2018
# 13           167645.0                5        127083.0       Nebraska  2018
# 14           143329.0                7        110530.0         Nevada  2018
# 15           142175.0                6         99472.0         Nevada  2018
# 16           417858.0                2        259875.0     New Jersey  2018
# 17           222395.0                2        167121.0     New Jersey  2018
# 23            69447.0                2         60998.0   North Dakota  2018
# 25           760808.0                5        360475.0           Ohio  2018
# 27           681334.0                2        429888.0   Pennsylvania  2018
# 28          1037779.0                3        641324.0          Texas  2018
# 29          1543674.0                5       1317450.0          Texas  2018
# 31           302671.0                2        217049.0           Utah  2018
# 33           304435.0                3        136544.0       Virginia  2018
# 34           159891.0                2        111589.0  West Virginia  2018
# 35           136220.0                6         47571.0  West Virginia  2018
#
#    PARTY  (I)  Primary Loser Vote  Party In House
# 0      D    1            844512.0               0
# 1      R    0           1174911.0               1
# 3      R    0            297987.0               1
# 6      D    1            109587.0               0
# 7      R    0            119619.0               1
# 8      D    0             58351.0               0
# 9      R    1             26713.0               1
# 11     R    0            100934.0               1
# 12     D    0             32826.0               0
# 13     R    1             40562.0               1
# 14     D    0             32799.0               0
# 15     R    1             42703.0               1
# 16     D    1            157983.0               0
# 17     R    0             55274.0               1
# 23     R    0              8449.0               1
# 25     R    0            400333.0               1
# 27     R    0            251446.0               1
# 28     D    0            396455.0               0
# 29     R    0            226224.0               1
# 31     R    0             85622.0               1
# 33     R    0            167891.0               1
# 34     D    1             48302.0               0
# 35     R    0             88649.0               1

# %%
# GENERAL VOTES	Total Party Votes	Candidate Count	(I)	Primary Winner	STATE	YEAR	PARTY	Primary Loser Vote	Party In House

# %%
fin2018 = fin2018[['Total Party Votes', 'Candidate Count', '(I)', 'Primary Winner', 'STATE', 'YEAR','PARTY','Primary Loser Vote','Party In House']]

# %%
### WE have to re-order so the columns are structured the same way as the input. 
fin2018['Predicted Turnout'] = Cat.predict(fin2018)
# Out:
# /Users/vicky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fin2018
# Out:
#     Total Party Votes  Candidate Count  (I)  Primary Winner          STATE  \
# 0           2876479.0               10    1       2031967.0     California
# 1           1573388.0               11    0        398477.0     California
# 3            506492.0                3    0        208505.0        Indiana
# 6            560477.0                8    1        450890.0       Maryland
# 7            169047.0               11    0         49428.0       Maryland
# 8             85709.0                6    0         27358.0    Mississippi
# 9            155022.0                2    1        128309.0    Mississippi
# 11           152483.0                4    0         51549.0        Montana
# 12            90480.0                4    0         57654.0       Nebraska
# 13           167645.0                5    1        127083.0       Nebraska
# 14           143329.0                7    0        110530.0         Nevada
# 15           142175.0                6    1         99472.0         Nevada
# 16           417858.0                2    1        259875.0     New Jersey
# 17           222395.0                2    0        167121.0     New Jersey
# 23            69447.0                2    0         60998.0   North Dakota
# 25           760808.0                5    0        360475.0           Ohio
# 27           681334.0                2    0        429888.0   Pennsylvania
# 28          1037779.0                3    0        641324.0          Texas
# 29          1543674.0                5    0       1317450.0          Texas
# 31           302671.0                2    0        217049.0           Utah
# 33           304435.0                3    0        136544.0       Virginia
# 34           159891.0                2    1        111589.0  West Virginia
# 35           136220.0                6    0         47571.0  West Virginia
#
#     YEAR PARTY  Primary Loser Vote  Party In House  Predicted Turnout
# 0   2018     D            844512.0               0       4.588160e+06
# 1   2018     R           1174911.0               1       2.513807e+06
# 3   2018     R            297987.0               1       1.368175e+06
# 6   2018     D            109587.0               0       1.279270e+06
# 7   2018     R            119619.0               1       5.808334e+05
# 8   2018     D             58351.0               0       3.283194e+05
# 9   2018     R             26713.0               1       5.614944e+05
# 11  2018     R            100934.0               1       4.083868e+05
# 12  2018     D             32826.0               0       3.836316e+05
# 13  2018     R             40562.0               1       5.127871e+05
# 14  2018     D             32799.0               0       4.713758e+05
# 15  2018     R             42703.0               1       4.694424e+05
# 16  2018     D            157983.0               0       1.227240e+06
# 17  2018     R             55274.0               1       9.770121e+05
# 23  2018     R              8449.0               1       3.800906e+05
# 25  2018     R            400333.0               1       1.811128e+06
# 27  2018     R            251446.0               1       1.610444e+06
# 28  2018     D            396455.0               0       2.698468e+06
# 29  2018     R            226224.0               1       3.085933e+06
# 31  2018     R             85622.0               1       6.849902e+05
# 33  2018     R            167891.0               1       1.040247e+06
# 34  2018     D             48302.0               0       5.309868e+05
# 35  2018     R             88649.0               1       3.743784e+05

# %%
fin2018.to_csv('Fin2018.csv')

# %% [markdown]
# ** Choosing which states to focus on!!! **

# %% [markdown]
# States that are most contentious:
# - Indiana (unopposed D...)
# - Mississippi (Seems likely R!)
# - Montana (unopposed D...)
# - Nebraska (Seems likely R!)
# - Nevada (Gonna be a close one!!!)
# - New Jersey (Seems likely D!)
# - North Dakota (unopposed D...)
# - Ohio (unopposed D...)
# - Pennsylvania (unopposed D...)
# - Texas (Seems likely R!...)
# - Virginia (unopposed D...)
# - West Virginia (Gonna be a close one!!!)
#
# **Maybe I look at how much they gather last election?**
