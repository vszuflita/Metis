# %% [markdown]
# ** Let's see if having Unopposed as zero ends up being predictive at all...** FINGERS CROSSED!

# %%
import pandas as pd
import csv
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error as MSE
import matplotlib.pyplot as plt
# %matplotlib inline
# from paramsearch import paramsearch
from itertools import product,chain

# %% [markdown]
# ### Data Aggregation

# %% [markdown]
# #### Prepping Files

# %% [markdown]
# Reading the CSV files

# %%
hm2016 = pd.read_csv('federalelections2016 (2).csv')
hm2014 = pd.read_csv('federalelections2014.csv')
hm2012 = pd.read_csv('Senate_Primary_2012.csv')
hm2010 = pd.read_csv('Primary2010.csv')
hm2008 = pd.read_csv('Primary2008.csv')
hm2006 = pd.read_csv('Primary2006.csv')
hm2004 = pd.read_csv('FederalElection2004.csv')


### Add back incumbent column!!

# %% [markdown]
# **Adding the year to each CSV for easier analysis**

# %%
hm2016['YEAR'] = '2016'
hm2014['YEAR'] = '2014'
hm2012['YEAR'] = '2012'
hm2010['YEAR'] = '2010'
hm2008['YEAR'] = '2008'
hm2006['YEAR'] = '2006'
hm2004['YEAR'] = '2004'

# %% [markdown]
# **Creating IDs I will later merge on**

# %%
hm2016["ID"] = hm2016["STATE"].map(str) + hm2016["YEAR"] +hm2016["PARTY"]
hm2016["ID2"] = hm2016["STATE"].map(str) + hm2016["YEAR"]

hm2014["ID"] = hm2014["STATE"].map(str) + hm2014["YEAR"] +hm2014["PARTY"]
hm2014["ID2"] = hm2014["STATE"].map(str) + hm2014["YEAR"]

hm2012["ID"] = hm2012["STATE"].map(str) + hm2012["YEAR"] +hm2012["PARTY"]
hm2012["ID2"] = hm2012["STATE"].map(str) + hm2012["YEAR"]

hm2010["ID"] = hm2010["STATE"].map(str) + hm2010["YEAR"] +hm2010["PARTY"]
hm2010["ID2"] = hm2010["STATE"].map(str) + hm2010["YEAR"]

hm2008["ID"] = hm2008["STATE"].map(str) + hm2008["YEAR"] +hm2008["PARTY"]
hm2008["ID2"] = hm2008["STATE"].map(str) + hm2008["YEAR"]

hm2006["ID"] = hm2006["STATE"].map(str) + hm2006["YEAR"] +hm2006["PARTY"]
hm2006["ID2"] = hm2006["STATE"].map(str) + hm2006["YEAR"]

hm2004["ID"] = hm2004["STATE"].map(str) + hm2004["YEAR"] +hm2004["PARTY"]
hm2004["ID2"] = hm2004["STATE"].map(str) + hm2004["YEAR"]

# %% [markdown]
# **Dropping weird columns & fixing weird merging errors**

# %%
hm2014 = hm2014.drop('Unnamed: 8', axis=1).drop('Unnamed: 9',axis=1)

# %%
# hm2012 = hm2012.drop('Unnamed: 9', axis=1)

# %%
# hm2010.columns = [col.strip() for col in hm2010.columns]

# %%
hm2012.columns = [col.strip() for col in hm2012.columns]

# %%
hm2014.columns = [col.strip() for col in hm2014.columns]

# %%
hm2016.columns = [col.strip() for col in hm2016.columns]

# %% [markdown]
# **Append files together**

# %%
hm = hm2016.append(hm2012).append(hm2004).append(hm2006).append(hm2008).append(hm2010).append(hm2014)

# %%
# ## Want to make "Incument" versus not a binary count.  
# hm = hm.replace(to_replace = 'FULL TERM',value='(I)').replace(to_replace = 'UNEXPIRED TERM ',value='(I)').replace(to_replace=' (I)',value='(I)').replace(to_replace='UNEXPIRED TERM',value='(I)')

# %%
len(hm[hm['PRIMARY VOTES']== 'Unopposed'])
# Out:
# 71

# %% [markdown]
# #### Party data

# %% [markdown]
# **Removing all third party candidates**

# %%
hm = hm.replace(to_replace = 'R*',value='R').replace(to_replace = 'R ',value='R').replace(to_replace = 'D*',value='D').replace(to_replace = 'D* ',value='D').replace(to_replace = 'D ',value='D')

# %%
hm_party = hm[hm['PARTY'].isin(['R','D'])]

# %% [markdown]
# **Throwing out rows that are interupting analysis**

# %%
hm_party2 = hm_party[~hm_party['PRIMARY VOTES'].isin(['*','#','14*','20*','1,040*','1,616**','Loser','Winner','Withdrew'])]

# %%
hm_party2 = hm_party2.replace(to_replace ='Unopposed', value=0)

# %%
hm_party2 = hm_party2[~hm_party2['TOTAL VOTES'].isin(['Party Votes:','Total State Votes:'])]

# %%
hm_party2 = hm_party2[~hm_party2['ID'].isin(['South Carolina2014R','Wyoming2008R'])]

# %% [markdown]
# **Find total votes for each party, each state **

# %%
#Didn't work :( It's missing a few states.
# hm_partytotal = hm_party[hm_party['TOTAL VOTES'].isin(['Party Votes:'])]
# hm_partytotal = hm_partytotal[['ID','PRIMARY VOTES']]

# %%
hm_partytotal = hm_party2[['ID','PRIMARY VOTES']]

# %%
hm_partytotal = hm_partytotal.dropna()

# %%
hm_partytotal["PRIMARY VOTES"]=hm_partytotal["PRIMARY VOTES"].astype(float)

# %%
hm_partytotal = hm_partytotal.groupby(['ID']).sum().reset_index()

# %%
hm_partytotal = hm_partytotal.rename(columns = {'PRIMARY VOTES':'Total Party Votes'})

# %% [markdown]
# **Finding How many people ran in the primary**

# %%
NumRunning = hm_party2.groupby(['ID']).count().reset_index()

# %%
NumRunning = NumRunning[['ID','PRIMARY VOTES','(I)']]

# %%
NumRunning['(I)'].value_counts()
# Out:
# 0    276
# 1    168
# Name: (I), dtype: int64

# %%
NumRunning = NumRunning.rename(columns = {'PRIMARY VOTES':'Candidate Count'})

# %% [markdown]
# **Finding max vote for each party, each state**

# %%
PartyWin = hm_party2[['ID','PRIMARY VOTES','STATE','YEAR','PARTY']]

# %%
PartyWin = PartyWin.dropna()

# %%
PartyWin["PRIMARY VOTES"]= PartyWin["PRIMARY VOTES"].astype(float)

# %%
PartyWin = PartyWin.groupby(['ID']).max().reset_index()

# %%
PartyWin = PartyWin.rename(columns = {'PRIMARY VOTES':'Primary Winner'})

# %% [markdown]
# -Group by state and party
# -Tuple of the candidates aggregated
# -Winner, candidates, number of columns

# %% [markdown]
# **Merging Columns Back Together**

# %%
votes_merged = hm_partytotal.merge(NumRunning, left_on='ID', right_on='ID', how='left')

# %%
votes_merged = votes_merged.merge(PartyWin, left_on='ID', right_on='ID', how = 'left')

# %% [markdown]
# **Calcuating the total number of votes by losers**

# %%
votes_merged['Primary Loser Vote'] = votes_merged['Total Party Votes'] - votes_merged['Primary Winner']

# %% [markdown]
# #### Final Results Data

# %% [markdown]
# Creating column with final election results numbers

# %%
hm_finals = hm[hm['PARTY'].isin(['R','D'])]

# %%
hm_finals = hm_finals[['GENERAL VOTES','ID','ID2']]

# %%
hm_finals = hm_finals.dropna()

# %% [markdown]
# #### 3rd Party Data #Not Including this anymore

# %% [markdown]
# Creating column with how many people showed up to vote for the third party candidate in the primaries.

# %%
hm_third = hm[~hm['PARTY'].isin(['R','D'])]

# %%
hm_third = hm_third[hm_third['TOTAL VOTES'].isin(['Party Votes:'])]

# %%
hm_third = hm_third[['PRIMARY VOTES','ID2']]

# %%
hm_third = hm_third.groupby(['ID2'])
hm_third = hm_third['PRIMARY VOTES'].agg([np.sum]).reset_index()

# %%
hm_third = hm_third.rename(columns = {'sum':'Third Party Votes'})

# %% [markdown]
# #### Merging

# %% [markdown]
# Merging the final results data and the third party data to the original dataframe.

# %%
hm_merged = hm_finals.merge(votes_merged, left_on='ID', right_on='ID', how='left')

# %%
# hm_merged = hm_merged.merge(hm_third, left_on='ID2', right_on='ID2', how='left')

# %%
# hm_merged['Third Party Votes'] = hm_merged['Third Party Votes'].fillna(value=0)

# %% [markdown]
# ** Throwing out NaNs for races that didn't have primary data**

# %%
hm_merged = hm_merged.dropna()

# %% [markdown]
# **Making a loop for whether or not a candidate's party is in the oval office.**

# %%
Republican = ['2008','2006','2004','2002','1992','1990']

OfficeParty = []


for year in hm_merged['YEAR']:
    if year in Republican:
        OfficeParty.append('R')
        
    else:
        OfficeParty.append('D')
    
hm_merged['OFFICE PARTY'] = OfficeParty

# %% [markdown]
# ** Create Column for whether or not the party is in office**

# %%
hm_merged['Party In House'] = np.where(hm_merged['PARTY']== hm_merged['OFFICE PARTY'], 1,0)

# %%
hm_model_ready = hm_merged.drop('ID',axis=1).drop('ID2',axis=1).drop('OFFICE PARTY',axis=1)

# %%
# hm_model_ready = hm_merged.drop('ID',axis=1).drop('ID2',axis=1).drop('Total Party Votes',axis=1).drop('YEAR',axis=1).drop('OFFICE PARTY',axis=1)

# %%
hm_model_ready = hm_model_ready[~hm_model_ready['GENERAL VOTES'].isin(['#'])]

# %%
hm_model_ready
# Out:
#     GENERAL VOTES  Total Party Votes  Candidate Count  (I)  Primary Winner  \
# 0      1.3351e+06           778851.0              5.0  1.0        505586.0
# 1          748709           274423.0              2.0  0.0        153897.0
# 2          138149            55293.0              4.0  1.0         39545.0
# 3           36200            25318.0              2.0  0.0         15228.0
# 4     1.35927e+06           591155.0              4.0  1.0        302532.0
# 5     1.03124e+06           333586.0              1.0  0.0        333586.0
# 6          661984           389834.0              2.0  1.0        298039.0
# 7          400602                0.0              1.0  0.0             0.0
# 8     7.54276e+06          4811300.0              7.0  0.0       3000689.0
# 9     4.70142e+06          4811300.0              7.0  0.0       3000689.0
# 10    1.37071e+06           262344.0              1.0  1.0        262344.0
# 11    1.21532e+06           347471.0              5.0  0.0        131125.0
# 14    4.83519e+06          1430492.0              4.0  1.0       1029830.0
# 15    4.12209e+06          1129781.0              5.0  0.0        665985.0
# 16    2.13581e+06           577660.0              3.0  1.0        447661.0
# 17    1.59973e+06           310053.0              3.0  0.0        166627.0
# 18         306604           189059.0              5.0  1.0        162905.0
# 19          92653            35865.0              4.0  0.0         26749.0
# 20         449017           119633.0              1.0  1.0        119633.0
# 21         188249            26471.0              1.0  0.0         26471.0
# 22    3.01294e+06          1895143.0              3.0  0.0       1220128.0
# 23    2.18469e+06          1320190.0              2.0  1.0        931619.0
# 24    1.42399e+06           985565.0              2.0  0.0        661136.0
# 25    1.15895e+06           516183.0              1.0  0.0        516183.0
# 26         926007            90089.0              1.0  1.0         90089.0
# 27         549460            97121.0              4.0  0.0         46322.0
# 28    1.09018e+06           199519.0              3.0  1.0        169180.0
# 29         813246           409643.0              7.0  0.0        240598.0
# 46    1.65991e+06           884344.0             10.0  0.0        470320.0
# 47         972557           379831.0             14.0  0.0        135337.0
# ..            ...                ...              ...  ...             ...
# 382        347636           218879.0              5.0  0.0        108443.0
# 383        170127            65970.0              2.0  0.0         44487.0
# 384        251184            39282.0              1.0  1.0         39282.0
# 385        235347           118234.0             10.0  0.0         59147.0
# 386       1043866           202129.0              1.0  1.0        202129.0
# 387        791297           145307.0              4.0  0.0         42728.0
# 388        286409           113502.0              1.0  1.0        113502.0
# 389        229097            65979.0              2.0  0.0         41566.0
# 390       1423259           488555.0              8.0  0.0        223174.0
# 391       1377651           482369.0              3.0  1.0        372209.0
# 392        558166           530633.0             12.0  1.0        231291.0
# 393        234307           163003.0              4.0  0.0         71462.0
# 394        557002           530633.0             12.0  1.0        231291.0
# 395        237923           163003.0              4.0  0.0         71462.0
# 396        538847           268416.0              5.0  0.0        134627.0
# 397        223675            98816.0              1.0  1.0         98816.0
# 398         92684            23787.0              1.0  0.0         23787.0
# 400        456726           225667.0              5.0  0.0         87552.0
# 402        459583           225667.0              5.0  0.0         87552.0
# 403        140741            74498.0              5.0  0.0         41377.0
# 404         82456                0.0              1.0  0.0             0.0
# 405        850087           664673.0              6.0  1.0        331705.0
# 406        437848           240949.0              4.0  0.0         87829.0
# 407       2861531          1314556.0              8.0  1.0        781259.0
# 408       1597387           510009.0              5.0  0.0        239914.0
# 409       1073667                0.0              1.0  1.0             0.0
# 411        281820            85322.0              3.0  0.0         74655.0
# 412        156360           134188.0              3.0  0.0        104598.0
# 413        121554            94942.0              5.0  1.0         77965.0
# 414         29377            14870.0              4.0  0.0          7200.0
#
#               STATE  YEAR PARTY  Primary Loser Vote  Party In House
# 0           Alabama  2016     R            273265.0               0
# 1           Alabama  2016     D            120526.0               1
# 2            Alaska  2016     R             15748.0               0
# 3            Alaska  2016     D             10090.0               1
# 4           Arizona  2016     R            288623.0               0
# 5           Arizona  2016     D                 0.0               1
# 6          Arkansas  2016     R             91795.0               0
# 7          Arkansas  2016     D                 0.0               1
# 8        California  2016     D           1810611.0               1
# 9        California  2016     D           1810611.0               1
# 10         Colorado  2016     D                 0.0               1
# 11         Colorado  2016     R            216346.0               0
# 14          Florida  2016     R            400662.0               0
# 15          Florida  2016     D            463796.0               1
# 16          Georgia  2016     R            129999.0               0
# 17          Georgia  2016     D            143426.0               1
# 18           Hawaii  2016     D             26154.0               1
# 19           Hawaii  2016     R              9116.0               0
# 20            Idaho  2016     R                 0.0               0
# 21            Idaho  2016     D                 0.0               1
# 22         Illinois  2016     D            675015.0               1
# 23         Illinois  2016     R            388571.0               0
# 24          Indiana  2016     R            324429.0               0
# 25          Indiana  2016     D                 0.0               1
# 26             Iowa  2016     R                 0.0               0
# 27             Iowa  2016     D             50799.0               1
# 28         Kentucky  2016     R             30339.0               0
# 29         Kentucky  2016     D            169045.0               1
# 46         Maryland  2016     D            414024.0               1
# 47         Maryland  2016     R            244494.0               0
# ..              ...   ...   ...                 ...             ...
# 382        Nebraska  2014     R            110436.0               0
# 383        Nebraska  2014     D             21483.0               1
# 384   New Hampshire  2014     D                 0.0               1
# 385   New Hampshire  2014     R             59087.0               0
# 386      New Jersey  2014     D                 0.0               1
# 387      New Jersey  2014     R            102579.0               0
# 388      New Mexico  2014     D                 0.0               1
# 389      New Mexico  2014     R             24413.0               0
# 390  North Carolina  2014     R            265381.0               0
# 391  North Carolina  2014     D            110160.0               1
# 392        Oklahoma  2014     R            299342.0               0
# 393        Oklahoma  2014     D             91541.0               1
# 394        Oklahoma  2014     R            299342.0               0
# 395        Oklahoma  2014     D             91541.0               1
# 396          Oregon  2014     R            133789.0               0
# 397    Rhode Island  2014     D                 0.0               1
# 398    Rhode Island  2014     R                 0.0               0
# 400  South Carolina  2014     D            138115.0               1
# 402  South Carolina  2014     D            138115.0               1
# 403    South Dakota  2014     R             33121.0               0
# 404    South Dakota  2014     D                 0.0               1
# 405       Tennessee  2014     R            332968.0               0
# 406       Tennessee  2014     D            153120.0               1
# 407           Texas  2014     R            533297.0               0
# 408           Texas  2014     D            270095.0               1
# 409        Virginia  2014     D                 0.0               1
# 411   West Virginia  2014     R             10667.0               0
# 412   West Virginia  2014     D             29590.0               1
# 413         Wyoming  2014     R             16977.0               0
# 414         Wyoming  2014     D              7670.0               1
#
# [369 rows x 10 columns]

# %%
hm_model_ready["GENERAL VOTES"]= hm_model_ready["GENERAL VOTES"].astype(float)
# hm_model_ready["Third Party Votes"]= hm_model_ready["Third Party Votes"].astype(float)
hm_model_ready["Party In House"]= hm_model_ready["Party In House"].astype(float)

# %% [markdown]
# ### Modeling (All 50 States)

# %% [markdown]
# #### EDA & Futhur Cleaning

# %%
hm_model_ready.describe()
# Out:
#        GENERAL VOTES  Total Party Votes  Candidate Count         (I)  \
# count   3.690000e+02       3.690000e+02       369.000000  369.000000
# mean    1.120396e+06       3.879946e+05         3.219512    0.387534
# std     1.203574e+06       5.490480e+05         2.552290    0.487849
# min     2.937700e+04       0.000000e+00         1.000000    0.000000
# 25%     2.846400e+05       7.813200e+04         1.000000    0.000000
# 50%     7.919500e+05       2.189690e+05         3.000000    0.000000
# 75%     1.479471e+06       5.216570e+05         4.000000    1.000000
# max     7.864624e+06       4.811300e+06        18.000000    1.000000
#
#        Primary Winner  Primary Loser Vote  Party In House
# count    3.690000e+02        3.690000e+02      369.000000
# mean     2.702476e+05        1.177470e+05        0.495935
# std      3.872883e+05        2.164664e+05        0.500662
# min      0.000000e+00        0.000000e+00        0.000000
# 25%      5.587800e+04        0.000000e+00        0.000000
# 50%      1.459740e+05        3.312100e+04        0.000000
# 75%      3.466700e+05        1.381150e+05        1.000000
# max      3.000689e+06        1.810611e+06        1.000000

# %%
hm_model_ready.sort_values(by=['GENERAL VOTES'])
# Out:
#      GENERAL VOTES  Total Party Votes  Candidate Count  (I)  Primary Winner  \
# 414        29377.0            14870.0              4.0  0.0          7200.0
# 3          36200.0            25318.0              2.0  0.0         15228.0
# 141        53019.0            16850.0              3.0  0.0          9173.0
# 273        57671.0            24924.0              1.0  0.0         24924.0
# 277        60045.0            30287.0              3.0  0.0         18035.0
# 250        64417.0            40647.0              1.0  0.0         40647.0
# 219        69734.0            11881.0              2.0  0.0          6110.0
# 335        72699.0            22750.0              1.0  0.0         22750.0
# 131        72898.0             8442.0              2.0  0.0          6358.0
# 206        75398.0            13364.0              3.0  0.0          9591.0
# 295        79939.0            34407.0              3.0  0.0         23033.0
# 404        82456.0                0.0              1.0  0.0             0.0
# 263        84924.0            32487.0              2.0  0.0         22008.0
# 161        87172.0            43956.0              4.0  0.0         21645.0
# 276        90839.0            55878.0              1.0  0.0         55878.0
# 19         92653.0            35865.0              4.0  0.0         26749.0
# 398        92684.0            23787.0              1.0  0.0         23787.0
# 94         92900.0            51941.0              4.0  0.0         22974.0
# 354        98006.0            35809.0              4.0  0.0         25874.0
# 190        98553.0            39329.0              1.0  0.0         39329.0
# 350        98823.0            24029.0              2.0  0.0         18181.0
# 74        103637.0            37782.0              1.0  0.0         37782.0
# 70        104140.0                0.0              1.0  0.0             0.0
# 226       111984.0            44601.0              2.0  0.0         22582.0
# 297       112057.0            24567.0              2.0  0.0         18340.0
# 86        115700.0                0.0              1.0  0.0             0.0
# 413       121554.0            94942.0              5.0  1.0         77965.0
# 289       123053.0            57584.0              2.0  0.0         30563.0
# 223       126097.0            24724.0              6.0  0.0         10139.0
# 344       129431.0            60116.0              2.0  1.0         58092.0
# ..             ...                ...              ...  ...             ...
# 220      2890548.0                0.0              1.0  1.0             0.0
# 197      2925080.0          1044532.0              2.0  1.0        530839.0
# 65       2951702.0          1342941.0              1.0  1.0       1342941.0
# 215      2990822.0          1560472.0              1.0  0.0       1560472.0
# 22       3012940.0          1895143.0              3.0  0.0       1220128.0
# 121      3021364.0           699171.0              2.0  1.0        565488.0
# 59       3118567.0          1626954.0              2.0  1.0       1336686.0
# 128      3194927.0           497487.0              4.0  0.0        174772.0
# 88       3458267.0          1127019.0              4.0  0.0        661570.0
# 191      3464651.0           835558.0              2.0  1.0        640082.0
# 157      3590201.0          1152513.0              4.0  0.0        669346.0
# 163      3597456.0          1242986.0              7.0  0.0        655923.0
# 156      3672864.0          1165931.0              8.0  0.0        522994.0
# 15       4122088.0          1129781.0              5.0  0.0        665985.0
# 283      4217386.0          2334042.0              5.0  0.0       1315429.0
# 186      4384907.0                0.0              1.0  1.0             0.0
# 116      4432525.0                0.0              1.0  1.0             0.0
# 127      4440137.0          1406648.0              9.0  0.0        627731.0
# 87       4523451.0           875741.0              2.0  1.0        690112.0
# 151      4555922.0          2266972.0             10.0  0.0       1015747.0
# 9        4701417.0          4811300.0              7.0  0.0       3000689.0
# 82       4713887.0          1907166.0             14.0  0.0        613613.0
# 54       4784218.0                0.0              1.0  1.0             0.0
# 14       4835191.0          1430492.0              4.0  1.0       1029830.0
# 214      5076289.0          2503369.0              3.0  1.0       2176888.0
# 282      5218137.0          2419935.0              3.0  1.0       1957920.0
# 208      5548646.0           769514.0              3.0  1.0        709497.0
# 150      6955728.0          2566298.0              1.0  1.0       2566298.0
# 8        7542759.0          4811300.0              7.0  0.0       3000689.0
# 81       7864624.0          2742936.0              6.0  1.0       2392822.0
#
#             STATE  YEAR PARTY  Primary Loser Vote  Party In House
# 414       Wyoming  2014     D              7670.0             1.0
# 3          Alaska  2016     D             10090.0             1.0
# 141       Wyoming  2012     D              7677.0             1.0
# 273       Wyoming  2006     D                 0.0             0.0
# 277        Alaska  2010     D             12252.0             1.0
# 250  North Dakota  2006     R                 0.0             1.0
# 219      Delaware  2006     R              5771.0             1.0
# 335       Vermont  2010     R                 0.0             0.0
# 131       Vermont  2012     R              2084.0             0.0
# 206       Vermont  2004     R              3773.0             1.0
# 295        Hawaii  2010     R             11374.0             0.0
# 404  South Dakota  2014     D                 0.0             1.0
# 263       Vermont  2006     R             10479.0             1.0
# 161        Hawaii  2004     R             22311.0             1.0
# 276        Alaska  2010     R                 0.0             0.0
# 19         Hawaii  2016     R              9116.0             0.0
# 398  Rhode Island  2014     R                 0.0             0.0
# 94          Maine  2012     D             28967.0             1.0
# 354        Hawaii  2014     R              9935.0             0.0
# 190  North Dakota  2004     R                 0.0             1.0
# 350      Delaware  2014     R              5848.0             0.0
# 74        Vermont  2016     R                 0.0             0.0
# 70   South Dakota  2016     D                 0.0             1.0
# 226         Maine  2006     D             22019.0             0.0
# 297         Idaho  2010     D              6227.0             1.0
# 86       Delaware  2012     R                 0.0             0.0
# 413       Wyoming  2014     R             16977.0             0.0
# 289      Delaware  2010     R             27021.0             0.0
# 223        Hawaii  2006     R             14585.0             1.0
# 344        Alaska  2014     D              2024.0             1.0
# ..            ...   ...   ...                 ...             ...
# 220       Florida  2006     D                 0.0             0.0
# 197  Pennsylvania  2004     R            513693.0             1.0
# 65   Pennsylvania  2016     R                 0.0             0.0
# 215    California  2006     R                 0.0             1.0
# 22       Illinois  2016     D            675015.0             1.0
# 121  Pennsylvania  2012     D            133683.0             1.0
# 59           Ohio  2016     R            290268.0             0.0
# 128         Texas  2012     D            322715.0             1.0
# 88        Florida  2012     R            465449.0             0.0
# 191          Ohio  2004     R            195476.0             1.0
# 157       Florida  2004     D            483167.0             0.0
# 163      Illinois  2004     D            587063.0             0.0
# 156       Florida  2004     R            642937.0             1.0
# 15        Florida  2016     D            463796.0             1.0
# 283    California  2010     R           1018613.0             0.0
# 186      New York  2004     D                 0.0             0.0
# 116      New York  2012     D                 0.0             1.0
# 127         Texas  2012     R            778917.0             0.0
# 87        Florida  2012     D            185629.0             1.0
# 151    California  2004     R           1251225.0             1.0
# 9      California  2016     D           1810611.0             1.0
# 82     California  2012     R           1293553.0             0.0
# 54       New York  2016     D                 0.0             1.0
# 14        Florida  2016     R            400662.0             0.0
# 214    California  2006     D            326481.0             0.0
# 282    California  2010     D            462015.0             1.0
# 208    Washington  2004     D             60017.0             0.0
# 150    California  2004     D                 0.0             0.0
# 8      California  2016     D           1810611.0             1.0
# 81     California  2012     D            350114.0             1.0
#
# [369 rows x 10 columns]

# %%
#Looks like there are some rogue additional states...
len(hm_model_ready['STATE'].value_counts())
# Out:
# 51

# %%
hm_model_ready['STATE'].unique()

##Virgin Islands not in state list
##Missouri counted twice due to space error
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois',
#        'Indiana', 'Iowa', 'Kentucky', 'Maryland', 'Missouri', 'Nevada',
#        'New Hampshire', 'New York', 'North Carolina', 'North Dakota',
#        'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'South Carolina',
#        'South Dakota', 'Utah', 'Vermont', 'Washington', 'Wisconsin',
#        'Connecticut', 'Delaware', 'Maine', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri ', 'Montana', 'Nebraska',
#        'New Jersey', 'New Mexico', 'Rhode Island', 'Tennessee', 'Texas',
#        'Virginia', 'West Virginia', 'Wyoming', 'Kansas', 'Louisiana'],
#       dtype=object)

# %%
#Dropping VI
hm_model_ready2 = hm_model_ready[~hm_model_ready['STATE'].isin(['Virgin Islands'])]

# %%
#Removing spaces

hm_model_ready2 = hm_model_ready2.replace(to_replace = 'Missouri ',value='Missouri')

# %%
len(hm_model_ready2['STATE'].unique())
# Out:
# 50

# %%
hm_model_ready2['(I)'].value_counts()
# Out:
# 0.0    226
# 1.0    143
# Name: (I), dtype: int64

# %%
hm_model_ready2.groupby(['STATE']).sum().sort_values(['GENERAL VOTES'])
# Out:
#                 GENERAL VOTES  Total Party Votes  Candidate Count  (I)  \
# STATE
# Wyoming              582045.0           311266.0             17.0  3.0
# North Dakota         771729.0           350801.0              6.0  1.0
# Alaska               880306.0           460223.0             23.0  3.0
# Vermont              970052.0           278217.0             14.0  3.0
# Kansas              1091200.0           438904.0              4.0  1.0
# Rhode Island        1118726.0           339786.0              9.0  3.0
# Delaware            1147959.0           143109.0             12.0  3.0
# Louisiana           1191987.0           207481.0              6.0  1.0
# South Dakota        1211988.0            74498.0             11.0  3.0
# Montana             1212195.0           641718.0             18.0  3.0
# Utah                1349647.0           482393.0              6.0  2.0
# Maine               1426620.0           327124.0             15.0  2.0
# New Mexico          1820674.0           585058.0             11.0  2.0
# Nebraska            1898651.0           913258.0             22.0  1.0
# Idaho               2006242.0           622873.0             11.0  4.0
# West Virginia       2043555.0           928403.0             30.0  2.0
# Hawaii              2268968.0          1509002.0             46.0  5.0
# New Hampshire       2291971.0           639043.0             29.0  3.0
# Connecticut         2346737.0           445795.0              6.0  0.0
# Mississippi         2432412.0           882052.0             18.0  3.0
# Minnesota           2553854.0           467713.0             11.0  0.0
# Arkansas            3654362.0          1193537.0             21.0  4.0
# Nevada              3945697.0          1068742.0             59.0  4.0
# Iowa                5098853.0           803534.0             17.0  3.0
# Oklahoma            5268680.0          2468031.0             48.0  4.0
# Tennessee           5310147.0          2356976.0             28.0  2.0
# Oregon              5380760.0          2401806.0             29.0  3.0
# South Carolina      5599378.0          1496666.0             24.0  2.0
# Alabama             6200437.0          1798797.0             14.0  4.0
# Kentucky            6375028.0          2567429.0             33.0  3.0
# Virginia            7211159.0           412264.0              9.0  2.0
# New Jersey          7348969.0          1194242.0             14.0  3.0
# Massachusetts       7398558.0          1761482.0              7.0  3.0
# Colorado            8255452.0          2484919.0             16.0  3.0
# Arizona             9517555.0          3630935.0             21.0  4.0
# Indiana             9522298.0          3954880.0             14.0  3.0
# Maryland           10636385.0          3902112.0             97.0  3.0
# Michigan           11209222.0          3491743.0             10.0  2.0
# Missouri           11821384.0          4736487.0             40.0  4.0
# Georgia            11872743.0          4008568.0             31.0  2.0
# Wisconsin          12937386.0          3410435.0             20.0  4.0
# North Carolina     13351548.0          4120008.0             33.0  3.0
# Texas              16310973.0          4856648.0             30.0  2.0
# Washington         19143531.0          7249939.0             49.0  6.0
# Illinois           20471328.0          9597572.0             45.0  2.0
# New York           22380050.0          1106098.0             12.0  4.0
# Ohio               23430330.0          8895689.0             23.0  4.0
# Pennsylvania       24661839.0          9203121.0             23.0  5.0
# Florida            32657416.0         10024846.0             39.0  3.0
# California         53836971.0         27923790.0             57.0  4.0
#
#                 Primary Winner  Primary Loser Vote  Party In House
# STATE
# Wyoming               270989.0             40277.0             3.0
# North Dakota          316588.0             34213.0             2.0
# Alaska                318109.0            142114.0             4.0
# Vermont               252712.0             25505.0             4.0
# Kansas                347891.0             91013.0             1.0
# Rhode Island          294531.0             45255.0             3.0
# Delaware               98441.0             44668.0             4.0
# Louisiana             163034.0             44447.0             1.0
# South Dakota           41377.0             33121.0             3.0
# Montana               489773.0            151945.0             3.0
# Utah                  287799.0            194594.0             1.0
# Maine                 226592.0            100532.0             3.0
# New Mexico            446921.0            138137.0             3.0
# Nebraska              515125.0            398133.0             3.0
# Idaho                 546179.0             76694.0             4.0
# West Virginia         745611.0            182792.0             4.0
# Hawaii               1050023.0            458979.0             6.0
# New Hampshire         465722.0            173321.0             4.0
# Connecticut           383953.0             61842.0             1.0
# Mississippi           571554.0            310498.0             3.0
# Minnesota             340075.0            127638.0             1.0
# Arkansas              787919.0            405618.0             4.0
# Nevada                725151.0            343591.0             5.0
# Iowa                  668592.0            134942.0             4.0
# Oklahoma             1413458.0           1054573.0             5.0
# Tennessee            1422673.0            934303.0             3.0
# Oregon               1634359.0            767447.0             3.0
# South Carolina        852497.0            644169.0             5.0
# Alabama              1225874.0            572923.0             3.0
# Kentucky             1606478.0            960951.0             4.0
# Virginia              251204.0            161060.0             3.0
# New Jersey            970273.0            223969.0             3.0
# Massachusetts        1727220.0             34262.0             3.0
# Colorado             1717676.0            767243.0             4.0
# Arizona              2734761.0            896174.0             5.0
# Indiana              3036022.0            918858.0             4.0
# Maryland             2332112.0           1570000.0             5.0
# Michigan             2920625.0            571118.0             3.0
# Missouri             3548442.0           1188045.0             5.0
# Georgia              2506786.0           1501782.0             4.0
# Wisconsin            2602450.0            807985.0             5.0
# North Carolina       2591977.0           1528031.0             4.0
# Texas                2666615.0           2190033.0             3.0
# Washington           6285504.0            964435.0             5.0
# Illinois             5439749.0           4157823.0             5.0
# New York              831793.0            274305.0             4.0
# Ohio                 6698730.0           2196959.0             5.0
# Pennsylvania         6435961.0           2767160.0             5.0
# Florida              6312910.0           3711936.0             5.0
# California          19600567.0           8323223.0             6.0

# %% [markdown]
# **Seeing if we throw out the rest of the unopposed if our score gets better...**
# It doesn't!

# %%
# moreopp = hm_model_ready2[hm_model_ready2['Primary Loser Vote'] == 0]

# %%
# #Dropping Unnopposed to see if it makes it better...
# hm_model_ready2 = hm_model_ready2[~hm_model_ready['Primary Loser Vote'].isin([0])]

# %%
# hm_model_ready2.loc[hm_model_ready2['Primary Loser Vote' == 0.0, ['Primary Winner']] = 0]
# hm_model_ready2[hm_model_ready2['Primary Loser Vote']==0.0]
hm_model_ready2['Primary Winner'][hm_model_ready2['Primary Loser Vote'] == 0] = 0
# Out:
# /Users/vicky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
hm_model_ready2[hm_model_ready2 ['Primary Winner'] ==0]
# Out:
#      GENERAL VOTES  Total Party Votes  Candidate Count  (I)  Primary Winner  \
# 5        1031245.0           333586.0              1.0  0.0             0.0
# 7         400602.0                0.0              1.0  0.0             0.0
# 10       1370710.0           262344.0              1.0  1.0             0.0
# 20        449017.0           119633.0              1.0  1.0             0.0
# 21        188249.0            26471.0              1.0  0.0             0.0
# 25       1158947.0           516183.0              1.0  0.0             0.0
# 26        926007.0            90089.0              1.0  1.0             0.0
# 52        354649.0            70374.0              1.0  0.0             0.0
# 54       4784218.0                0.0              1.0  1.0             0.0
# 55       1723920.0                0.0              1.0  0.0             0.0
# 58        268788.0           103677.0              1.0  1.0             0.0
# 61        980892.0                0.0              1.0  1.0             0.0
# 62        355911.0                0.0              1.0  0.0             0.0
# 65       2951702.0          1342941.0              1.0  1.0             0.0
# 67       1241609.0                0.0              1.0  1.0             0.0
# 68        704540.0                0.0              1.0  0.0             0.0
# 69        265516.0                0.0              1.0  1.0             0.0
# 70        104140.0                0.0              1.0  0.0             0.0
# 74        103637.0            37782.0              1.0  0.0             0.0
# 77       1479471.0           248754.0              1.0  1.0             0.0
# 80       1036542.0           289881.0              1.0  0.0             0.0
# 83        792983.0            94424.0              1.0  0.0             0.0
# 84        604569.0            82646.0              1.0  0.0             0.0
# 86        115700.0                0.0              1.0  0.0             0.0
# 91       1281181.0           207715.0              1.0  0.0             0.0
# 97       1696346.0           308979.0              1.0  0.0             0.0
# 98       1458048.0           133860.0              1.0  1.0             0.0
# 99       2735826.0           555719.0              1.0  1.0             0.0
# 104      1494125.0           289481.0              1.0  1.0             0.0
# 106       236123.0            88720.0              1.0  1.0             0.0
# ..             ...                ...              ...  ...             ...
# 292      1489904.0           558298.0              1.0  1.0             0.0
# 304       718215.0           197194.0              1.0  1.0             0.0
# 317       167545.0            49845.0              1.0  0.0             0.0
# 320       181689.0            65075.0              1.0  0.0             0.0
# 321      2168742.0           667369.0              1.0  0.0             0.0
# 331       227947.0                0.0              1.0  1.0             0.0
# 334       151281.0            64515.0              1.0  1.0             0.0
# 335        72699.0            22750.0              1.0  0.0             0.0
# 341      1020958.0           223688.0              1.0  1.0             0.0
# 342       795606.0                0.0              1.0  1.0             0.0
# 345       478819.0                0.0              1.0  0.0             0.0
# 346       334174.0                0.0              1.0  1.0             0.0
# 347       983891.0           338324.0              1.0  0.0             0.0
# 348       944203.0           213746.0              1.0  1.0             0.0
# 349       130655.0                0.0              1.0  1.0             0.0
# 357      1929637.0           429041.0              1.0  1.0             0.0
# 360       494370.0            62600.0              1.0  0.0             0.0
# 371       413495.0            53416.0              1.0  1.0             0.0
# 372       190244.0            47909.0              1.0  0.0             0.0
# 373      1289944.0           402433.0              1.0  1.0             0.0
# 374       791950.0           117216.0              1.0  0.0             0.0
# 375      1704936.0           504102.0              1.0  0.0             0.0
# 376      1290199.0           588084.0              1.0  0.0             0.0
# 384       251184.0            39282.0              1.0  1.0             0.0
# 386      1043866.0           202129.0              1.0  1.0             0.0
# 388       286409.0           113502.0              1.0  1.0             0.0
# 397       223675.0            98816.0              1.0  1.0             0.0
# 398        92684.0            23787.0              1.0  0.0             0.0
# 404        82456.0                0.0              1.0  0.0             0.0
# 409      1073667.0                0.0              1.0  1.0             0.0
#
#               STATE  YEAR PARTY  Primary Loser Vote  Party In House
# 5           Arizona  2016     D                 0.0             1.0
# 7          Arkansas  2016     D                 0.0             1.0
# 10         Colorado  2016     D                 0.0             1.0
# 20            Idaho  2016     R                 0.0             0.0
# 21            Idaho  2016     D                 0.0             1.0
# 25          Indiana  2016     D                 0.0             1.0
# 26             Iowa  2016     R                 0.0             0.0
# 52    New Hampshire  2016     D                 0.0             1.0
# 54         New York  2016     D                 0.0             1.0
# 55         New York  2016     R                 0.0             0.0
# 58     North Dakota  2016     R                 0.0             0.0
# 61         Oklahoma  2016     R                 0.0             0.0
# 62         Oklahoma  2016     D                 0.0             1.0
# 65     Pennsylvania  2016     R                 0.0             0.0
# 67   South Carolina  2016     R                 0.0             0.0
# 68   South Carolina  2016     D                 0.0             1.0
# 69     South Dakota  2016     R                 0.0             0.0
# 70     South Dakota  2016     D                 0.0             1.0
# 74          Vermont  2016     R                 0.0             0.0
# 77        Wisconsin  2016     R                 0.0             0.0
# 80          Arizona  2012     D                 0.0             1.0
# 83      Connecticut  2012     D                 0.0             1.0
# 84      Connecticut  2012     R                 0.0             0.0
# 86         Delaware  2012     R                 0.0             0.0
# 91          Indiana  2012     D                 0.0             1.0
# 97    Massachusetts  2012     D                 0.0             1.0
# 98    Massachusetts  2012     R                 0.0             0.0
# 99         Michigan  2012     D                 0.0             1.0
# 104        Missouri  2012     D                 0.0             1.0
# 106         Montana  2012     D                 0.0             1.0
# ..              ...   ...   ...                 ...             ...
# 292         Georgia  2010     R                 0.0             0.0
# 304            Iowa  2010     R                 0.0             0.0
# 317   New Hampshire  2010     D                 0.0             1.0
# 320    North Dakota  2010     R                 0.0             0.0
# 321            Ohio  2010     R                 0.0             0.0
# 331    South Dakota  2010     R                 0.0             0.0
# 334         Vermont  2010     D                 0.0             1.0
# 335         Vermont  2010     R                 0.0             0.0
# 341       Wisconsin  2010     D                 0.0             1.0
# 342         Alabama  2014     R                 0.0             0.0
# 345        Arkansas  2014     R                 0.0             0.0
# 346        Arkansas  2014     D                 0.0             1.0
# 347        Colorado  2014     R                 0.0             0.0
# 348        Colorado  2014     D                 0.0             1.0
# 349        Delaware  2014     D                 0.0             1.0
# 357        Illinois  2014     D                 0.0             1.0
# 360            Iowa  2014     D                 0.0             1.0
# 371           Maine  2014     R                 0.0             0.0
# 372           Maine  2014     D                 0.0             1.0
# 373   Massachusetts  2014     D                 0.0             1.0
# 374   Massachusetts  2014     R                 0.0             0.0
# 375        Michigan  2014     D                 0.0             1.0
# 376        Michigan  2014     R                 0.0             0.0
# 384   New Hampshire  2014     D                 0.0             1.0
# 386      New Jersey  2014     D                 0.0             1.0
# 388      New Mexico  2014     D                 0.0             1.0
# 397    Rhode Island  2014     D                 0.0             1.0
# 398    Rhode Island  2014     R                 0.0             0.0
# 404    South Dakota  2014     D                 0.0             1.0
# 409        Virginia  2014     D                 0.0             1.0
#
# [112 rows x 10 columns]

# %%
hm_model_ready2
# Out:
#      GENERAL VOTES  Total Party Votes  Candidate Count  (I)  Primary Winner  \
# 0        1335104.0           778851.0              5.0  1.0        505586.0
# 1         748709.0           274423.0              2.0  0.0        153897.0
# 2         138149.0            55293.0              4.0  1.0         39545.0
# 3          36200.0            25318.0              2.0  0.0         15228.0
# 4        1359267.0           591155.0              4.0  1.0        302532.0
# 5        1031245.0           333586.0              1.0  0.0             0.0
# 6         661984.0           389834.0              2.0  1.0        298039.0
# 7         400602.0                0.0              1.0  0.0             0.0
# 8        7542759.0          4811300.0              7.0  0.0       3000689.0
# 9        4701417.0          4811300.0              7.0  0.0       3000689.0
# 10       1370710.0           262344.0              1.0  1.0             0.0
# 11       1215318.0           347471.0              5.0  0.0        131125.0
# 14       4835191.0          1430492.0              4.0  1.0       1029830.0
# 15       4122088.0          1129781.0              5.0  0.0        665985.0
# 16       2135806.0           577660.0              3.0  1.0        447661.0
# 17       1599726.0           310053.0              3.0  0.0        166627.0
# 18        306604.0           189059.0              5.0  1.0        162905.0
# 19         92653.0            35865.0              4.0  0.0         26749.0
# 20        449017.0           119633.0              1.0  1.0             0.0
# 21        188249.0            26471.0              1.0  0.0             0.0
# 22       3012940.0          1895143.0              3.0  0.0       1220128.0
# 23       2184692.0          1320190.0              2.0  1.0        931619.0
# 24       1423991.0           985565.0              2.0  0.0        661136.0
# 25       1158947.0           516183.0              1.0  0.0             0.0
# 26        926007.0            90089.0              1.0  1.0             0.0
# 27        549460.0            97121.0              4.0  0.0         46322.0
# 28       1090177.0           199519.0              3.0  1.0        169180.0
# 29        813246.0           409643.0              7.0  0.0        240598.0
# 46       1659907.0           884344.0             10.0  0.0        470320.0
# 47        972557.0           379831.0             14.0  0.0        135337.0
# ..             ...                ...              ...  ...             ...
# 382       347636.0           218879.0              5.0  0.0        108443.0
# 383       170127.0            65970.0              2.0  0.0         44487.0
# 384       251184.0            39282.0              1.0  1.0             0.0
# 385       235347.0           118234.0             10.0  0.0         59147.0
# 386      1043866.0           202129.0              1.0  1.0             0.0
# 387       791297.0           145307.0              4.0  0.0         42728.0
# 388       286409.0           113502.0              1.0  1.0             0.0
# 389       229097.0            65979.0              2.0  0.0         41566.0
# 390      1423259.0           488555.0              8.0  0.0        223174.0
# 391      1377651.0           482369.0              3.0  1.0        372209.0
# 392       558166.0           530633.0             12.0  1.0        231291.0
# 393       234307.0           163003.0              4.0  0.0         71462.0
# 394       557002.0           530633.0             12.0  1.0        231291.0
# 395       237923.0           163003.0              4.0  0.0         71462.0
# 396       538847.0           268416.0              5.0  0.0        134627.0
# 397       223675.0            98816.0              1.0  1.0             0.0
# 398        92684.0            23787.0              1.0  0.0             0.0
# 400       456726.0           225667.0              5.0  0.0         87552.0
# 402       459583.0           225667.0              5.0  0.0         87552.0
# 403       140741.0            74498.0              5.0  0.0         41377.0
# 404        82456.0                0.0              1.0  0.0             0.0
# 405       850087.0           664673.0              6.0  1.0        331705.0
# 406       437848.0           240949.0              4.0  0.0         87829.0
# 407      2861531.0          1314556.0              8.0  1.0        781259.0
# 408      1597387.0           510009.0              5.0  0.0        239914.0
# 409      1073667.0                0.0              1.0  1.0             0.0
# 411       281820.0            85322.0              3.0  0.0         74655.0
# 412       156360.0           134188.0              3.0  0.0        104598.0
# 413       121554.0            94942.0              5.0  1.0         77965.0
# 414        29377.0            14870.0              4.0  0.0          7200.0
#
#               STATE  YEAR PARTY  Primary Loser Vote  Party In House
# 0           Alabama  2016     R            273265.0             0.0
# 1           Alabama  2016     D            120526.0             1.0
# 2            Alaska  2016     R             15748.0             0.0
# 3            Alaska  2016     D             10090.0             1.0
# 4           Arizona  2016     R            288623.0             0.0
# 5           Arizona  2016     D                 0.0             1.0
# 6          Arkansas  2016     R             91795.0             0.0
# 7          Arkansas  2016     D                 0.0             1.0
# 8        California  2016     D           1810611.0             1.0
# 9        California  2016     D           1810611.0             1.0
# 10         Colorado  2016     D                 0.0             1.0
# 11         Colorado  2016     R            216346.0             0.0
# 14          Florida  2016     R            400662.0             0.0
# 15          Florida  2016     D            463796.0             1.0
# 16          Georgia  2016     R            129999.0             0.0
# 17          Georgia  2016     D            143426.0             1.0
# 18           Hawaii  2016     D             26154.0             1.0
# 19           Hawaii  2016     R              9116.0             0.0
# 20            Idaho  2016     R                 0.0             0.0
# 21            Idaho  2016     D                 0.0             1.0
# 22         Illinois  2016     D            675015.0             1.0
# 23         Illinois  2016     R            388571.0             0.0
# 24          Indiana  2016     R            324429.0             0.0
# 25          Indiana  2016     D                 0.0             1.0
# 26             Iowa  2016     R                 0.0             0.0
# 27             Iowa  2016     D             50799.0             1.0
# 28         Kentucky  2016     R             30339.0             0.0
# 29         Kentucky  2016     D            169045.0             1.0
# 46         Maryland  2016     D            414024.0             1.0
# 47         Maryland  2016     R            244494.0             0.0
# ..              ...   ...   ...                 ...             ...
# 382        Nebraska  2014     R            110436.0             0.0
# 383        Nebraska  2014     D             21483.0             1.0
# 384   New Hampshire  2014     D                 0.0             1.0
# 385   New Hampshire  2014     R             59087.0             0.0
# 386      New Jersey  2014     D                 0.0             1.0
# 387      New Jersey  2014     R            102579.0             0.0
# 388      New Mexico  2014     D                 0.0             1.0
# 389      New Mexico  2014     R             24413.0             0.0
# 390  North Carolina  2014     R            265381.0             0.0
# 391  North Carolina  2014     D            110160.0             1.0
# 392        Oklahoma  2014     R            299342.0             0.0
# 393        Oklahoma  2014     D             91541.0             1.0
# 394        Oklahoma  2014     R            299342.0             0.0
# 395        Oklahoma  2014     D             91541.0             1.0
# 396          Oregon  2014     R            133789.0             0.0
# 397    Rhode Island  2014     D                 0.0             1.0
# 398    Rhode Island  2014     R                 0.0             0.0
# 400  South Carolina  2014     D            138115.0             1.0
# 402  South Carolina  2014     D            138115.0             1.0
# 403    South Dakota  2014     R             33121.0             0.0
# 404    South Dakota  2014     D                 0.0             1.0
# 405       Tennessee  2014     R            332968.0             0.0
# 406       Tennessee  2014     D            153120.0             1.0
# 407           Texas  2014     R            533297.0             0.0
# 408           Texas  2014     D            270095.0             1.0
# 409        Virginia  2014     D                 0.0             1.0
# 411   West Virginia  2014     R             10667.0             0.0
# 412   West Virginia  2014     D             29590.0             1.0
# 413         Wyoming  2014     R             16977.0             0.0
# 414         Wyoming  2014     D              7670.0             1.0
#
# [369 rows x 10 columns]

# %% [markdown]
# #### Catboost (With All Inputs Included) ***THIS ONE PREVAILS!! :)

# %% [markdown]
# ** Splitting x&y **

# %%
hm_model_ready2
# Out:
#      GENERAL VOTES  Total Party Votes  Candidate Count  (I)  Primary Winner  \
# 0        1335104.0           778851.0              5.0  1.0        505586.0
# 1         748709.0           274423.0              2.0  0.0        153897.0
# 2         138149.0            55293.0              4.0  1.0         39545.0
# 3          36200.0            25318.0              2.0  0.0         15228.0
# 4        1359267.0           591155.0              4.0  1.0        302532.0
# 5        1031245.0           333586.0              1.0  0.0        333586.0
# 6         661984.0           389834.0              2.0  1.0        298039.0
# 7         400602.0                0.0              1.0  0.0             0.0
# 8        7542759.0          4811300.0              7.0  0.0       3000689.0
# 9        4701417.0          4811300.0              7.0  0.0       3000689.0
# 10       1370710.0           262344.0              1.0  1.0        262344.0
# 11       1215318.0           347471.0              5.0  0.0        131125.0
# 14       4835191.0          1430492.0              4.0  1.0       1029830.0
# 15       4122088.0          1129781.0              5.0  0.0        665985.0
# 16       2135806.0           577660.0              3.0  1.0        447661.0
# 17       1599726.0           310053.0              3.0  0.0        166627.0
# 18        306604.0           189059.0              5.0  1.0        162905.0
# 19         92653.0            35865.0              4.0  0.0         26749.0
# 20        449017.0           119633.0              1.0  1.0        119633.0
# 21        188249.0            26471.0              1.0  0.0         26471.0
# 22       3012940.0          1895143.0              3.0  0.0       1220128.0
# 23       2184692.0          1320190.0              2.0  1.0        931619.0
# 24       1423991.0           985565.0              2.0  0.0        661136.0
# 25       1158947.0           516183.0              1.0  0.0        516183.0
# 26        926007.0            90089.0              1.0  1.0         90089.0
# 27        549460.0            97121.0              4.0  0.0         46322.0
# 28       1090177.0           199519.0              3.0  1.0        169180.0
# 29        813246.0           409643.0              7.0  0.0        240598.0
# 46       1659907.0           884344.0             10.0  0.0        470320.0
# 47        972557.0           379831.0             14.0  0.0        135337.0
# ..             ...                ...              ...  ...             ...
# 382       347636.0           218879.0              5.0  0.0        108443.0
# 383       170127.0            65970.0              2.0  0.0         44487.0
# 384       251184.0            39282.0              1.0  1.0         39282.0
# 385       235347.0           118234.0             10.0  0.0         59147.0
# 386      1043866.0           202129.0              1.0  1.0        202129.0
# 387       791297.0           145307.0              4.0  0.0         42728.0
# 388       286409.0           113502.0              1.0  1.0        113502.0
# 389       229097.0            65979.0              2.0  0.0         41566.0
# 390      1423259.0           488555.0              8.0  0.0        223174.0
# 391      1377651.0           482369.0              3.0  1.0        372209.0
# 392       558166.0           530633.0             12.0  1.0        231291.0
# 393       234307.0           163003.0              4.0  0.0         71462.0
# 394       557002.0           530633.0             12.0  1.0        231291.0
# 395       237923.0           163003.0              4.0  0.0         71462.0
# 396       538847.0           268416.0              5.0  0.0        134627.0
# 397       223675.0            98816.0              1.0  1.0         98816.0
# 398        92684.0            23787.0              1.0  0.0         23787.0
# 400       456726.0           225667.0              5.0  0.0         87552.0
# 402       459583.0           225667.0              5.0  0.0         87552.0
# 403       140741.0            74498.0              5.0  0.0         41377.0
# 404        82456.0                0.0              1.0  0.0             0.0
# 405       850087.0           664673.0              6.0  1.0        331705.0
# 406       437848.0           240949.0              4.0  0.0         87829.0
# 407      2861531.0          1314556.0              8.0  1.0        781259.0
# 408      1597387.0           510009.0              5.0  0.0        239914.0
# 409      1073667.0                0.0              1.0  1.0             0.0
# 411       281820.0            85322.0              3.0  0.0         74655.0
# 412       156360.0           134188.0              3.0  0.0        104598.0
# 413       121554.0            94942.0              5.0  1.0         77965.0
# 414        29377.0            14870.0              4.0  0.0          7200.0
#
#               STATE  YEAR PARTY  Primary Loser Vote  Party In House
# 0           Alabama  2016     R            273265.0             0.0
# 1           Alabama  2016     D            120526.0             1.0
# 2            Alaska  2016     R             15748.0             0.0
# 3            Alaska  2016     D             10090.0             1.0
# 4           Arizona  2016     R            288623.0             0.0
# 5           Arizona  2016     D                 0.0             1.0
# 6          Arkansas  2016     R             91795.0             0.0
# 7          Arkansas  2016     D                 0.0             1.0
# 8        California  2016     D           1810611.0             1.0
# 9        California  2016     D           1810611.0             1.0
# 10         Colorado  2016     D                 0.0             1.0
# 11         Colorado  2016     R            216346.0             0.0
# 14          Florida  2016     R            400662.0             0.0
# 15          Florida  2016     D            463796.0             1.0
# 16          Georgia  2016     R            129999.0             0.0
# 17          Georgia  2016     D            143426.0             1.0
# 18           Hawaii  2016     D             26154.0             1.0
# 19           Hawaii  2016     R              9116.0             0.0
# 20            Idaho  2016     R                 0.0             0.0
# 21            Idaho  2016     D                 0.0             1.0
# 22         Illinois  2016     D            675015.0             1.0
# 23         Illinois  2016     R            388571.0             0.0
# 24          Indiana  2016     R            324429.0             0.0
# 25          Indiana  2016     D                 0.0             1.0
# 26             Iowa  2016     R                 0.0             0.0
# 27             Iowa  2016     D             50799.0             1.0
# 28         Kentucky  2016     R             30339.0             0.0
# 29         Kentucky  2016     D            169045.0             1.0
# 46         Maryland  2016     D            414024.0             1.0
# 47         Maryland  2016     R            244494.0             0.0
# ..              ...   ...   ...                 ...             ...
# 382        Nebraska  2014     R            110436.0             0.0
# 383        Nebraska  2014     D             21483.0             1.0
# 384   New Hampshire  2014     D                 0.0             1.0
# 385   New Hampshire  2014     R             59087.0             0.0
# 386      New Jersey  2014     D                 0.0             1.0
# 387      New Jersey  2014     R            102579.0             0.0
# 388      New Mexico  2014     D                 0.0             1.0
# 389      New Mexico  2014     R             24413.0             0.0
# 390  North Carolina  2014     R            265381.0             0.0
# 391  North Carolina  2014     D            110160.0             1.0
# 392        Oklahoma  2014     R            299342.0             0.0
# 393        Oklahoma  2014     D             91541.0             1.0
# 394        Oklahoma  2014     R            299342.0             0.0
# 395        Oklahoma  2014     D             91541.0             1.0
# 396          Oregon  2014     R            133789.0             0.0
# 397    Rhode Island  2014     D                 0.0             1.0
# 398    Rhode Island  2014     R                 0.0             0.0
# 400  South Carolina  2014     D            138115.0             1.0
# 402  South Carolina  2014     D            138115.0             1.0
# 403    South Dakota  2014     R             33121.0             0.0
# 404    South Dakota  2014     D                 0.0             1.0
# 405       Tennessee  2014     R            332968.0             0.0
# 406       Tennessee  2014     D            153120.0             1.0
# 407           Texas  2014     R            533297.0             0.0
# 408           Texas  2014     D            270095.0             1.0
# 409        Virginia  2014     D                 0.0             1.0
# 411   West Virginia  2014     R             10667.0             0.0
# 412   West Virginia  2014     D             29590.0             1.0
# 413         Wyoming  2014     R             16977.0             0.0
# 414         Wyoming  2014     D              7670.0             1.0
#
# [369 rows x 10 columns]

# %%
ycat = hm_model_ready2['GENERAL VOTES'] 
Xcat = hm_model_ready2.drop('GENERAL VOTES',axis = 1)

# %% [markdown]
# ** Splitting for T-T-S **

# %%
X_trainc, X_testc, y_trainc, y_testc = train_test_split(Xcat, ycat, test_size=0.3, random_state=42)

# %%
X_trainc.columns
# Out:
# Index(['Total Party Votes', 'Candidate Count', '(I)', 'Primary Winner',
#        'STATE', 'YEAR', 'PARTY', 'Primary Loser Vote', 'Party In House'],
#       dtype='object')

# %% [markdown]
# ** Running Catboost **

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_trainc.dtypes != np.float)[0]
train_pool = Pool(X_trainc, y_trainc, cat_features=categorical_features_indices)
test_pool = Pool(X_testc, y_testc, cat_features=categorical_features_indices)


Catset=CatBoostRegressor(learning_rate = 0.01, depth = 10)
Cat = Catset.fit(X_trainc, y_trainc, cat_features=categorical_features_indices, plot=True, use_best_model=True)
# Out:
# You should provide test set for use best model. use_best_model parameter swiched to false value.
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# 0:	learn: 1706152.4622453	total: 58.1ms	remaining: 58.1s
# 1:	learn: 1696840.2281737	total: 93.3ms	remaining: 46.6s
# 2:	learn: 1687231.6790903	total: 98.8ms	remaining: 32.8s
# 3:	learn: 1677198.4104707	total: 113ms	remaining: 28.1s
# 4:	learn: 1668084.9052241	total: 118ms	remaining: 23.6s
# 5:	learn: 1657284.9367231	total: 121ms	remaining: 20s
# 6:	learn: 1647916.1855094	total: 123ms	remaining: 17.4s
# 7:	learn: 1637702.3177310	total: 125ms	remaining: 15.5s
# 8:	learn: 1629153.2261290	total: 127ms	remaining: 14s
# 9:	learn: 1619290.9284340	total: 129ms	remaining: 12.8s
# 10:	learn: 1612566.8367314	total: 131ms	remaining: 11.8s
# 11:	learn: 1602372.3710189	total: 134ms	remaining: 11.1s
# 12:	learn: 1592807.2143642	total: 137ms	remaining: 10.4s
# 13:	learn: 1582970.9409605	total: 139ms	remaining: 9.8s
# 14:	learn: 1574252.1555916	total: 142ms	remaining: 9.29s
# 15:	learn: 1564712.5323285	total: 145ms	remaining: 8.94s
# 16:	learn: 1554737.9231651	total: 148ms	remaining: 8.55s
# 17:	learn: 1545603.7457375	total: 151ms	remaining: 8.25s
# 18:	learn: 1536542.0318101	total: 154ms	remaining: 7.94s
# 19:	learn: 1527297.1699812	total: 157ms	remaining: 7.69s
# 20:	learn: 1518086.8101548	total: 160ms	remaining: 7.47s
# 21:	learn: 1508944.2938242	total: 162ms	remaining: 7.22s
# 22:	learn: 1500256.3337929	total: 166ms	remaining: 7.03s
# 23:	learn: 1491501.5632566	total: 168ms	remaining: 6.82s
# 24:	learn: 1483177.0920166	total: 170ms	remaining: 6.63s
# 25:	learn: 1475019.7981367	total: 173ms	remaining: 6.47s
# 26:	learn: 1467112.7824601	total: 177ms	remaining: 6.39s
# 27:	learn: 1458529.4692154	total: 180ms	remaining: 6.23s
# 28:	learn: 1450272.0388270	total: 185ms	remaining: 6.2s
# 29:	learn: 1442217.1272035	total: 190ms	remaining: 6.13s
# 30:	learn: 1434884.4802741	total: 204ms	remaining: 6.37s
# 31:	learn: 1427326.6660889	total: 208ms	remaining: 6.3s
# 32:	learn: 1418977.3213290	total: 211ms	remaining: 6.19s
# 33:	learn: 1410834.7107142	total: 213ms	remaining: 6.05s
# 34:	learn: 1404413.7448978	total: 216ms	remaining: 5.96s
# 35:	learn: 1396697.0816734	total: 219ms	remaining: 5.85s
# 36:	learn: 1389529.2838850	total: 222ms	remaining: 5.77s
# 37:	learn: 1382534.1432027	total: 224ms	remaining: 5.68s
# 38:	learn: 1375043.4308253	total: 227ms	remaining: 5.58s
# 39:	learn: 1368842.2814285	total: 235ms	remaining: 5.63s
# 40:	learn: 1361552.5298461	total: 238ms	remaining: 5.57s
# 41:	learn: 1354055.7439653	total: 240ms	remaining: 5.48s
# 42:	learn: 1347375.4711413	total: 243ms	remaining: 5.4s
# 43:	learn: 1340738.5278613	total: 245ms	remaining: 5.32s
# 44:	learn: 1333740.3674169	total: 247ms	remaining: 5.24s
# 45:	learn: 1329446.5288633	total: 249ms	remaining: 5.16s
# 46:	learn: 1322741.8655709	total: 253ms	remaining: 5.12s
# 47:	learn: 1316081.3935064	total: 255ms	remaining: 5.06s
# 48:	learn: 1309322.4320423	total: 257ms	remaining: 4.99s
# 49:	learn: 1303596.6940333	total: 260ms	remaining: 4.93s
# 50:	learn: 1297069.1914807	total: 262ms	remaining: 4.88s
# 51:	learn: 1290978.4903359	total: 265ms	remaining: 4.82s
# 52:	learn: 1284658.5879216	total: 267ms	remaining: 4.77s
# 53:	learn: 1278649.1196197	total: 273ms	remaining: 4.78s
# 54:	learn: 1272513.9628406	total: 276ms	remaining: 4.74s
# 55:	learn: 1266250.6609241	total: 278ms	remaining: 4.69s
# 56:	learn: 1260427.2434126	total: 280ms	remaining: 4.64s
# 57:	learn: 1254977.2600258	total: 283ms	remaining: 4.6s
# 58:	learn: 1249454.9611678	total: 287ms	remaining: 4.57s
# 59:	learn: 1242980.1521358	total: 290ms	remaining: 4.55s
# 60:	learn: 1237760.7680546	total: 296ms	remaining: 4.56s
# 61:	learn: 1231942.6525687	total: 299ms	remaining: 4.53s
# 62:	learn: 1226427.4941910	total: 303ms	remaining: 4.51s
# 63:	learn: 1220765.8471124	total: 305ms	remaining: 4.47s
# 64:	learn: 1215700.1773051	total: 308ms	remaining: 4.42s
# 65:	learn: 1209850.9409627	total: 311ms	remaining: 4.4s
# 66:	learn: 1204563.3508198	total: 314ms	remaining: 4.37s
# 67:	learn: 1199562.8657375	total: 316ms	remaining: 4.33s
# 68:	learn: 1194379.3393164	total: 318ms	remaining: 4.29s
# 69:	learn: 1189165.5504473	total: 321ms	remaining: 4.26s
# 70:	learn: 1183979.9259090	total: 323ms	remaining: 4.23s
# 71:	learn: 1178858.0469041	total: 326ms	remaining: 4.2s
# 72:	learn: 1174056.8494979	total: 329ms	remaining: 4.18s
# 73:	learn: 1168854.0717193	total: 335ms	remaining: 4.19s
# 74:	learn: 1163119.8015929	total: 339ms	remaining: 4.18s
# 75:	learn: 1157479.9630596	total: 348ms	remaining: 4.23s
# 76:	learn: 1152976.9376904	total: 350ms	remaining: 4.19s
# 77:	learn: 1148165.5434917	total: 352ms	remaining: 4.16s
# 78:	learn: 1142990.8983623	total: 355ms	remaining: 4.14s
# 79:	learn: 1137246.4235622	total: 357ms	remaining: 4.11s
# 80:	learn: 1132191.7744476	total: 390ms	remaining: 4.43s
# 81:	learn: 1127013.0917900	total: 394ms	remaining: 4.41s
# 82:	learn: 1122349.0749859	total: 398ms	remaining: 4.39s
# 83:	learn: 1117379.2917261	total: 401ms	remaining: 4.37s
# 84:	learn: 1112658.0966868	total: 404ms	remaining: 4.35s
# 85:	learn: 1107665.0866091	total: 411ms	remaining: 4.36s
# 86:	learn: 1103274.7912799	total: 413ms	remaining: 4.33s
# 87:	learn: 1098769.8574510	total: 418ms	remaining: 4.33s
# 88:	learn: 1093427.8161655	total: 423ms	remaining: 4.33s
# 89:	learn: 1089475.2667736	total: 426ms	remaining: 4.31s
# 90:	learn: 1084648.7402525	total: 430ms	remaining: 4.29s
# 91:	learn: 1080209.1175016	total: 435ms	remaining: 4.29s
# 92:	learn: 1075126.8666765	total: 439ms	remaining: 4.28s
# 93:	learn: 1070183.5393546	total: 442ms	remaining: 4.26s
# 94:	learn: 1066091.4141121	total: 449ms	remaining: 4.28s
# 95:	learn: 1061212.3116294	total: 455ms	remaining: 4.28s
# 96:	learn: 1057812.6679240	total: 458ms	remaining: 4.26s
# 97:	learn: 1053301.9358057	total: 462ms	remaining: 4.25s
# 98:	learn: 1048688.6900939	total: 465ms	remaining: 4.23s
# 99:	learn: 1044443.2436060	total: 468ms	remaining: 4.21s
# 100:	learn: 1040921.4152085	total: 472ms	remaining: 4.2s
# 101:	learn: 1036633.4919425	total: 506ms	remaining: 4.45s
# 102:	learn: 1033326.2945725	total: 508ms	remaining: 4.43s
# 103:	learn: 1029421.4309950	total: 514ms	remaining: 4.43s
# 104:	learn: 1025115.3942512	total: 519ms	remaining: 4.43s
# 105:	learn: 1020497.4456422	total: 523ms	remaining: 4.41s
# 106:	learn: 1017089.5703142	total: 526ms	remaining: 4.39s
# 107:	learn: 1012921.6211492	total: 529ms	remaining: 4.37s
# 108:	learn: 1008757.6703663	total: 532ms	remaining: 4.35s
# 109:	learn: 1005003.7390007	total: 538ms	remaining: 4.35s
# 110:	learn: 1001883.3916056	total: 540ms	remaining: 4.32s
# 111:	learn: 997646.3049693	total: 544ms	remaining: 4.31s
# 112:	learn: 993609.2257628	total: 549ms	remaining: 4.3s
# 113:	learn: 990313.9989874	total: 551ms	remaining: 4.29s
# 114:	learn: 986668.5788339	total: 580ms	remaining: 4.47s
# 115:	learn: 982666.7926358	total: 584ms	remaining: 4.45s
# 116:	learn: 979445.3807366	total: 587ms	remaining: 4.43s
# 117:	learn: 975890.5094954	total: 592ms	remaining: 4.42s
# 118:	learn: 973144.9869186	total: 595ms	remaining: 4.4s
# 119:	learn: 969832.4883617	total: 597ms	remaining: 4.38s
# 120:	learn: 966307.1196293	total: 611ms	remaining: 4.44s
# 121:	learn: 963013.7361304	total: 613ms	remaining: 4.41s
# 122:	learn: 959514.8642430	total: 618ms	remaining: 4.41s
# 123:	learn: 956219.7293634	total: 623ms	remaining: 4.4s
# 124:	learn: 953010.8560306	total: 630ms	remaining: 4.41s
# 125:	learn: 949990.7127107	total: 636ms	remaining: 4.41s
# 126:	learn: 946896.2892673	total: 639ms	remaining: 4.39s
# 127:	learn: 943786.3524002	total: 644ms	remaining: 4.39s
# 128:	learn: 940484.3204244	total: 651ms	remaining: 4.4s
# 129:	learn: 937605.5736665	total: 654ms	remaining: 4.37s
# 130:	learn: 934585.2132828	total: 660ms	remaining: 4.38s
# 131:	learn: 931564.1264843	total: 666ms	remaining: 4.38s
# 132:	learn: 928444.5796285	total: 669ms	remaining: 4.36s
# 133:	learn: 925732.4512830	total: 672ms	remaining: 4.34s
# 134:	learn: 922502.9284533	total: 675ms	remaining: 4.32s
# 135:	learn: 919447.6175507	total: 679ms	remaining: 4.31s
# 136:	learn: 916578.6251463	total: 683ms	remaining: 4.3s
# 137:	learn: 913356.2390496	total: 691ms	remaining: 4.31s
# 138:	learn: 910814.2613165	total: 693ms	remaining: 4.29s
# 139:	learn: 908153.3281236	total: 723ms	remaining: 4.44s
# 140:	learn: 905728.4621720	total: 725ms	remaining: 4.42s
# 141:	learn: 902988.2398655	total: 728ms	remaining: 4.4s
# 142:	learn: 900807.0158288	total: 730ms	remaining: 4.37s
# 143:	learn: 897942.2829955	total: 739ms	remaining: 4.39s
# 144:	learn: 895401.0769785	total: 742ms	remaining: 4.37s
# 145:	learn: 893066.5569377	total: 745ms	remaining: 4.36s
# 146:	learn: 890093.1357013	total: 748ms	remaining: 4.34s
# 147:	learn: 887408.2392084	total: 751ms	remaining: 4.32s
# 148:	learn: 884797.6062209	total: 755ms	remaining: 4.31s
# 149:	learn: 882685.8256144	total: 758ms	remaining: 4.29s
# 150:	learn: 880248.5910760	total: 760ms	remaining: 4.27s
# 151:	learn: 877285.3185114	total: 764ms	remaining: 4.26s
# 152:	learn: 875044.7041220	total: 766ms	remaining: 4.24s
# 153:	learn: 872939.3935942	total: 768ms	remaining: 4.22s
# 154:	learn: 870372.7168569	total: 771ms	remaining: 4.2s
# 155:	learn: 867845.7891633	total: 775ms	remaining: 4.2s
# 156:	learn: 865506.8999856	total: 781ms	remaining: 4.19s
# 157:	learn: 863531.6373927	total: 783ms	remaining: 4.17s
# 158:	learn: 861040.6814778	total: 798ms	remaining: 4.22s
# 159:	learn: 858518.0235718	total: 807ms	remaining: 4.24s
# 160:	learn: 855729.3098607	total: 837ms	remaining: 4.36s
# 161:	learn: 854088.1743914	total: 843ms	remaining: 4.36s
# 162:	learn: 851881.9508774	total: 845ms	remaining: 4.34s
# 163:	learn: 850033.1677629	total: 848ms	remaining: 4.32s
# 164:	learn: 847956.3281416	total: 850ms	remaining: 4.3s
# 165:	learn: 845206.8963503	total: 857ms	remaining: 4.3s
# 166:	learn: 842845.1823039	total: 861ms	remaining: 4.29s
# 167:	learn: 840514.9424773	total: 866ms	remaining: 4.29s
# 168:	learn: 838826.4126294	total: 869ms	remaining: 4.27s
# 169:	learn: 836706.3309473	total: 881ms	remaining: 4.3s
# 170:	learn: 834800.6517400	total: 885ms	remaining: 4.29s
# 171:	learn: 832404.8071277	total: 891ms	remaining: 4.29s
# 172:	learn: 830156.1416630	total: 895ms	remaining: 4.28s
# 173:	learn: 828033.0019285	total: 904ms	remaining: 4.29s
# 174:	learn: 825742.5900259	total: 910ms	remaining: 4.29s
# 175:	learn: 824018.6249418	total: 913ms	remaining: 4.28s
# 176:	learn: 821528.8055458	total: 916ms	remaining: 4.26s
# 177:	learn: 819866.0230669	total: 932ms	remaining: 4.3s
# 178:	learn: 817493.3578415	total: 935ms	remaining: 4.29s
# 179:	learn: 815602.0476695	total: 940ms	remaining: 4.28s
# 180:	learn: 813836.0887777	total: 943ms	remaining: 4.27s
# 181:	learn: 811452.8726674	total: 947ms	remaining: 4.26s
# 182:	learn: 809476.2697456	total: 951ms	remaining: 4.25s
# 183:	learn: 807231.1762155	total: 958ms	remaining: 4.25s
# 184:	learn: 805235.1413709	total: 962ms	remaining: 4.24s
# 185:	learn: 803662.2475929	total: 965ms	remaining: 4.22s
# 186:	learn: 802313.7958358	total: 967ms	remaining: 4.21s
# 187:	learn: 800185.6066103	total: 970ms	remaining: 4.19s
# 188:	learn: 798588.3452257	total: 973ms	remaining: 4.18s
# MetricVisualizer(data={'catboost_info': {'path': 'catboost_info', 'name': 'catboost_info', 'content': {'passed_iterations': 188, 'total_iterations': 1000, 'data': {'iterations': [{'learn': [1706152.462], 'iteration': 0, 'passed_time': 0.05812973756, 'remaining_time': 58.07160783}, {'learn': [1696840.228], 'iteration': 1, 'passed_time': 0.09329306689, 'remaining_time': 46.55324038}, {'learn': [1687231.679], 'iteration': 2, 'passed_time': 0.09882827015, 'remaining_time': 32.84392845}, {'learn': [1677198.41], 'iteration': 3, 'passed_time': 0.1126566905, 'remaining_time': 28.05151595}, {'learn': [1668084.905], 'iteration': 4, 'passed_time': 0.118346665, 'remaining_time': 23.55098633}, {'learn': [1657284.937], 'iteration': 5, 'passed_time': 0.120637388, 'remaining_time': 19.98559395}, {'learn': [1647916.186], 'iteration': 6, 'passed_time': 0.1228393366, 'remaining_time': 17.42563733}, {'learn': [1637702.318], 'iteration': 7, 'passed_time': 0.1252130254, 'remaining_time': 15.52641515}, {'learn': [1629153.226], 'iteration': 8, 'passed_time': 0.1272323731, 'remaining_time': 14.00969797}, {'learn': [1619290.928], 'iteration': 9, 'passed_time': 0.1291615263, 'remaining_time': 12.7869911}, {'learn': [1612566.837], 'iteration': 10, 'passed_time': 0.1311198841, 'remaining_time': 11.78886958}, {'learn': [1602372.371], 'iteration': 11, 'passed_time': 0.134496145, 'remaining_time': 11.07351594}, {'learn': [1592807.214], 'iteration': 12, 'passed_time': 0.1367663983, 'remaining_time': 10.38372578}, {'learn': [1582970.941], 'iteration': 13, 'passed_time': 0.1391478533, 'remaining_time': 9.799984523}, {'learn': [1574252.156], 'iteration': 14, 'passed_time': 0.1415130146, 'remaining_time': 9.292687956}, {'learn': [1564712.532], 'iteration': 15, 'passed_time': 0.1453744545, 'remaining_time': 8.940528949}, {'learn': [1554737.923], 'iteration': 16, 'passed_time': 0.1478310802, 'remaining_time': 8.548114816}, {'learn': [1545603.746], 'iteration': 17, 'passed_time': 0.1512630647, 'remaining_time': 8.252240531}, {'learn': [1536542.032], 'iteration': 18, 'passed_time': 0.1537135553, 'remaining_time': 7.936473566}, {'learn': [1527297.17], 'iteration': 19, 'passed_time': 0.1568974275, 'remaining_time': 7.687973948}, {'learn': [1518086.81], 'iteration': 20, 'passed_time': 0.1603168291, 'remaining_time': 7.473817892}, {'learn': [1508944.294], 'iteration': 21, 'passed_time': 0.1623269055, 'remaining_time': 7.2161688}, {'learn': [1500256.334], 'iteration': 22, 'passed_time': 0.1655304888, 'remaining_time': 7.031447284}, {'learn': [1491501.563], 'iteration': 23, 'passed_time': 0.1676638566, 'remaining_time': 6.818330168}, {'learn': [1483177.092], 'iteration': 24, 'passed_time': 0.1700461735, 'remaining_time': 6.631800766}, {'learn': [1475019.798], 'iteration': 25, 'passed_time': 0.1727697945, 'remaining_time': 6.472222303}, {'learn': [1467112.782], 'iteration': 26, 'passed_time': 0.1772858655, 'remaining_time': 6.388857302}, {'learn': [1458529.469], 'iteration': 27, 'passed_time': 0.1795217608, 'remaining_time': 6.231969695}, {'learn': [1450272.039], 'iteration': 28, 'passed_time': 0.185194741, 'remaining_time': 6.200830812}, {'learn': [1442217.127], 'iteration': 29, 'passed_time': 0.189562676, 'remaining_time': 6.129193191}, {'learn': [1434884.48], 'iteration': 30, 'passed_time': 0.2037173968, 'remaining_time': 6.367811532}, {'learn': [1427326.666], 'iteration': 31, 'passed_time': 0.2083768201, 'remaining_time': 6.303398807}, {'learn': [1418977.321], 'iteration': 32, 'passed_time': 0.2111688908, 'remaining_time': 6.187888407}, {'learn': [1410834.711], 'iteration': 33, 'passed_time': 0.2131215232, 'remaining_time': 6.05515857}, {'learn': [1404413.745], 'iteration': 34, 'passed_time': 0.2163679338, 'remaining_time': 5.965573033}, {'learn': [1396697.082], 'iteration': 35, 'passed_time': 0.2185861388, 'remaining_time': 5.853251049}, {'learn': [1389529.284], 'iteration': 36, 'passed_time': 0.2215645472, 'remaining_time': 5.766666459}, {'learn': [1382534.143], 'iter ...
# 189:	learn: 796471.9762471	total: 983ms	remaining: 4.19s
# 190:	learn: 794325.1129842	total: 998ms	remaining: 4.23s
# 191:	learn: 792203.7739979	total: 1s	remaining: 4.22s
# 192:	learn: 790888.5618009	total: 1s	remaining: 4.2s
# 193:	learn: 788740.1406827	total: 1.01s	remaining: 4.18s
# 194:	learn: 786547.1619139	total: 1.01s	remaining: 4.17s
# 195:	learn: 784501.2933198	total: 1.01s	remaining: 4.16s
# 196:	learn: 782298.0262366	total: 1.03s	remaining: 4.21s
# 197:	learn: 780936.5925094	total: 1.04s	remaining: 4.21s
# 198:	learn: 779370.2477955	total: 1.04s	remaining: 4.2s
# 199:	learn: 777508.5008431	total: 1.05s	remaining: 4.19s
# 200:	learn: 775500.8409715	total: 1.05s	remaining: 4.18s
# 201:	learn: 773548.1058727	total: 1.06s	remaining: 4.19s
# 202:	learn: 771728.7566165	total: 1.06s	remaining: 4.18s
# 203:	learn: 769824.5283224	total: 1.08s	remaining: 4.21s
# 204:	learn: 768597.9190236	total: 1.08s	remaining: 4.2s
# 205:	learn: 766943.4693288	total: 1.08s	remaining: 4.18s
# 206:	learn: 765103.8776078	total: 1.09s	remaining: 4.17s
# 207:	learn: 763422.2294234	total: 1.09s	remaining: 4.16s
# 208:	learn: 761536.2009965	total: 1.1s	remaining: 4.15s
# 209:	learn: 759803.4973990	total: 1.13s	remaining: 4.24s
# 210:	learn: 757929.9328339	total: 1.13s	remaining: 4.22s
# 211:	learn: 756270.9771909	total: 1.14s	remaining: 4.22s
# 212:	learn: 754572.6634373	total: 1.17s	remaining: 4.3s
# 213:	learn: 753047.5711959	total: 1.17s	remaining: 4.29s
# 214:	learn: 751762.4196035	total: 1.18s	remaining: 4.3s
# 215:	learn: 749891.7001379	total: 1.19s	remaining: 4.31s
# 216:	learn: 748318.1139707	total: 1.2s	remaining: 4.32s
# 217:	learn: 746695.8599889	total: 1.23s	remaining: 4.4s
# 218:	learn: 744799.3408081	total: 1.23s	remaining: 4.38s
# 219:	learn: 743420.3188621	total: 1.23s	remaining: 4.37s
# 220:	learn: 741817.1241143	total: 1.23s	remaining: 4.35s
# 221:	learn: 740061.5277037	total: 1.24s	remaining: 4.34s
# 222:	learn: 738645.6585261	total: 1.25s	remaining: 4.35s
# 223:	learn: 737466.6804218	total: 1.25s	remaining: 4.33s
# 224:	learn: 736067.7828312	total: 1.28s	remaining: 4.42s
# 225:	learn: 734617.1041623	total: 1.29s	remaining: 4.41s
# 226:	learn: 733764.0021307	total: 1.29s	remaining: 4.4s
# 227:	learn: 732013.4530242	total: 1.3s	remaining: 4.4s
# 228:	learn: 730269.9301633	total: 1.31s	remaining: 4.41s
# 229:	learn: 728646.2857999	total: 1.31s	remaining: 4.4s
# 230:	learn: 727181.6133137	total: 1.34s	remaining: 4.46s
# 231:	learn: 725916.9065168	total: 1.34s	remaining: 4.44s
# 232:	learn: 724273.5488196	total: 1.34s	remaining: 4.42s
# 233:	learn: 723126.9595328	total: 1.34s	remaining: 4.4s
# 234:	learn: 722108.2192458	total: 1.34s	remaining: 4.38s
# 235:	learn: 720951.0018963	total: 1.35s	remaining: 4.36s
# 236:	learn: 719507.7889535	total: 1.35s	remaining: 4.34s
# 237:	learn: 718010.0531684	total: 1.36s	remaining: 4.35s
# 238:	learn: 716008.8761356	total: 1.38s	remaining: 4.4s
# 239:	learn: 714757.1092344	total: 1.39s	remaining: 4.4s
# 240:	learn: 713530.7335581	total: 1.39s	remaining: 4.38s
# 241:	learn: 712223.9450730	total: 1.41s	remaining: 4.4s
# 242:	learn: 711179.5903274	total: 1.41s	remaining: 4.41s
# 243:	learn: 709980.9447569	total: 1.43s	remaining: 4.44s
# 244:	learn: 708735.6026253	total: 1.44s	remaining: 4.45s
# 245:	learn: 707886.9347247	total: 1.44s	remaining: 4.43s
# 246:	learn: 706801.0995863	total: 1.45s	remaining: 4.42s
# 247:	learn: 705247.6244144	total: 1.45s	remaining: 4.41s
# 248:	learn: 704240.5669853	total: 1.46s	remaining: 4.39s
# 249:	learn: 702764.1127870	total: 1.47s	remaining: 4.4s
# 250:	learn: 701766.1139178	total: 1.47s	remaining: 4.38s
# 251:	learn: 699878.7333050	total: 1.48s	remaining: 4.38s
# 252:	learn: 699024.7575264	total: 1.48s	remaining: 4.36s
# 253:	learn: 698543.2881523	total: 1.48s	remaining: 4.35s
# 254:	learn: 697445.5477288	total: 1.48s	remaining: 4.33s
# 255:	learn: 696026.4103646	total: 1.49s	remaining: 4.32s
# 256:	learn: 694824.0611345	total: 1.49s	remaining: 4.3s
# 257:	learn: 694148.5492104	total: 1.49s	remaining: 4.29s
# 258:	learn: 692915.4773051	total: 1.49s	remaining: 4.28s
# 259:	learn: 691337.6888167	total: 1.5s	remaining: 4.27s
# 260:	learn: 690585.0618812	total: 1.5s	remaining: 4.25s
# 261:	learn: 690037.4060009	total: 1.5s	remaining: 4.24s
# 262:	learn: 688878.4886177	total: 1.53s	remaining: 4.3s
# 263:	learn: 687737.5459682	total: 1.54s	remaining: 4.29s
# 264:	learn: 686066.0475477	total: 1.54s	remaining: 4.29s
# 265:	learn: 685369.6188925	total: 1.55s	remaining: 4.27s
# 266:	learn: 684212.6098870	total: 1.55s	remaining: 4.26s
# 267:	learn: 683231.5121847	total: 1.55s	remaining: 4.25s
# 268:	learn: 681755.3247136	total: 1.56s	remaining: 4.23s
# 269:	learn: 680572.5989650	total: 1.56s	remaining: 4.22s
# 270:	learn: 679325.9544321	total: 1.56s	remaining: 4.21s
# 271:	learn: 678434.7881120	total: 1.57s	remaining: 4.2s
# 272:	learn: 677213.0942074	total: 1.57s	remaining: 4.19s
# 273:	learn: 676034.5814927	total: 1.57s	remaining: 4.17s
# 274:	learn: 675261.6039922	total: 1.58s	remaining: 4.16s
# 275:	learn: 674527.7272441	total: 1.58s	remaining: 4.15s
# 276:	learn: 673342.2449514	total: 1.58s	remaining: 4.14s
# 277:	learn: 673181.8850807	total: 1.59s	remaining: 4.12s
# 278:	learn: 672181.5893280	total: 1.59s	remaining: 4.11s
# 279:	learn: 670216.8414544	total: 1.59s	remaining: 4.1s
# 280:	learn: 668836.0631414	total: 1.62s	remaining: 4.16s
# 281:	learn: 668380.4065722	total: 1.63s	remaining: 4.14s
# 282:	learn: 667066.8129121	total: 1.63s	remaining: 4.14s
# 283:	learn: 665311.0456645	total: 1.64s	remaining: 4.13s
# 284:	learn: 664443.0392510	total: 1.65s	remaining: 4.13s
# 285:	learn: 663378.6206614	total: 1.68s	remaining: 4.2s
# 286:	learn: 662288.7918401	total: 1.69s	remaining: 4.2s
# 287:	learn: 661219.5249082	total: 1.69s	remaining: 4.18s
# 288:	learn: 660365.8097855	total: 1.7s	remaining: 4.17s
# 289:	learn: 660037.1926991	total: 1.7s	remaining: 4.16s
# 290:	learn: 658960.2511581	total: 1.7s	remaining: 4.15s
# 291:	learn: 657822.4598852	total: 1.73s	remaining: 4.19s
# 292:	learn: 657259.7713007	total: 1.73s	remaining: 4.18s
# 293:	learn: 656497.8212889	total: 1.74s	remaining: 4.17s
# 294:	learn: 655067.0126860	total: 1.76s	remaining: 4.2s
# 295:	learn: 654082.0216901	total: 1.76s	remaining: 4.19s
# 296:	learn: 653144.5386999	total: 1.76s	remaining: 4.17s
# 297:	learn: 652664.2133118	total: 1.76s	remaining: 4.16s
# 298:	learn: 651903.0257598	total: 1.77s	remaining: 4.15s
# 299:	learn: 650852.9730589	total: 1.77s	remaining: 4.14s
# 300:	learn: 649913.2974213	total: 1.78s	remaining: 4.13s
# 301:	learn: 649253.1944032	total: 1.78s	remaining: 4.12s
# 302:	learn: 648419.4511909	total: 1.79s	remaining: 4.11s
# 303:	learn: 647499.7336766	total: 1.79s	remaining: 4.11s
# 304:	learn: 646379.2636350	total: 1.8s	remaining: 4.09s
# 305:	learn: 645860.6624331	total: 1.8s	remaining: 4.08s
# 306:	learn: 645037.7762554	total: 1.8s	remaining: 4.07s
# 307:	learn: 644312.4918377	total: 1.81s	remaining: 4.06s
# 308:	learn: 643473.2350289	total: 1.81s	remaining: 4.06s
# 309:	learn: 642579.4896145	total: 1.82s	remaining: 4.06s
# 310:	learn: 641837.6477541	total: 1.83s	remaining: 4.05s
# 311:	learn: 640736.9136781	total: 1.86s	remaining: 4.1s
# 312:	learn: 640141.2567244	total: 1.86s	remaining: 4.09s
# 313:	learn: 639773.1962490	total: 1.86s	remaining: 4.08s
# 314:	learn: 638871.1755668	total: 1.87s	remaining: 4.07s
# 315:	learn: 638512.6736061	total: 1.87s	remaining: 4.05s
# 316:	learn: 637698.2294417	total: 1.88s	remaining: 4.06s
# 317:	learn: 636525.6692045	total: 1.92s	remaining: 4.11s
# 318:	learn: 635602.2605807	total: 1.92s	remaining: 4.09s
# 319:	learn: 634738.4895755	total: 1.92s	remaining: 4.08s
# 320:	learn: 634140.0312695	total: 1.92s	remaining: 4.06s
# 321:	learn: 633065.8627756	total: 1.92s	remaining: 4.05s
# 322:	learn: 632411.7034578	total: 1.92s	remaining: 4.03s
# 323:	learn: 631390.4561196	total: 1.93s	remaining: 4.02s
# 324:	learn: 630524.4538913	total: 1.93s	remaining: 4s
# 325:	learn: 629309.2711216	total: 1.94s	remaining: 4.01s
# 326:	learn: 628701.3024484	total: 1.94s	remaining: 3.99s
# 327:	learn: 627785.1286338	total: 1.94s	remaining: 3.98s
# 328:	learn: 627438.1478704	total: 1.94s	remaining: 3.96s
# 329:	learn: 626749.0730427	total: 1.95s	remaining: 3.95s
# 330:	learn: 625873.2314929	total: 1.95s	remaining: 3.94s
# 331:	learn: 625442.0741929	total: 1.95s	remaining: 3.92s
# 332:	learn: 625017.6971676	total: 1.95s	remaining: 3.91s
# 333:	learn: 623938.8206418	total: 1.96s	remaining: 3.91s
# 334:	learn: 622734.9755905	total: 1.97s	remaining: 3.9s
# 335:	learn: 622123.5896438	total: 1.97s	remaining: 3.89s
# 336:	learn: 621780.1568790	total: 1.97s	remaining: 3.88s
# 337:	learn: 621143.0988805	total: 1.98s	remaining: 3.87s
# 338:	learn: 620661.3175122	total: 1.98s	remaining: 3.86s
# 339:	learn: 620241.9853301	total: 1.98s	remaining: 3.85s
# 340:	learn: 619269.4189767	total: 2.01s	remaining: 3.88s
# 341:	learn: 618409.0988099	total: 2.01s	remaining: 3.86s
# 342:	learn: 617670.2978025	total: 2.01s	remaining: 3.85s
# 343:	learn: 616839.0227786	total: 2.02s	remaining: 3.85s
# 344:	learn: 616165.1518402	total: 2.02s	remaining: 3.84s
# 345:	learn: 615071.2175388	total: 2.03s	remaining: 3.83s
# 346:	learn: 614573.8349326	total: 2.03s	remaining: 3.82s
# 347:	learn: 613857.4920952	total: 2.03s	remaining: 3.81s
# 348:	learn: 613648.4107467	total: 2.03s	remaining: 3.79s
# 349:	learn: 612941.4127583	total: 2.04s	remaining: 3.78s
# 350:	learn: 612499.3257882	total: 2.04s	remaining: 3.77s
# 351:	learn: 612220.1917691	total: 2.04s	remaining: 3.76s
# 352:	learn: 611321.3657288	total: 2.04s	remaining: 3.75s
# 353:	learn: 610479.1652014	total: 2.05s	remaining: 3.73s
# 354:	learn: 609560.8745805	total: 2.05s	remaining: 3.72s
# 355:	learn: 609506.8382313	total: 2.05s	remaining: 3.71s
# 356:	learn: 609189.2338991	total: 2.05s	remaining: 3.69s
# 357:	learn: 608777.7567849	total: 2.05s	remaining: 3.68s
# 358:	learn: 607398.0449142	total: 2.07s	remaining: 3.7s
# 359:	learn: 606495.2026480	total: 2.09s	remaining: 3.72s
# 360:	learn: 605708.6055651	total: 2.09s	remaining: 3.71s
# 361:	learn: 604349.3004444	total: 2.1s	remaining: 3.7s
# 362:	learn: 604299.9062608	total: 2.1s	remaining: 3.68s
# 363:	learn: 604029.9004584	total: 2.1s	remaining: 3.67s
# 364:	learn: 603388.3294497	total: 2.12s	remaining: 3.69s
# 365:	learn: 602610.7861134	total: 2.13s	remaining: 3.68s
# 366:	learn: 602147.2548238	total: 2.13s	remaining: 3.68s
# 367:	learn: 601860.3753955	total: 2.13s	remaining: 3.67s
# 368:	learn: 601346.4389907	total: 2.14s	remaining: 3.66s
# 369:	learn: 601157.4273494	total: 2.14s	remaining: 3.65s
# 370:	learn: 600486.4763958	total: 2.15s	remaining: 3.65s
# 371:	learn: 600203.6540885	total: 2.15s	remaining: 3.64s
# 372:	learn: 599910.9464455	total: 2.16s	remaining: 3.63s
# 373:	learn: 599521.0132107	total: 2.16s	remaining: 3.62s
# 374:	learn: 598544.1178341	total: 2.16s	remaining: 3.61s
# 375:	learn: 597620.0633693	total: 2.17s	remaining: 3.6s
# 376:	learn: 597332.1879755	total: 2.17s	remaining: 3.6s
# 377:	learn: 596714.9866384	total: 2.18s	remaining: 3.58s
# 378:	learn: 596162.8123067	total: 2.19s	remaining: 3.6s
# 379:	learn: 595533.2257337	total: 2.2s	remaining: 3.59s
# 380:	learn: 595099.2137236	total: 2.2s	remaining: 3.58s
# 381:	learn: 594753.9974670	total: 2.21s	remaining: 3.57s
# 382:	learn: 594527.9241349	total: 2.21s	remaining: 3.56s
# 383:	learn: 593684.8200962	total: 2.21s	remaining: 3.55s
# 384:	learn: 593290.8917256	total: 2.22s	remaining: 3.54s
# 385:	learn: 592704.4698391	total: 2.22s	remaining: 3.53s
# 386:	learn: 592124.8064209	total: 2.22s	remaining: 3.52s
# 387:	learn: 591548.1580599	total: 2.23s	remaining: 3.51s
# 388:	learn: 590880.3516047	total: 2.23s	remaining: 3.5s
# 389:	learn: 590317.2625441	total: 2.23s	remaining: 3.49s
# 390:	learn: 589615.7914951	total: 2.23s	remaining: 3.48s
# 391:	learn: 589014.3561173	total: 2.26s	remaining: 3.5s
# 392:	learn: 588382.3994023	total: 2.26s	remaining: 3.49s
# 393:	learn: 587518.4256288	total: 2.26s	remaining: 3.48s
# 394:	learn: 586568.7047823	total: 2.28s	remaining: 3.49s
# 395:	learn: 586001.0928610	total: 2.28s	remaining: 3.48s
# 396:	learn: 585403.2942750	total: 2.28s	remaining: 3.47s
# 397:	learn: 584874.3447761	total: 2.29s	remaining: 3.46s
# 398:	learn: 584402.3660918	total: 2.29s	remaining: 3.44s
# 399:	learn: 583630.1238680	total: 2.29s	remaining: 3.44s
# 400:	learn: 583293.1504244	total: 2.3s	remaining: 3.44s
# 401:	learn: 582246.4935429	total: 2.32s	remaining: 3.45s
# 402:	learn: 581612.8762039	total: 2.32s	remaining: 3.44s
# 403:	learn: 581158.0313030	total: 2.32s	remaining: 3.43s
# 404:	learn: 580629.8454949	total: 2.32s	remaining: 3.42s
# 405:	learn: 580122.4624962	total: 2.33s	remaining: 3.4s
# 406:	learn: 580095.5139968	total: 2.33s	remaining: 3.39s
# 407:	learn: 579613.2758930	total: 2.33s	remaining: 3.38s
# 408:	learn: 579155.6187395	total: 2.33s	remaining: 3.36s
# 409:	learn: 578654.3097782	total: 2.33s	remaining: 3.35s
# 410:	learn: 578548.2890751	total: 2.33s	remaining: 3.34s
# 411:	learn: 578403.8005001	total: 2.33s	remaining: 3.33s
# 412:	learn: 577264.6297784	total: 2.33s	remaining: 3.32s
# 413:	learn: 576817.4480433	total: 2.34s	remaining: 3.31s
# 414:	learn: 576342.3027879	total: 2.34s	remaining: 3.29s
# 415:	learn: 575749.0464981	total: 2.34s	remaining: 3.28s
# 416:	learn: 575456.1770036	total: 2.34s	remaining: 3.27s
# 417:	learn: 575179.9154170	total: 2.34s	remaining: 3.26s
# 418:	learn: 574775.5284307	total: 2.34s	remaining: 3.25s
# 419:	learn: 573644.9214187	total: 2.35s	remaining: 3.24s
# 420:	learn: 572980.7613284	total: 2.35s	remaining: 3.23s
# 421:	learn: 572309.8633337	total: 2.37s	remaining: 3.25s
# 422:	learn: 571897.2323594	total: 2.38s	remaining: 3.24s
# 423:	learn: 571192.9301724	total: 2.38s	remaining: 3.23s
# 424:	learn: 570535.6735858	total: 2.38s	remaining: 3.22s
# 425:	learn: 569454.3548624	total: 2.39s	remaining: 3.22s
# 426:	learn: 569005.2860114	total: 2.4s	remaining: 3.22s
# 427:	learn: 568504.2051602	total: 2.4s	remaining: 3.21s
# 428:	learn: 567850.1807792	total: 2.41s	remaining: 3.21s
# 429:	learn: 566775.7955677	total: 2.42s	remaining: 3.2s
# 430:	learn: 566312.9706302	total: 2.42s	remaining: 3.19s
# 431:	learn: 565563.3974440	total: 2.42s	remaining: 3.19s
# 432:	learn: 565114.2507539	total: 2.42s	remaining: 3.18s
# 433:	learn: 564984.4797286	total: 2.43s	remaining: 3.17s
# 434:	learn: 564743.3851929	total: 2.43s	remaining: 3.16s
# 435:	learn: 564360.0682566	total: 2.43s	remaining: 3.15s
# 436:	learn: 562899.9536595	total: 2.45s	remaining: 3.16s
# 437:	learn: 562779.3974162	total: 2.46s	remaining: 3.15s
# 438:	learn: 562390.6134229	total: 2.46s	remaining: 3.14s
# 439:	learn: 561978.8732806	total: 2.46s	remaining: 3.13s
# 440:	learn: 561444.3489603	total: 2.46s	remaining: 3.13s
# 441:	learn: 561046.1057180	total: 2.47s	remaining: 3.11s
# 442:	learn: 559773.3181698	total: 2.49s	remaining: 3.13s
# 443:	learn: 559575.1308162	total: 2.49s	remaining: 3.12s
# 444:	learn: 558863.8827784	total: 2.51s	remaining: 3.13s
# 445:	learn: 558125.4687279	total: 2.52s	remaining: 3.13s
# 446:	learn: 557557.9553666	total: 2.53s	remaining: 3.13s
# 447:	learn: 557169.7088380	total: 2.53s	remaining: 3.12s
# 448:	learn: 557088.5114138	total: 2.53s	remaining: 3.11s
# 449:	learn: 556404.4346234	total: 2.54s	remaining: 3.1s
# 450:	learn: 556108.0345631	total: 2.54s	remaining: 3.1s
# 451:	learn: 555639.1225625	total: 2.54s	remaining: 3.09s
# 452:	learn: 555105.6688548	total: 2.56s	remaining: 3.08s
# 453:	learn: 554320.2476338	total: 2.57s	remaining: 3.09s
# 454:	learn: 553486.9382546	total: 2.59s	remaining: 3.11s
# 455:	learn: 552861.2239021	total: 2.6s	remaining: 3.1s
# 456:	learn: 552558.0320800	total: 2.6s	remaining: 3.09s
# 457:	learn: 552297.2971951	total: 2.6s	remaining: 3.08s
# 458:	learn: 552209.0331707	total: 2.6s	remaining: 3.06s
# 459:	learn: 551905.1799792	total: 2.6s	remaining: 3.06s
# 460:	learn: 551548.4363499	total: 2.61s	remaining: 3.05s
# 461:	learn: 551097.0397314	total: 2.61s	remaining: 3.04s
# 462:	learn: 551000.3531822	total: 2.62s	remaining: 3.03s
# 463:	learn: 550374.6590609	total: 2.62s	remaining: 3.03s
# 464:	learn: 550023.5606157	total: 2.63s	remaining: 3.02s
# 465:	learn: 549636.6444849	total: 2.64s	remaining: 3.02s
# 466:	learn: 549322.0556812	total: 2.64s	remaining: 3.01s
# 467:	learn: 549000.5509071	total: 2.64s	remaining: 3s
# 468:	learn: 548862.1256316	total: 2.64s	remaining: 2.99s
# 469:	learn: 548561.3701651	total: 2.65s	remaining: 2.99s
# 470:	learn: 548423.7041382	total: 2.66s	remaining: 2.98s
# 471:	learn: 548064.5683284	total: 2.66s	remaining: 2.97s
# 472:	learn: 547733.7438317	total: 2.66s	remaining: 2.96s
# 473:	learn: 546856.9162029	total: 2.67s	remaining: 2.96s
# 474:	learn: 546530.1127885	total: 2.67s	remaining: 2.95s
# 475:	learn: 545696.7311132	total: 2.67s	remaining: 2.94s
# 476:	learn: 545368.2932258	total: 2.67s	remaining: 2.93s
# 477:	learn: 545268.0036185	total: 2.68s	remaining: 2.92s
# 478:	learn: 544961.4107991	total: 2.68s	remaining: 2.92s
# 479:	learn: 544625.1830567	total: 2.68s	remaining: 2.91s
# 480:	learn: 543745.2607656	total: 2.69s	remaining: 2.9s
# 481:	learn: 543174.3959386	total: 2.7s	remaining: 2.9s
# 482:	learn: 542881.7956017	total: 2.7s	remaining: 2.89s
# 483:	learn: 541805.6423691	total: 2.71s	remaining: 2.88s
# 484:	learn: 541331.9295257	total: 2.71s	remaining: 2.88s
# 485:	learn: 540653.9461017	total: 2.74s	remaining: 2.9s
# 486:	learn: 540342.2257633	total: 2.75s	remaining: 2.89s
# 487:	learn: 540038.2852165	total: 2.75s	remaining: 2.88s
# 488:	learn: 539526.2617027	total: 2.75s	remaining: 2.87s
# 489:	learn: 539005.3105527	total: 2.75s	remaining: 2.87s
# 490:	learn: 537927.0257153	total: 2.76s	remaining: 2.86s
# 491:	learn: 537701.5066705	total: 2.76s	remaining: 2.85s
# 492:	learn: 536670.6589913	total: 2.78s	remaining: 2.86s
# 493:	learn: 536030.9302161	total: 2.8s	remaining: 2.87s
# 494:	learn: 535835.3940288	total: 2.8s	remaining: 2.86s
# 495:	learn: 535358.9227069	total: 2.83s	remaining: 2.87s
# 496:	learn: 534659.8699942	total: 2.86s	remaining: 2.89s
# 497:	learn: 534448.5016708	total: 2.86s	remaining: 2.88s
# 498:	learn: 534372.3690418	total: 2.86s	remaining: 2.87s
# 499:	learn: 533529.5573441	total: 2.87s	remaining: 2.87s
# 500:	learn: 533320.3938033	total: 2.87s	remaining: 2.85s
# 501:	learn: 532028.1753865	total: 2.89s	remaining: 2.86s
# 502:	learn: 531739.6944322	total: 2.89s	remaining: 2.85s
# 503:	learn: 531674.8167069	total: 2.89s	remaining: 2.85s
# 504:	learn: 531461.6537144	total: 2.89s	remaining: 2.84s
# 505:	learn: 530458.3237556	total: 2.9s	remaining: 2.83s
# 506:	learn: 530247.0057312	total: 2.9s	remaining: 2.82s
# 507:	learn: 529642.1214810	total: 2.93s	remaining: 2.84s
# 508:	learn: 529070.7776652	total: 2.94s	remaining: 2.84s
# 509:	learn: 528973.4483518	total: 2.94s	remaining: 2.83s
# 510:	learn: 528645.3318703	total: 2.94s	remaining: 2.82s
# 511:	learn: 528019.4347119	total: 2.95s	remaining: 2.81s
# 512:	learn: 527044.2327573	total: 2.95s	remaining: 2.8s
# 513:	learn: 526184.4893479	total: 2.97s	remaining: 2.81s
# 514:	learn: 525986.4267247	total: 2.97s	remaining: 2.8s
# 515:	learn: 525665.1646580	total: 2.98s	remaining: 2.79s
# 516:	learn: 525250.7043590	total: 2.98s	remaining: 2.78s
# 517:	learn: 524896.3970402	total: 2.98s	remaining: 2.77s
# 518:	learn: 524265.5385546	total: 2.98s	remaining: 2.76s
# 519:	learn: 523399.2989468	total: 2.99s	remaining: 2.76s
# 520:	learn: 523096.9180840	total: 2.99s	remaining: 2.75s
# 521:	learn: 522743.2590363	total: 2.99s	remaining: 2.74s
# 522:	learn: 522558.3485429	total: 3s	remaining: 2.73s
# 523:	learn: 522372.9813498	total: 3s	remaining: 2.73s
# 524:	learn: 522045.2387583	total: 3s	remaining: 2.72s
# 525:	learn: 521353.3400528	total: 3.01s	remaining: 2.71s
# 526:	learn: 520871.5371415	total: 3.04s	remaining: 2.73s
# 527:	learn: 520166.5477045	total: 3.06s	remaining: 2.74s
# 528:	learn: 519561.1324890	total: 3.07s	remaining: 2.73s
# 529:	learn: 519453.3822542	total: 3.07s	remaining: 2.72s
# 530:	learn: 519217.8414799	total: 3.07s	remaining: 2.71s
# 531:	learn: 518754.4000937	total: 3.07s	remaining: 2.7s
# 532:	learn: 518470.4969930	total: 3.08s	remaining: 2.69s
# 533:	learn: 517945.3394965	total: 3.1s	remaining: 2.7s
# 534:	learn: 517730.5318168	total: 3.1s	remaining: 2.69s
# 535:	learn: 517646.4354828	total: 3.1s	remaining: 2.68s
# 536:	learn: 516639.8861056	total: 3.11s	remaining: 2.68s
# 537:	learn: 516263.7081274	total: 3.11s	remaining: 2.67s
# 538:	learn: 516172.6589827	total: 3.11s	remaining: 2.66s
# 539:	learn: 515780.7788256	total: 3.12s	remaining: 2.65s
# 540:	learn: 515574.8606847	total: 3.12s	remaining: 2.65s
# 541:	learn: 515412.5002302	total: 3.12s	remaining: 2.63s
# 542:	learn: 515029.8390527	total: 3.12s	remaining: 2.63s
# 543:	learn: 514603.2291542	total: 3.13s	remaining: 2.62s
# 544:	learn: 514544.6671291	total: 3.13s	remaining: 2.61s
# 545:	learn: 513681.3565017	total: 3.13s	remaining: 2.6s
# 546:	learn: 512726.6241292	total: 3.15s	remaining: 2.61s
# 547:	learn: 512141.9708428	total: 3.15s	remaining: 2.6s
# 548:	learn: 511720.7930885	total: 3.17s	remaining: 2.61s
# 549:	learn: 511378.0887018	total: 3.17s	remaining: 2.6s
# 550:	learn: 510933.3216076	total: 3.18s	remaining: 2.59s
# 551:	learn: 510479.3806292	total: 3.2s	remaining: 2.6s
# 552:	learn: 510413.4898463	total: 3.21s	remaining: 2.59s
# 553:	learn: 510050.9249424	total: 3.21s	remaining: 2.59s
# 554:	learn: 509201.3190667	total: 3.24s	remaining: 2.59s
# 555:	learn: 508976.5352102	total: 3.24s	remaining: 2.58s
# 556:	learn: 508074.1527030	total: 3.25s	remaining: 2.58s
# 557:	learn: 507247.7074741	total: 3.27s	remaining: 2.59s
# 558:	learn: 506328.3964640	total: 3.28s	remaining: 2.59s
# 559:	learn: 506146.2062063	total: 3.29s	remaining: 2.58s
# 560:	learn: 505743.9204003	total: 3.29s	remaining: 2.57s
# 561:	learn: 505390.8554258	total: 3.29s	remaining: 2.56s
# 562:	learn: 504769.6918452	total: 3.29s	remaining: 2.56s
# 563:	learn: 504473.5081800	total: 3.3s	remaining: 2.55s
# 564:	learn: 503556.2748964	total: 3.32s	remaining: 2.55s
# 565:	learn: 503230.6380212	total: 3.32s	remaining: 2.55s
# 566:	learn: 503056.4806563	total: 3.32s	remaining: 2.54s
# 567:	learn: 502424.0040275	total: 3.33s	remaining: 2.53s
# 568:	learn: 501906.4343067	total: 3.33s	remaining: 2.52s
# 569:	learn: 501080.9933927	total: 3.36s	remaining: 2.54s
# 570:	learn: 500913.7364680	total: 3.36s	remaining: 2.53s
# 571:	learn: 499973.1941522	total: 3.39s	remaining: 2.54s
# 572:	learn: 498783.0518348	total: 3.43s	remaining: 2.55s
# 573:	learn: 498072.9911843	total: 3.47s	remaining: 2.57s
# 574:	learn: 497910.4566566	total: 3.47s	remaining: 2.57s
# 575:	learn: 497788.9058299	total: 3.48s	remaining: 2.56s
# 576:	learn: 497651.8605289	total: 3.48s	remaining: 2.55s
# 577:	learn: 497456.8054200	total: 3.48s	remaining: 2.54s
# 578:	learn: 496969.0296830	total: 3.48s	remaining: 2.53s
# 579:	learn: 496207.9503173	total: 3.49s	remaining: 2.53s
# 580:	learn: 495379.5305915	total: 3.52s	remaining: 2.54s
# 581:	learn: 494802.9842040	total: 3.52s	remaining: 2.53s
# 582:	learn: 494070.3121501	total: 3.52s	remaining: 2.52s
# 583:	learn: 493914.4913329	total: 3.52s	remaining: 2.51s
# 584:	learn: 493264.7665602	total: 3.53s	remaining: 2.51s
# 585:	learn: 492425.4383042	total: 3.56s	remaining: 2.52s
# 586:	learn: 492406.7770893	total: 3.56s	remaining: 2.51s
# 587:	learn: 492357.9974101	total: 3.56s	remaining: 2.5s
# 588:	learn: 492143.0262262	total: 3.57s	remaining: 2.49s
# 589:	learn: 491723.5291883	total: 3.57s	remaining: 2.48s
# 590:	learn: 490960.4209318	total: 3.59s	remaining: 2.48s
# 591:	learn: 490750.1031597	total: 3.59s	remaining: 2.48s
# 592:	learn: 490490.5211751	total: 3.6s	remaining: 2.47s
# 593:	learn: 490443.8171936	total: 3.6s	remaining: 2.46s
# 594:	learn: 490149.0136553	total: 3.6s	remaining: 2.45s
# 595:	learn: 489199.6806887	total: 3.62s	remaining: 2.45s
# 596:	learn: 488937.2597382	total: 3.62s	remaining: 2.44s
# 597:	learn: 488687.0148638	total: 3.62s	remaining: 2.44s
# 598:	learn: 488281.7627864	total: 3.64s	remaining: 2.44s
# 599:	learn: 487940.1119696	total: 3.64s	remaining: 2.43s
# 600:	learn: 487367.5412946	total: 3.65s	remaining: 2.42s
# 601:	learn: 486819.6050387	total: 3.67s	remaining: 2.43s
# 602:	learn: 486062.2766723	total: 3.68s	remaining: 2.42s
# 603:	learn: 485957.8148798	total: 3.68s	remaining: 2.41s
# 604:	learn: 485809.0556398	total: 3.68s	remaining: 2.4s
# 605:	learn: 485707.5218080	total: 3.68s	remaining: 2.39s
# 606:	learn: 484709.0662746	total: 3.7s	remaining: 2.4s
# 607:	learn: 484433.9278155	total: 3.7s	remaining: 2.39s
# 608:	learn: 484321.6466382	total: 3.71s	remaining: 2.38s
# 609:	learn: 483293.5086715	total: 3.72s	remaining: 2.38s
# 610:	learn: 483036.2491753	total: 3.73s	remaining: 2.37s
# 611:	learn: 482910.9101983	total: 3.73s	remaining: 2.36s
# 612:	learn: 482643.4455477	total: 3.73s	remaining: 2.35s
# 613:	learn: 482604.9874849	total: 3.73s	remaining: 2.34s
# 614:	learn: 482177.3357681	total: 3.73s	remaining: 2.34s
# 615:	learn: 481657.6917127	total: 3.75s	remaining: 2.34s
# 616:	learn: 480938.3611652	total: 3.77s	remaining: 2.34s
# 617:	learn: 480298.7912851	total: 3.8s	remaining: 2.35s
# 618:	learn: 479686.8899994	total: 3.8s	remaining: 2.34s
# 619:	learn: 479573.5317301	total: 3.81s	remaining: 2.33s
# 620:	learn: 479158.6206785	total: 3.81s	remaining: 2.33s
# 621:	learn: 478984.6326743	total: 3.82s	remaining: 2.32s
# 622:	learn: 478608.6293658	total: 3.83s	remaining: 2.32s
# 623:	learn: 477942.5333446	total: 3.84s	remaining: 2.31s
# 624:	learn: 477665.3707362	total: 3.87s	remaining: 2.32s
# 625:	learn: 477214.8398695	total: 3.88s	remaining: 2.32s
# 626:	learn: 476942.6085797	total: 3.88s	remaining: 2.31s
# 627:	learn: 476504.0310880	total: 3.88s	remaining: 2.3s
# 628:	learn: 475412.4581910	total: 3.9s	remaining: 2.3s
# 629:	learn: 475162.2141789	total: 3.9s	remaining: 2.29s
# 630:	learn: 474916.3644815	total: 3.9s	remaining: 2.28s
# 631:	learn: 474440.5528747	total: 3.91s	remaining: 2.28s
# ...
# 719:	learn: 439020.2622701	total: 4.97s	remaining: 1.93s
# 720:	learn: 438787.4734280	total: 4.97s	remaining: 1.92s
# 721:	learn: 438091.1402483	total: 4.99s	remaining: 1.92s
# 722:	learn: 437402.9890768	total: 5.01s	remaining: 1.92s
# 723:	learn: 436650.9404765	total: 5.03s	remaining: 1.92s
# 724:	learn: 436032.3823438	total: 5.05s	remaining: 1.91s
# 725:	learn: 435356.3418506	total: 5.07s	remaining: 1.91s
# 726:	learn: 435047.3998547	total: 5.08s	remaining: 1.91s
# 727:	learn: 434466.7120894	total: 5.1s	remaining: 1.91s
# 728:	learn: 433962.8497207	total: 5.13s	remaining: 1.91s
# 729:	learn: 433673.7244206	total: 5.15s	remaining: 1.9s
# 730:	learn: 433055.5191851	total: 5.17s	remaining: 1.9s
# 731:	learn: 432566.3109500	total: 5.19s	remaining: 1.9s
# 732:	learn: 431896.0789253	total: 5.21s	remaining: 1.9s
# 733:	learn: 431735.5482799	total: 5.21s	remaining: 1.89s
# 734:	learn: 431146.1194538	total: 5.22s	remaining: 1.88s
# 735:	learn: 430420.1645600	total: 5.24s	remaining: 1.88s
# 736:	learn: 430170.3322515	total: 5.26s	remaining: 1.88s
# 737:	learn: 429462.5914640	total: 5.28s	remaining: 1.87s
# 738:	learn: 429316.2302195	total: 5.28s	remaining: 1.86s
# 739:	learn: 428934.6093852	total: 5.3s	remaining: 1.86s
# 740:	learn: 428269.8875168	total: 5.32s	remaining: 1.86s
# 741:	learn: 428015.8219232	total: 5.32s	remaining: 1.85s
# 742:	learn: 427702.9936311	total: 5.33s	remaining: 1.84s
# 743:	learn: 427593.3612799	total: 5.34s	remaining: 1.84s
# 744:	learn: 427119.8833924	total: 5.37s	remaining: 1.84s
# 745:	learn: 426768.1491358	total: 5.4s	remaining: 1.84s
# 746:	learn: 426491.7099526	total: 5.43s	remaining: 1.84s
# 747:	learn: 426223.5779170	total: 5.43s	remaining: 1.83s
# 748:	learn: 426091.9332753	total: 5.44s	remaining: 1.82s
# 749:	learn: 425516.4003002	total: 5.47s	remaining: 1.82s
# 750:	learn: 425055.5089187	total: 5.5s	remaining: 1.82s
# 751:	learn: 424846.2380194	total: 5.51s	remaining: 1.82s
# 752:	learn: 424375.1029579	total: 5.54s	remaining: 1.82s
# 753:	learn: 424273.3275897	total: 5.55s	remaining: 1.81s
# 754:	learn: 423585.3733655	total: 5.58s	remaining: 1.81s
# 755:	learn: 423268.9070114	total: 5.61s	remaining: 1.81s
# 756:	learn: 423172.8607318	total: 5.62s	remaining: 1.8s
# 757:	learn: 422604.8338117	total: 5.64s	remaining: 1.8s
# 758:	learn: 422423.3259420	total: 5.65s	remaining: 1.79s
# 759:	learn: 422270.5486336	total: 5.66s	remaining: 1.79s
# 760:	learn: 421461.6468856	total: 5.69s	remaining: 1.78s
# 761:	learn: 420839.1735100	total: 5.71s	remaining: 1.78s
# 762:	learn: 420662.4846127	total: 5.72s	remaining: 1.78s
# 763:	learn: 420215.6161739	total: 5.75s	remaining: 1.78s
# 764:	learn: 420063.1085483	total: 5.77s	remaining: 1.77s
# 765:	learn: 419600.7810210	total: 5.79s	remaining: 1.77s
# 766:	learn: 419513.5611962	total: 5.79s	remaining: 1.76s
# 767:	learn: 418896.0891057	total: 5.81s	remaining: 1.75s
# 768:	learn: 418783.9195568	total: 5.83s	remaining: 1.75s
# 769:	learn: 418502.2112347	total: 5.85s	remaining: 1.75s
# 770:	learn: 418366.3839007	total: 5.85s	remaining: 1.74s
# 771:	learn: 417868.2773188	total: 5.87s	remaining: 1.73s
# 772:	learn: 417280.2754428	total: 5.88s	remaining: 1.73s
# 773:	learn: 416914.7991660	total: 5.9s	remaining: 1.72s
# 774:	learn: 416279.4299494	total: 5.92s	remaining: 1.72s
# 775:	learn: 415566.9518621	total: 5.94s	remaining: 1.71s
# 776:	learn: 415141.0554007	total: 5.96s	remaining: 1.71s
# 777:	learn: 415047.0209967	total: 5.97s	remaining: 1.7s
# 778:	learn: 414404.8624550	total: 5.99s	remaining: 1.7s
# 779:	learn: 414143.3942642	total: 5.99s	remaining: 1.69s
# 780:	learn: 413742.8695829	total: 6.01s	remaining: 1.69s
# 781:	learn: 413492.4181440	total: 6.03s	remaining: 1.68s
# 782:	learn: 413069.5946107	total: 6.05s	remaining: 1.68s
# 783:	learn: 412812.3609803	total: 6.07s	remaining: 1.67s
# 784:	learn: 412170.2357357	total: 6.1s	remaining: 1.67s
# 785:	learn: 411604.0403664	total: 6.12s	remaining: 1.67s
# 786:	learn: 411486.5548234	total: 6.13s	remaining: 1.66s
# 787:	learn: 411390.1042422	total: 6.13s	remaining: 1.65s
# 788:	learn: 411281.2045048	total: 6.13s	remaining: 1.64s
# 789:	learn: 410810.0117374	total: 6.16s	remaining: 1.64s
# 790:	learn: 410639.5182533	total: 6.17s	remaining: 1.63s
# 791:	learn: 410351.0722932	total: 6.21s	remaining: 1.63s
# 792:	learn: 410045.6421839	total: 6.21s	remaining: 1.62s
# 793:	learn: 409277.2568619	total: 6.23s	remaining: 1.62s
# 794:	learn: 409070.8726344	total: 6.26s	remaining: 1.61s
# 795:	learn: 408840.1761668	total: 6.28s	remaining: 1.61s
# 796:	learn: 408545.7724195	total: 6.29s	remaining: 1.6s
# 797:	learn: 408029.8125638	total: 6.32s	remaining: 1.6s
# 798:	learn: 407599.9763942	total: 6.34s	remaining: 1.59s
# 799:	learn: 407351.6164369	total: 6.34s	remaining: 1.59s
# 800:	learn: 406787.3366114	total: 6.37s	remaining: 1.58s
# 801:	learn: 406576.3426510	total: 6.4s	remaining: 1.58s
# 802:	learn: 406113.3479759	total: 6.42s	remaining: 1.57s
# 803:	learn: 405683.3085094	total: 6.45s	remaining: 1.57s
# 804:	learn: 404951.7492565	total: 6.47s	remaining: 1.57s
# 805:	learn: 404512.3832168	total: 6.49s	remaining: 1.56s
# 806:	learn: 404148.2324217	total: 6.51s	remaining: 1.56s
# 807:	learn: 403938.3152945	total: 6.53s	remaining: 1.55s
# 808:	learn: 403205.6495801	total: 6.54s	remaining: 1.54s
# 809:	learn: 402827.1898665	total: 6.56s	remaining: 1.54s
# 810:	learn: 402201.7874180	total: 6.57s	remaining: 1.53s
# 811:	learn: 401706.4183442	total: 6.58s	remaining: 1.52s
# 812:	learn: 400855.5445863	total: 6.61s	remaining: 1.52s
# 813:	learn: 400483.3493857	total: 6.62s	remaining: 1.51s
# 814:	learn: 400242.9841851	total: 6.64s	remaining: 1.51s
# 815:	learn: 400034.7434742	total: 6.66s	remaining: 1.5s
# 816:	learn: 399680.6782375	total: 6.68s	remaining: 1.5s
# 817:	learn: 399336.3877407	total: 6.69s	remaining: 1.49s
# 818:	learn: 399060.1838086	total: 6.72s	remaining: 1.48s
# 819:	learn: 398716.5532531	total: 6.74s	remaining: 1.48s
# 820:	learn: 398696.4806904	total: 6.74s	remaining: 1.47s
# 821:	learn: 398677.8400206	total: 6.74s	remaining: 1.46s
# 822:	learn: 398491.2235701	total: 6.75s	remaining: 1.45s
# 823:	learn: 398011.9632333	total: 6.77s	remaining: 1.45s
# 824:	learn: 397735.7360219	total: 6.79s	remaining: 1.44s
# 825:	learn: 397580.7324788	total: 6.82s	remaining: 1.44s
# 826:	learn: 397483.7173627	total: 6.83s	remaining: 1.43s
# 827:	learn: 397010.9084772	total: 6.86s	remaining: 1.42s
# 828:	learn: 396835.2741665	total: 6.87s	remaining: 1.42s
# 829:	learn: 396496.8662543	total: 6.92s	remaining: 1.42s
# 830:	learn: 396086.7215060	total: 6.94s	remaining: 1.41s
# 831:	learn: 396005.7273047	total: 6.94s	remaining: 1.4s
# 832:	learn: 395862.3462699	total: 6.96s	remaining: 1.4s
# 833:	learn: 395380.1064238	total: 6.98s	remaining: 1.39s
# 834:	learn: 395036.8514898	total: 7s	remaining: 1.38s
# 835:	learn: 394925.7188251	total: 7.02s	remaining: 1.38s
# 836:	learn: 394538.8275516	total: 7.04s	remaining: 1.37s
# 837:	learn: 394331.7788871	total: 7.07s	remaining: 1.37s
# 838:	learn: 393802.0289912	total: 7.08s	remaining: 1.36s
# 839:	learn: 393655.5299630	total: 7.1s	remaining: 1.35s
# 840:	learn: 393278.8987769	total: 7.12s	remaining: 1.34s
# 841:	learn: 392835.4970933	total: 7.14s	remaining: 1.34s
# 842:	learn: 392589.9139818	total: 7.16s	remaining: 1.33s
# 843:	learn: 392091.8632377	total: 7.17s	remaining: 1.33s
# 844:	learn: 391835.4925085	total: 7.19s	remaining: 1.32s
# 845:	learn: 391712.1092190	total: 7.2s	remaining: 1.31s
# 846:	learn: 391415.7080784	total: 7.22s	remaining: 1.3s
# 847:	learn: 391209.8656631	total: 7.24s	remaining: 1.3s
# 848:	learn: 390947.2749451	total: 7.26s	remaining: 1.29s
# 849:	learn: 390711.4694317	total: 7.28s	remaining: 1.28s
# 850:	learn: 390429.7363958	total: 7.3s	remaining: 1.28s
# 851:	learn: 390027.4763589	total: 7.32s	remaining: 1.27s
# 852:	learn: 389717.6069610	total: 7.35s	remaining: 1.27s
# 853:	learn: 389126.4305442	total: 7.38s	remaining: 1.26s
# 854:	learn: 388683.3485519	total: 7.41s	remaining: 1.25s
# 855:	learn: 388370.0924155	total: 7.43s	remaining: 1.25s
# 856:	learn: 388098.1044499	total: 7.46s	remaining: 1.24s
# 857:	learn: 387708.0303003	total: 7.49s	remaining: 1.24s
# 858:	learn: 387407.8625605	total: 7.51s	remaining: 1.23s
# 859:	learn: 386979.1763882	total: 7.54s	remaining: 1.23s
# 860:	learn: 386483.8694582	total: 7.57s	remaining: 1.22s
# 861:	learn: 386290.6562832	total: 7.61s	remaining: 1.22s
# 862:	learn: 386178.1556815	total: 7.62s	remaining: 1.21s
# 863:	learn: 385961.7885306	total: 7.65s	remaining: 1.2s
# 864:	learn: 385694.2375845	total: 7.69s	remaining: 1.2s
# 865:	learn: 385432.6140181	total: 7.72s	remaining: 1.19s
# 866:	learn: 384949.6873241	total: 7.75s	remaining: 1.19s
# 867:	learn: 384537.1992390	total: 7.78s	remaining: 1.18s
# 868:	learn: 383953.6791471	total: 7.8s	remaining: 1.18s
# 869:	learn: 383444.8674241	total: 7.82s	remaining: 1.17s
# 870:	learn: 383127.3826473	total: 7.84s	remaining: 1.16s
# 871:	learn: 382952.0192925	total: 7.86s	remaining: 1.15s
# 872:	learn: 382530.2541932	total: 7.89s	remaining: 1.15s
# 873:	learn: 382429.0212090	total: 7.91s	remaining: 1.14s
# 874:	learn: 381996.7333539	total: 7.93s	remaining: 1.13s
# 875:	learn: 381702.1966534	total: 7.95s	remaining: 1.12s
# 876:	learn: 381429.1766722	total: 7.95s	remaining: 1.11s
# 877:	learn: 380944.0927305	total: 7.97s	remaining: 1.11s
# 878:	learn: 380493.0119783	total: 8s	remaining: 1.1s
# 879:	learn: 380384.9999028	total: 8.03s	remaining: 1.09s
# 880:	learn: 380138.3485270	total: 8.06s	remaining: 1.09s
# 881:	learn: 379921.8980825	total: 8.09s	remaining: 1.08s
# 882:	learn: 379812.9191138	total: 8.11s	remaining: 1.07s
# 883:	learn: 379524.8475707	total: 8.14s	remaining: 1.07s
# 884:	learn: 379166.4091724	total: 8.18s	remaining: 1.06s
# 885:	learn: 378829.4713671	total: 8.21s	remaining: 1.06s
# 886:	learn: 378771.2798349	total: 8.22s	remaining: 1.05s
# 887:	learn: 378693.2207016	total: 8.22s	remaining: 1.04s
# 888:	learn: 378313.2522775	total: 8.25s	remaining: 1.03s
# 889:	learn: 378010.7148681	total: 8.28s	remaining: 1.02s
# 890:	learn: 377903.2046730	total: 8.32s	remaining: 1.02s
# 891:	learn: 377821.6536643	total: 8.34s	remaining: 1.01s
# 892:	learn: 377685.2253958	total: 8.35s	remaining: 1s
# 893:	learn: 377388.4550104	total: 8.37s	remaining: 993ms
# 894:	learn: 377199.5066596	total: 8.39s	remaining: 984ms
# 895:	learn: 376982.3291414	total: 8.41s	remaining: 976ms
# 896:	learn: 376715.9927287	total: 8.43s	remaining: 968ms
# 897:	learn: 376205.9548894	total: 8.45s	remaining: 960ms
# 898:	learn: 376090.4185000	total: 8.47s	remaining: 951ms
# 899:	learn: 375857.4048548	total: 8.49s	remaining: 943ms
# 900:	learn: 375417.3542222	total: 8.52s	remaining: 936ms
# 901:	learn: 375165.6353548	total: 8.54s	remaining: 927ms
# 902:	learn: 374988.5579311	total: 8.56s	remaining: 919ms
# 903:	learn: 374691.3901530	total: 8.58s	remaining: 911ms
# 904:	learn: 374235.9124921	total: 8.62s	remaining: 904ms
# 905:	learn: 374111.3591318	total: 8.65s	remaining: 897ms
# 906:	learn: 373988.8525302	total: 8.68s	remaining: 890ms
# 907:	learn: 373463.3756113	total: 8.71s	remaining: 883ms
# 908:	learn: 373366.3169631	total: 8.74s	remaining: 875ms
# 909:	learn: 373169.3171105	total: 8.77s	remaining: 867ms
# 910:	learn: 372933.6564467	total: 8.78s	remaining: 858ms
# 911:	learn: 372647.0212645	total: 8.8s	remaining: 849ms
# 912:	learn: 372292.7094162	total: 8.82s	remaining: 840ms
# 913:	learn: 372170.0759641	total: 8.84s	remaining: 832ms
# 914:	learn: 372064.6522504	total: 8.85s	remaining: 823ms
# 915:	learn: 371918.6621001	total: 8.87s	remaining: 814ms
# 916:	learn: 371117.7269726	total: 8.89s	remaining: 805ms
# 917:	learn: 370739.6925543	total: 8.95s	remaining: 800ms
# 918:	learn: 370690.9748589	total: 8.97s	remaining: 791ms
# 919:	learn: 370605.5600028	total: 8.99s	remaining: 782ms
# 920:	learn: 370476.2114108	total: 9.01s	remaining: 773ms
# 921:	learn: 370158.4597654	total: 9.03s	remaining: 764ms
# 922:	learn: 369962.3645410	total: 9.05s	remaining: 755ms
# 923:	learn: 369837.3993787	total: 9.06s	remaining: 746ms
# 924:	learn: 369340.7370647	total: 9.08s	remaining: 736ms
# 925:	learn: 369301.3408327	total: 9.09s	remaining: 726ms
# 926:	learn: 369248.2368309	total: 9.11s	remaining: 717ms
# 927:	learn: 368933.6709530	total: 9.12s	remaining: 708ms
# 928:	learn: 368539.2346394	total: 9.14s	remaining: 699ms
# 929:	learn: 368313.5933837	total: 9.17s	remaining: 690ms
# 930:	learn: 367914.4124823	total: 9.19s	remaining: 681ms
# 931:	learn: 367349.6988049	total: 9.21s	remaining: 672ms
# 932:	learn: 367301.4039445	total: 9.21s	remaining: 661ms
# 933:	learn: 366948.5412222	total: 9.23s	remaining: 653ms
# 934:	learn: 366750.2870237	total: 9.25s	remaining: 643ms
# 935:	learn: 366352.2956776	total: 9.27s	remaining: 634ms
# 936:	learn: 366260.8448779	total: 9.29s	remaining: 625ms
# 937:	learn: 366076.4552495	total: 9.31s	remaining: 615ms
# 938:	learn: 365809.9194464	total: 9.33s	remaining: 606ms
# 939:	learn: 365453.3865894	total: 9.35s	remaining: 597ms
# 940:	learn: 365258.0413047	total: 9.38s	remaining: 588ms
# 941:	learn: 365024.4954673	total: 9.41s	remaining: 579ms
# 942:	learn: 364689.6380647	total: 9.44s	remaining: 571ms
# 943:	learn: 364150.3425671	total: 9.47s	remaining: 562ms
# 944:	learn: 363915.8290205	total: 9.49s	remaining: 553ms
# 945:	learn: 363674.2475295	total: 9.52s	remaining: 544ms
# 946:	learn: 363510.4036699	total: 9.55s	remaining: 535ms
# 947:	learn: 363293.1363778	total: 9.57s	remaining: 525ms
# 948:	learn: 363121.0202127	total: 9.6s	remaining: 516ms
# 949:	learn: 362868.1523395	total: 9.63s	remaining: 507ms
# 950:	learn: 362627.4217146	total: 9.65s	remaining: 497ms
# 951:	learn: 362242.3934823	total: 9.68s	remaining: 488ms
# 952:	learn: 362110.1699065	total: 9.7s	remaining: 478ms
# 953:	learn: 361986.5066185	total: 9.72s	remaining: 469ms
# 954:	learn: 361510.5156731	total: 9.74s	remaining: 459ms
# 955:	learn: 361348.1754586	total: 9.76s	remaining: 449ms
# 956:	learn: 361207.3333218	total: 9.78s	remaining: 439ms
# 957:	learn: 361123.9843225	total: 9.79s	remaining: 429ms
# 958:	learn: 361038.7840330	total: 9.81s	remaining: 419ms
# 959:	learn: 360721.2453195	total: 9.83s	remaining: 410ms
# 960:	learn: 360155.0603524	total: 9.86s	remaining: 400ms
# 961:	learn: 360060.9768366	total: 9.88s	remaining: 390ms
# 962:	learn: 359379.2313739	total: 9.89s	remaining: 380ms
# 963:	learn: 359229.7505732	total: 9.91s	remaining: 370ms
# 964:	learn: 359046.7553638	total: 9.93s	remaining: 360ms
# 965:	learn: 358926.0071592	total: 9.95s	remaining: 350ms
# 966:	learn: 358735.9626779	total: 9.97s	remaining: 340ms
# 967:	learn: 358324.9973248	total: 9.99s	remaining: 330ms
# 968:	learn: 357979.0962096	total: 10s	remaining: 320ms
# 969:	learn: 357964.3595187	total: 10s	remaining: 310ms
# 970:	learn: 357716.0699888	total: 10s	remaining: 300ms
# 971:	learn: 357564.8592971	total: 10.1s	remaining: 290ms
# 972:	learn: 357160.3821533	total: 10.1s	remaining: 280ms
# 973:	learn: 356775.7269912	total: 10.1s	remaining: 270ms
# 974:	learn: 356679.6044936	total: 10.1s	remaining: 259ms
# 975:	learn: 356422.7815056	total: 10.1s	remaining: 249ms
# 976:	learn: 356157.8277833	total: 10.2s	remaining: 239ms
# 977:	learn: 355685.8223255	total: 10.2s	remaining: 229ms
# 978:	learn: 355517.0997895	total: 10.2s	remaining: 219ms
# 979:	learn: 355172.7208960	total: 10.2s	remaining: 208ms
# 980:	learn: 354874.6246020	total: 10.2s	remaining: 198ms
# 981:	learn: 354386.8012360	total: 10.3s	remaining: 188ms
# 982:	learn: 353865.0478840	total: 10.3s	remaining: 178ms
# 983:	learn: 353541.0339017	total: 10.3s	remaining: 167ms
# 984:	learn: 353445.4037701	total: 10.3s	remaining: 157ms
# 985:	learn: 353376.9966359	total: 10.3s	remaining: 146ms
# 986:	learn: 353114.8726676	total: 10.3s	remaining: 136ms
# 987:	learn: 352792.5559860	total: 10.4s	remaining: 126ms
# 988:	learn: 352459.5206881	total: 10.4s	remaining: 115ms
# 989:	learn: 352181.5739382	total: 10.4s	remaining: 105ms
# 990:	learn: 351652.2827114	total: 10.4s	remaining: 94.5ms
# 991:	learn: 351384.4122337	total: 10.4s	remaining: 84.1ms
# 992:	learn: 351027.4081274	total: 10.4s	remaining: 73.6ms
# 993:	learn: 350426.3155311	total: 10.5s	remaining: 63.2ms
# 994:	learn: 350383.9128694	total: 10.5s	remaining: 52.7ms
# 995:	learn: 350072.1134561	total: 10.5s	remaining: 42.2ms
# 996:	learn: 350011.5507324	total: 10.5s	remaining: 31.6ms
# 997:	learn: 349387.0640400	total: 10.5s	remaining: 21.1ms
# 998:	learn: 349228.2595218	total: 10.6s	remaining: 10.6ms
# 999:	learn: 348842.0273106	total: 10.6s	remaining: 0us

# %%
## Checking out feature importance for this model. 

feature_importances = Cat.get_feature_importance(train_pool)
feature_names = X_trainc.columns
for score, name in sorted(zip(feature_importances, feature_names), reverse=True):
    print('{}: {}'.format(name, score))
# Out:
# Total Party Votes: 49.5203542825143
# STATE: 19.324826235312624
# Primary Winner: 16.474285799606406
# (I): 4.269804202048356
# YEAR: 3.6938600208243857
# Primary Loser Vote: 2.4538223779285344
# PARTY: 2.4052426398301656
# Candidate Count: 1.5503943294431999
# Party In House: 0.3074101124920372

# %%
Cat.eval_metrics(data = test_pool, metrics =['RMSE'], plot = True)
# Out:
# {'RMSE': [1449168.8989154273,
#   1438923.6160298362,
#   1428643.935977522,
#   1418263.2401577544,
#   1410374.8026007654,
#   1398505.8480239615,
#   1388658.9345129752,
#   1377697.0966170197,
#   1369198.646085112,
#   1357759.1956284523,
#   1350570.097435111,
#   1339946.8705055774,
#   1328916.111928917,
#   1319330.525027069,
#   1311155.8556834492,
#   1301391.2703681318,
#   1290899.624592532,
#   1281664.8527232357,
#   1271343.7069139103,
#   1262289.2988585995,
#   1252423.0834729904,
#   1242473.5122611234,
#   1232682.3707755352,
#   1222906.2337088059,
#   1214270.2362101702,
#   1205311.903883515,
#   1196977.087838176,
#   1188442.3165276775,
#   1180146.4767367917,
#   1171588.7963449182,
#   1164119.5351010219,
#   1156817.9306824359,
#   1148728.0447405796,
#   1140775.664213473,
#   1133948.3842214812,
#   1125162.287103678,
#   1119002.4440588842,
#   1111963.9860897227,
#   1103849.1589682838,
#   1097994.7714933269,
#   1090544.5871957275,
#   1083099.268975268,
#   1075619.1461032466,
#   1068162.876507864,
#   1061225.0521691565,
#   1056617.6777239859,
#   1049079.252894719,
#   1041741.6190283981,
#   1034751.1545955217,
#   1028349.9107945886,
#   1022102.6681760804,
#   1015445.6659899463,
#   1008552.5144809333,
#   1003324.7726435964,
#   996448.608895406,
#   990445.2318675417,
#   984005.8505179333,
#   977936.7973334314,
#   972411.2873191809,
#   965651.7076545605,
#   960542.0632943343,
#   954640.419297107,
#   950530.929837963,
#   944739.4347282771,
#   939267.3976121373,
#   933548.0985446488,
#   927679.1981134876,
#   922480.5281991396,
#   916745.971212086,
#   911307.7045634974,
#   906114.5633801321,
#   901300.796008996,
#   896304.3663324073,
#   891388.868690128,
#   886063.0327706751,
#   880609.5032702237,
#   876261.9722595066,
#   871221.9413519,
#   866055.9244179855,
#   860499.4989824917,
#   856207.4225096401,
#   851156.355770141,
#   846378.1434634936,
#   841125.3247683026,
#   836210.0887780433,
#   831158.4847073479,
#   826543.5308826376,
#   822372.044214821,
#   817407.0250415079,
#   813587.4705829408,
#   809240.7384909292,
#   805178.8277542784,
#   799841.7868723972,
#   794654.2694377544,
#   790483.5476993462,
#   786262.923645102,
#   783401.395313432,
#   778755.4482902754,
#   773734.6959054256,
#   769189.6830149386,
#   765097.764537399,
#   761087.4501169334,
#   757727.0398324274,
#   753883.270347115,
#   749381.3445972103,
#   744625.4870598248,
#   741300.8634686207,
#   737245.2677666631,
#   732726.2093317423,
#   729572.5337454961,
#   726553.4094418571,
#   723188.2171923472,
#   719535.90834076,
#   716010.8640077676,
#   713488.588699363,
#   710260.6227906366,
#   706660.951703167,
#   703606.7313509887,
#   700983.6727835815,
#   697816.7407565814,
#   695324.0679935862,
#   692482.3801859659,
#   689306.4614767213,
#   686125.7948315556,
#   682830.4015868446,
#   680728.4239603286,
#   678650.4121156766,
#   675340.1215943581,
#   672405.1184439887,
#   669228.480914685,
#   666816.0106433639,
#   663505.9932430105,
#   660962.606043318,
#   658279.8709035768,
#   655571.8702881307,
#   652510.144486801,
#   650181.1572579225,
#   648535.9919283192,
#   645863.7836127068,
#   643995.098584933,
#   642281.557821927,
#   639817.7829842749,
#   637510.2758667055,
#   636289.0427208702,
#   634225.1005931057,
#   631625.877865965,
#   628644.7773493482,
#   626804.0332419046,
#   625106.5108170542,
#   623373.0377300885,
#   621553.7479900831,
#   618737.4972125455,
#   616147.0056402936,
#   614945.3777130769,
#   613075.9877636046,
#   611874.5790636754,
#   610216.4628055874,
#   608901.119971398,
#   607684.3736851919,
#   605451.1025426041,
#   604282.4067518386,
#   603124.6254989277,
#   600987.4263878013,
#   599727.0862905878,
#   598302.9901662692,
#   596265.4342184515,
#   594038.4744439502,
#   591961.3692423136,
#   590250.56813063,
#   588349.5600777837,
#   586899.4551016296,
#   585044.638200297,
#   582577.1418949146,
#   581418.257790241,
#   580000.1150505828,
#   579161.6349153228,
#   577218.0631160708,
#   576065.3942929863,
#   573622.2174400263,
#   572791.4593086068,
#   571362.4207959423,
#   569559.640441294,
#   568508.339989621,
#   566885.9402885505,
#   566322.4712922277,
#   565431.3273091691,
#   564415.0251501033,
#   562112.9118200586,
#   561561.2645392524,
#   560014.6770667613,
#   558387.1564093033,
#   556173.5681581037,
#   555664.6969556364,
#   553608.7525035257,
#   552539.0253214315,
#   550990.9268447814,
#   550148.8021614535,
#   549467.8056313025,
#   548547.4830212478,
#   548050.5038884862,
#   546115.7563683785,
#   544894.1023393802,
#   543726.4745082334,
#   542447.6541383662,
#   542040.3705907228,
#   541356.3482099721,
#   540052.0788775111,
#   539706.1466353104,
#   538445.9736255328,
#   537786.4988671278,
#   536037.1071264232,
#   534790.2968846571,
#   533992.6506277866,
#   533690.1093115609,
#   533558.3219071703,
#   533543.7546090146,
#   533002.7536738535,
#   532696.6261646193,
#   531583.159482807,
#   531215.4730424659,
#   530111.9585502509,
#   529769.3170863233,
#   529828.1844144525,
#   529445.113183208,
#   529129.9737898626,
#   528888.301877567,
#   528351.4202031101,
#   527896.3998436853,
#   527467.8769526577,
#   526937.2859691688,
#   526388.2980012855,
#   525736.5265996002,
#   524756.3009676528,
#   524135.5615111113,
#   522920.82327097125,
#   522820.39004060056,
#   522081.74357843027,
#   521526.03642404143,
#   520817.95387821837,
#   519947.81886020827,
#   518754.5418817105,
#   518526.78126048436,
#   518018.3651975463,
#   517947.8448990814,
#   518088.5780136006,
#   517807.7534263254,
#   517550.6242672896,
#   516800.28109391185,
#   516085.41541081225,
#   516355.892337182,
#   515263.3987868779,
#   515155.44999762194,
#   514991.4317103336,
#   514796.0770994693,
#   514209.6341771189,
#   513485.8433554221,
#   513084.2850040851,
#   513118.7619591437,
#   512220.8362111592,
#   511665.4690785271,
#   511786.3679452771,
#   511998.38593529473,
#   511816.9374558731,
#   510842.1843165209,
#   510375.79564763594,
#   510001.18502108805,
#   509980.78964891843,
#   509381.95892956445,
#   508859.9377425331,
#   507878.6224681151,
#   507336.5007850898,
#   506879.7349151651,
#   506225.52939137386,
#   505640.4983107488,
#   505379.99973421404,
#   505044.0885539488,
#   504599.80994208006,
#   504570.59989999514,
#   504067.9889856155,
#   503754.0248040137,
#   503461.8326158263,
#   503498.6143057902,
#   503371.11331019027,
#   503197.68813968194,
#   503272.0450629971,
#   502884.04969830083,
#   503397.6567461095,
#   502882.6578542748,
#   502994.6114937431,
#   502944.3051579131,
#   502912.49717550504,
#   503258.16369515745,
#   503217.09298649203,
#   503725.1936947637,
#   503603.80028959014,
#   503479.3123877747,
#   502650.7672536805,
#   502591.0522324045,
#   502597.5508198289,
#   502085.8056429288,
#   501156.6549209212,
#   501381.1758214189,
#   501213.5491723262,
#   500543.4768016294,
#   500323.2618886337,
#   500400.68052517984,
#   500251.33127654437,
#   500090.2577893066,
#   500414.88202409307,
#   500539.1651444358,
#   500336.757352891,
#   500391.2028813717,
#   500024.06182300445,
#   500328.164366676,
#   500181.74547904753,
#   500490.4279201479,
#   500549.5138094267,
#   499969.3895688132,
#   499660.4166518951,
#   499360.16802733473,
#   498870.3406272857,
#   498995.6731853564,
#   498814.85596214177,
#   498405.9399064985,
#   498125.2083186268,
#   497979.6305591909,
#   497779.7678415127,
#   497795.63086903474,
#   497751.6909900967,
#   497518.38523690356,
#   497666.8050339029,
#   497790.7945059394,
#   497184.4783211093,
#   497426.562643955,
#   497446.25080713234,
#   497477.8559418102,
#   497773.5100547747,
#   497739.72821206594,
#   497805.63681887445,
#   497456.01148912543,
#   497545.3806648404,
#   497465.47748518875,
#   497227.4885942382,
#   497293.9859551954,
#   497488.0870908851,
#   497286.7810028294,
#   497263.94858090644,
#   497043.97113666305,
#   497330.75338969374,
#   497127.199805808,
#   497078.90829044825,
#   497232.16080063634,
#   497098.5152910175,
#   497057.71715654404,
#   497046.0075427847,
#   497077.6585611393,
#   497009.77756748715,
#   496988.15290667256,
#   497069.7900932243,
#   496881.17979591276,
#   496843.4564114749,
#   496678.0316950295,
#   496711.06354448345,
#   496857.4126547311,
#   496986.028840667,
#   497042.84241396555,
#   497330.4931238024,
#   497252.3588535404,
#   497665.1980203501,
#   497958.7763399746,
#   497996.51782097726,
#   497612.6038176852,
#   497695.10625119647,
#   497847.8619530876,
#   497601.86374000955,
#   497910.6431041978,
#   498061.08041683835,
#   497923.8483358842,
#   497926.6375811133,
#   497784.78424791165,
#   497985.4254217307,
#   498141.64153747685,
#   498085.1617687122,
#   498168.9346359376,
#   498213.3612136448,
#   498078.0193344889,
#   497947.48994477076,
#   497978.3628249867,
#   498017.6923394731,
#   497895.0681684658,
#   497894.7764464773,
#   497810.655324354,
#   497921.8942360051,
#   498106.0208501638,
#   498168.6545875824,
#   498052.8941221271,
#   498053.7124343796,
#   498010.53610738576,
#   497710.3088138483,
#   497610.0627678112,
#   497698.3278265998,
#   497888.49040582986,
#   497810.4991980233,
#   497798.88011237513,
#   497710.4515976671,
#   497630.44853436324,
#   497664.3280253212,
#   497659.5102319203,
#   497173.61302921263,
#   497352.2643063984,
#   497604.2181498471,
#   497671.1849396722,
#   497687.89371114894,
#   497717.38295555225,
#   497648.63043116865,
#   497406.90773036046,
#   497534.4906463239,
#   497300.19725092215,
#   497010.4737248098,
#   496948.35676836,
#   497076.8469997324,
#   497340.00836798764,
#   497285.13606266695,
#   497175.72967032646,
#   497113.52755589806,
#   497453.18784409476,
#   497272.2473861526,
#   497690.6480324529,
#   497805.0609855858,
#   498038.8670811749,
#   498113.8708288007,
#   497956.06235019455,
#   497942.6108046565,
#   498122.16203784815,
#   497998.77588174836,
#   498038.6627518727,
#   498104.01512777846,
#   498098.1682333271,
#   498175.77032308513,
#   498168.41725525097,
#   498495.60434917756,
#   498471.4939074836,
#   498556.04883651854,
#   498694.0571138079,
#   498835.5051255249,
#   498958.1068602338,
#   499116.4284100704,
#   499186.3944606937,
#   499366.95433460653,
#   499474.2862190345,
#   499484.6827837426,
#   499264.9889072873,
#   499282.2629048519,
#   498989.75810518645,
#   499018.1803430981,
#   498962.0379660852,
#   498738.5468084986,
#   498442.9508498295,
#   498596.64900683577,
#   498972.6432654682,
#   498982.6528380591,
#   499117.54344287264,
#   499320.25352566055,
#   499751.81110116246,
#   499620.2470790735,
#   499447.6962203587,
#   499658.269790062,
#   499754.29853830993,
#   499639.76249288913,
#   499682.32229361654,
#   499702.7623445442,
#   499761.50308281387,
#   499793.09920332994,
#   499924.6080194784,
#   499932.2979582705,
#   500043.3247493589,
#   500054.5483409748,
#   500057.4811709563,
#   499728.4299645854,
#   499927.9282287213,
#   500038.3423714943,
#   499994.7986384447,
#   500003.90198073385,
#   500169.11800584936,
#   500231.8193033928,
#   499993.7379773852,
#   499964.84290764894,
#   499984.7338567092,
#   500191.8032982402,
#   500136.3730074871,
#   500442.49168201594,
#   500464.41874300275,
#   500726.1547953464,
#   501049.0698707778,
#   500953.92767779465,
#   500990.66381157644,
#   501099.19489918154,
#   501175.7229694633,
#   501290.3956593266,
#   501213.0119139653,
#   501265.5254382111,
#   500963.0644784555,
#   500936.5408771919,
#   500877.1289616758,
#   500651.61067555746,
#   500667.7441540957,
#   500677.4677550582,
#   500662.51943012926,
#   500779.83164422767,
#   500698.7491041965,
#   500594.52803327603,
#   500942.3393133141,
#   501188.2117638883,
#   501311.57850658835,
#   501323.1147975379,
#   501356.9539366399,
#   501453.0531102971,
#   501476.70633293263,
#   501590.5230896182,
#   501416.92422420386,
#   501475.74035626766,
#   501441.43511282373,
#   501504.9292965113,
#   501539.23659916554,
#   501690.1085641281,
#   501769.23504762363,
#   501794.7469778105,
#   501913.2411599983,
#   502136.8856858634,
#   502282.9938650555,
#   502321.2379036936,
#   502466.2596679207,
#   502541.04409730085,
#   502617.72132907494,
#   502628.94402171357,
#   502508.4289480489,
#   502608.2557991073,
#   502711.7372017509,
#   502911.4266027393,
#   502965.0423432387,
#   503013.4602415461,
#   502902.95136458124,
#   502849.5607105531,
#   502709.34901718964,
#   502909.59462102747,
#   503100.2699480462,
#   503214.732801639,
#   503333.36567790835,
#   503142.583675708,
#   503142.5635851693,
#   503181.51070397993,
#   503170.93398637,
#   503114.2869427673,
#   503329.6377982197,
#   503430.0293908731,
#   503298.642332985,
#   503415.75280023523,
#   503893.3099645475,
#   503935.9209898405,
#   503990.19236092194,
#   504117.9553309459,
#   504179.9548787082,
#   504348.42985968833,
#   504042.87275024835,
#   504408.4207745986,
#   504533.52889848006,
#   504601.8262414464,
#   504761.896164747,
#   505056.83909135277,
#   505415.3197153153,
#   505456.396860211,
#   505465.5985153658,
#   505632.0971607983,
#   505861.5480961807,
#   505928.4153464867,
#   505980.0765661317,
#   505783.00149652106,
#   505800.25313304644,
#   505982.6639995559,
#   506278.27904513496,
#   506155.9576015811,
#   506318.99131767923,
#   506431.3405880904,
#   506484.435087236,
#   506521.247729298,
#   506699.13492402394,
#   506793.51818605105,
#   506752.2309303938,
#   506803.2509956263,
#   506920.8746458093,
#   507117.7285998584,
#   507220.27503899205,
#   507213.255407531,
#   507223.05170485453,
#   507359.7984614333,
#   507556.686359101,
#   507647.5639478925,
#   507683.56468500674,
#   507481.5180191463,
#   507616.0451931356,
#   507464.8703971144,
#   507545.17586457037,
#   507677.09200789727,
#   507623.88448632904,
#   507694.9935260778,
#   507643.8480381694,
#   507909.4738740686,
#   508027.64298894716,
#   508148.41274123127,
#   508402.8187460416,
#   508500.02331305615,
#   508548.4617991877,
#   508667.28888652317,
#   508603.6901110141,
#   508698.864768915,
#   508714.78260284435,
#   508768.37606506643,
#   508585.31328303885,
#   508685.6180899554,
#   508742.80307701277,
#   508638.63556720933,
#   508738.64193968853,
#   508885.5988231573,
#   509186.725270475,
#   509229.77419345727,
#   508902.71068032394,
#   508912.6959693165,
#   509085.6003856672,
#   509333.71947635914,
#   509449.95543457335,
#   509569.2713559406,
#   509577.00880607887,
#   509506.259504387,
#   509387.01011359354,
#   509511.90168721235,
#   509596.54826388706,
#   509715.09288638824,
#   509760.9068886396,
#   509896.90857107914,
#   510193.0808394882,
#   510253.41113919584,
#   509991.92286327365,
#   510207.1397965341,
#   510180.6060209069,
#   510264.10294158524,
#   510371.7961029972,
#   510481.672656923,
#   510425.95776141534,
#   510681.15598383854,
#   510687.1173181565,
#   510746.7763446338,
#   510694.5666795186,
#   510596.0583716352,
#   510628.54421633383,
#   510703.07162158174,
#   510691.948532716,
#   510610.8132345847,
#   510628.96859423246,
#   510737.7977884879,
#   510725.50307567866,
#   510934.984763279,
#   511150.6587220588,
#   511229.30501437926,
#   511263.89245364163,
#   511196.83990626386,
#   511445.59851844324,
#   511459.47474840336,
#   511324.9775114865,
#   511425.9994783708,
#   511735.73850888666,
#   512025.57478456997,
#   511800.47748873784,
#   511916.3998239592,
#   512033.3323692164,
#   512171.4299617952,
#   512379.89026198967,
#   512432.7245310671,
#   512400.26698324474,
#   512416.9807662726,
#   512396.67470084684,
#   512485.1971718492,
#   512399.9150725995,
#   512141.5757762228,
#   512006.39828167163,
#   511990.6378932581,
#   512010.68155467964,
#   511966.24340933264,
#   511836.4493935792,
#   511850.7667912406,
#   512023.0126642063,
#   512172.9517519178,
#   512255.8190395801,
#   512298.5551473495,
#   512293.06080236495,
#   512496.9147502503,
#   512742.73345344,
#   512792.8888619785,
#   512836.4908160853,
#   512860.88290251064,
#   512863.79057467746,
#   512803.4698473688,
#   512933.4167297993,
#   513054.32083791913,
#   513244.3415290523,
#   513343.01938489825,
#   513283.4251985015,
#   513404.95995725784,
#   513252.51445896475,
#   513161.90237558604,
#   513154.9520849994,
#   513258.8928381502,
#   513359.003667451,
#   513420.8361890718,
#   513520.3647357452,
#   513711.07038994663,
#   513965.28892757266,
#   514139.22492523986,
#   514054.01937399537,
#   514109.4996104583,
#   514079.68211216235,
#   514213.3254953677,
#   514464.109143761,
#   514556.92672123807,
#   514851.01720101095,
#   514895.7166432797,
#   515025.73535341164,
#   515053.03236606263,
#   515139.3851714593,
#   515220.9731768339,
#   515277.9233597385,
#   515510.30068623304,
#   515758.72021161875,
#   515644.21704712714,
#   515732.919026615,
#   516001.72857197997,
#   515797.7014301843,
#   515830.0232408292,
#   515822.3552797584,
#   515931.3026190633,
#   516211.89088033536,
#   516504.72832125606,
#   516395.8145577411,
#   516627.3797044364,
#   516639.16615758627,
#   516537.96355465206,
#   516531.7231606487,
#   516407.65958905814,
#   516540.15971644263,
#   516652.8979836542,
#   516754.23919397796,
#   516992.65664333326,
#   517159.3928674515,
#   517139.49749289936,
#   517175.36394507234,
#   517250.05303385877,
#   517215.3007588269,
#   517301.4234202484,
#   517289.7106314196,
#   517397.56878801505,
#   517497.1810379971,
#   517715.92773313733,
#   517626.0572085913,
#   517832.9738365428,
#   517859.1181865117,
#   517799.6318904583,
#   517912.06006920995,
#   517866.705754348,
#   517840.3800455207,
#   517716.9730990796,
#   517775.2584829516,
#   517881.0068342387,
#   517887.41841166007,
#   518099.6682848868,
#   518281.18664410966,
#   518453.5032024799,
#   518481.0995268863,
#   518572.7693887413,
#   518683.17520918476,
#   518831.1264125238,
#   518987.5254220295,
#   519097.3117211912,
#   519041.00872215914,
#   519061.97897842637,
#   519142.6105437652,
#   519134.5905239455,
#   519258.7788714847,
#   519358.5957061832,
#   519471.6727826061,
#   519498.86684113013,
#   519635.62226561416,
#   519736.3973106431,
#   519814.9506609445,
#   519929.7445370949,
#   519586.72219890455,
#   519582.76572799,
#   519607.1607526795,
#   519800.563529378,
#   519952.3855316318,
#   520136.5526109829,
#   520330.5947671429,
#   520514.7211934841,
#   520520.09859088424,
#   520287.65729020967,
#   520363.9499367341,
#   520353.5362959056,
#   520571.75315100566,
#   520689.6975329472,
#   520759.4393582134,
#   520687.7727159766,
#   520822.4981186222,
#   520993.300950266,
#   521123.5543265673,
#   521120.93226354197,
#   521359.5904805203,
#   521266.33792813536,
#   521281.0418731388,
#   521425.08256741875,
#   521624.28777748265,
#   521468.8621840774,
#   521597.8241316943,
#   521613.8223458836,
#   521603.3339943508,
#   521647.48071602505,
#   521704.2796676399,
#   521595.9389661911,
#   521597.6625287167,
#   521562.34100228886,
#   521663.7087344802,
#   521775.0966472627,
#   521864.8169426791,
#   521979.0684938618,
#   521929.601275291,
#   521988.4704195216,
#   522005.81661746337,
#   522129.09788859036,
#   522213.76986333815,
#   522099.3230268894,
#   522044.8340970242,
#   522103.33615928167,
#   522040.2842828245,
#   522096.5097271481,
#   522237.3693016679,
#   522243.9658420352,
#   522211.23485799495,
#   522228.7240087876,
#   522324.8775193255,
#   522401.99592941604,
#   522436.14370586525,
#   522509.68329976895,
#   522432.5195208022,
#   522388.2890515011,
#   522369.70876986964,
#   522420.79080306063,
#   522537.2444213479,
#   522649.9380077895,
#   522605.7313502058,
#   522778.0123176967,
#   523034.11688588595,
#   523247.368539051,
#   523453.57535030314,
#   523401.90524216223,
#   523265.71550214523,
#   523250.4149505007,
#   523360.2460708716,
#   523503.2839851613,
#   523670.1948171721,
#   523932.06498672906,
#   523941.566988236,
#   524028.9112232364,
#   524020.2941246024,
#   524130.3152090069,
#   524261.54221245355,
#   524430.598500134,
#   524441.5960615125,
#   524670.6639234283,
#   524755.7204610531,
#   524887.5002383941,
#   524901.7558037682,
#   524958.1291484012,
#   525004.4330818662,
#   525123.8330617681,
#   525253.6023604844,
#   525354.2671302025,
#   525606.3761234418,
#   525511.855150695,
#   525785.0704474108,
#   525807.2825045143,
#   525874.4374067734,
#   525899.8318723595,
#   525641.8261875106,
#   525633.7150818611,
#   525720.6612611302,
#   525844.9813015953,
#   525769.2000143281,
#   525826.9023509327,
#   525910.3168887614,
#   525855.7853773771,
#   525984.0961236482,
#   525934.8410887433,
#   526126.6412167228,
#   526259.2588518091,
#   526382.6439930678,
#   526347.9498092886,
#   526199.2344486291,
#   526222.4593248067,
#   526288.5056486356,
#   526300.2354576443,
#   526273.739972767,
#   526415.3997809837,
#   526645.5294665683,
#   526690.056949762,
#   526783.6608579333,
#   526836.0984509139,
#   526974.9626247484,
#   526908.1459855279,
#   526931.0396418154,
#   526537.4640603364,
#   526707.9662301589,
#   526736.9135414459,
#   526727.5259599583,
#   526698.5196645567,
#   526746.0505215412,
#   526747.1016165041,
#   526690.3031868886,
#   526430.0213621261,
#   526490.4817336918,
#   526565.7308883421,
#   526344.3019160706,
#   526546.3959758508,
#   526654.2230125839,
#   526792.907337819,
#   526748.9557831273,
#   526823.6762199752,
#   526943.4692761983,
#   527070.5355910818,
#   527062.998497176,
#   527243.5873874485,
#   527319.1314728247,
#   527270.4058717699,
#   527353.9984102632,
#   527284.0595331118,
#   527309.6743722802,
#   527413.0655657519,
#   527451.1672467978,
#   527625.2672752553,
#   527744.1713060976,
#   527898.3410477391,
#   527849.1084419548,
#   527973.6115430408,
#   528157.2877115024,
#   528191.3881204084,
#   527965.7493430461,
#   528049.3138537286,
#   527994.7419936004,
#   528199.0563399474,
#   528182.3727028306,
#   528177.0808858244,
#   528173.9791722114,
#   528225.8572997599,
#   528418.9604881929,
#   528497.3854511316,
#   528493.1472950747,
#   528487.50486425,
#   528639.1208329168,
#   528739.5940861031,
#   528765.9895017531,
#   528866.3326353012,
#   528735.1347456019,
#   528853.7118142458,
#   528869.3401698234,
#   528909.857961435,
#   529012.7628603792,
#   528979.5064540969,
#   528871.5008722843,
#   528983.1520689188,
#   529044.0391167974,
#   529120.2760034745,
#   529159.4987790491,
#   529333.0345348865,
#   529366.7087886309,
#   529472.6999893362,
#   529546.5045372176,
#   529584.4815126715,
#   529493.5882902697,
#   529524.3458045471,
#   529484.6310646858,
#   529461.3847910281,
#   529429.9501769342,
#   529541.2906231687,
#   529327.5232480003,
#   529365.7670194398,
#   529439.1573264188,
#   529145.9547769584,
#   529311.7048921507,
#   529355.7438602439,
#   529235.3807299507,
#   529233.3949793271,
#   529009.1201519419,
#   528979.1214964577,
#   528703.0217896648]}
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(data={'catboost_info': {'path': 'catboost_info', 'name': 'catboost_info', 'content': {'passed_iterations': 999, 'total_iterations': 1000, 'data': {'iterations': [{'iteration': 0, 'eval_dataset': [1449168.899]}, {'iteration': 1, 'eval_dataset': [1438923.616]}, {'iteration': 2, 'eval_dataset': [1428643.936]}, {'iteration': 3, 'eval_dataset': [1418263.24]}, {'iteration': 4, 'eval_dataset': [1410374.803]}, {'iteration': 5, 'eval_dataset': [1398505.848]}, {'iteration': 6, 'eval_dataset': [1388658.935]}, {'iteration': 7, 'eval_dataset': [1377697.097]}, {'iteration': 8, 'eval_dataset': [1369198.646]}, {'iteration': 9, 'eval_dataset': [1357759.196]}, {'iteration': 10, 'eval_dataset': [1350570.097]}, {'iteration': 11, 'eval_dataset': [1339946.871]}, {'iteration': 12, 'eval_dataset': [1328916.112]}, {'iteration': 13, 'eval_dataset': [1319330.525]}, {'iteration': 14, 'eval_dataset': [1311155.856]}, {'iteration': 15, 'eval_dataset': [1301391.27]}, {'iteration': 16, 'eval_dataset': [1290899.625]}, {'iteration': 17, 'eval_dataset': [1281664.853]}, {'iteration': 18, 'eval_dataset': [1271343.707]}, {'iteration': 19, 'eval_dataset': [1262289.299]}, {'iteration': 20, 'eval_dataset': [1252423.083]}, {'iteration': 21, 'eval_dataset': [1242473.512]}, {'iteration': 22, 'eval_dataset': [1232682.371]}, {'iteration': 23, 'eval_dataset': [1222906.234]}, {'iteration': 24, 'eval_dataset': [1214270.236]}, {'iteration': 25, 'eval_dataset': [1205311.904]}, {'iteration': 26, 'eval_dataset': [1196977.088]}, {'iteration': 27, 'eval_dataset': [1188442.317]}, {'iteration': 28, 'eval_dataset': [1180146.477]}, {'iteration': 29, 'eval_dataset': [1171588.796]}, {'iteration': 30, 'eval_dataset': [1164119.535]}, {'iteration': 31, 'eval_dataset': [1156817.931]}, {'iteration': 32, 'eval_dataset': [1148728.045]}, {'iteration': 33, 'eval_dataset': [1140775.664]}, {'iteration': 34, 'eval_dataset': [1133948.384]}, {'iteration': 35, 'eval_dataset': [1125162.287]}, {'iteration': 36, 'eval_dataset': [1119002.444]}, {'iteration': 37, 'eval_dataset': [1111963.986]}, {'iteration': 38, 'eval_dataset': [1103849.159]}, {'iteration': 39, 'eval_dataset': [1097994.771]}, {'iteration': 40, 'eval_dataset': [1090544.587]}, {'iteration': 41, 'eval_dataset': [1083099.269]}, {'iteration': 42, 'eval_dataset': [1075619.146]}, {'iteration': 43, 'eval_dataset': [1068162.877]}, {'iteration': 44, 'eval_dataset': [1061225.052]}, {'iteration': 45, 'eval_dataset': [1056617.678]}, {'iteration': 46, 'eval_dataset': [1049079.253]}, {'iteration': 47, 'eval_dataset': [1041741.619]}, {'iteration': 48, 'eval_dataset': [1034751.155]}, {'iteration': 49, 'eval_dataset': [1028349.911]}, {'iteration': 50, 'eval_dataset': [1022102.668]}, {'iteration': 51, 'eval_dataset': [1015445.666]}, {'iteration': 52, 'eval_dataset': [1008552.514]}, {'iteration': 53, 'eval_dataset': [1003324.773]}, {'iteration': 54, 'eval_dataset': [996448.6089]}, {'iteration': 55, 'eval_dataset': [990445.2319]}, {'iteration': 56, 'eval_dataset': [984005.8505]}, {'iteration': 57, 'eval_dataset': [977936.7973]}, {'iteration': 58, 'eval_dataset': [972411.2873]}, {'iteration': 59, 'eval_dataset': [965651.7077]}, {'iteration': 60, 'eval_dataset': [960542.0633]}, {'iteration': 61, 'eval_dataset': [954640.4193]}, {'iteration': 62, 'eval_dataset': [950530.9298]}, {'iteration': 63, 'eval_dataset': [944739.4347]}, {'iteration': 64, 'eval_dataset': [939267.3976]}, {'iteration': 65, 'eval_dataset': [933548.0985]}, {'iteration': 66, 'eval_dataset': [927679.1981]}, {'iteration': 67, 'eval_dataset': [922480.5282]}, {'iteration': 68, 'eval_dataset': [916745.9712]}, {'iteration': 69, 'eval_dataset': [911307.7046]}, {'iteration': 70, 'eval_dataset': [906114.5634]}, {'iteration': 71, 'eval_dataset': [901300.796]}, {'iteration': 72, 'eval_dataset': [896304.3663]}, {'iteration': 73, 'eval_dataset': [891388.8687]}, {'iteration': 74, 'eval_dataset': [886063.0328]}, {'iteration': 75, 'eval_dataset': [880609.5033]}, {'iteration': 76, 'eval_dataset':  ...

# %%
Cat.eval_metrics(data = test_pool, metrics =['R2'], plot = True)
# Out:
# {'R2': [0.004788226750846447,
#   0.009492245243488129,
#   0.013514223865930819,
#   0.017911366811277363,
#   0.020518645733014207,
#   0.025705570201292605,
#   0.02959488013792777,
#   0.03485921171703443,
#   0.03715042457101414,
#   0.042349688775589533,
#   0.04286788714938017,
#   0.049066709524073215,
#   0.05482470853265453,
#   0.05941933945288114,
#   0.06249788123384703,
#   0.0681190824902348,
#   0.07445401269640683,
#   0.07950990618481069,
#   0.08485194875788082,
#   0.0903193014142678,
#   0.09571733583489694,
#   0.10119602249672222,
#   0.10688121140032936,
#   0.11239376295985448,
#   0.11731289357185104,
#   0.1221162891767319,
#   0.12741854724832402,
#   0.13253575547276752,
#   0.13805234593632165,
#   0.14379133751930084,
#   0.14931321770077544,
#   0.15408043180171982,
#   0.15954951901301617,
#   0.16486747146952851,
#   0.16875548486615122,
#   0.1748444936398862,
#   0.17837586971732255,
#   0.1823098572883507,
#   0.1875368261034409,
#   0.19121897123197085,
#   0.19616043599972022,
#   0.2015436964270909,
#   0.2064642292043941,
#   0.21142986102053019,
#   0.21675524976294636,
#   0.21823625509247935,
#   0.2235988789020571,
#   0.22882081350615047,
#   0.23395046807787934,
#   0.2385624479944497,
#   0.2434633060055693,
#   0.2484563219817435,
#   0.25364022240030826,
#   0.2578756557692006,
#   0.26389123774992884,
#   0.2685142342808342,
#   0.27375261257259653,
#   0.2787261295303791,
#   0.2827926253407591,
#   0.2891862690803544,
#   0.29330496844975773,
#   0.2984536088663229,
#   0.3014844471309458,
#   0.3060466859070111,
#   0.31039556771478016,
#   0.3156699610630239,
#   0.32099420656301436,
#   0.3251149797087707,
#   0.32992612806621147,
#   0.3344587241392937,
#   0.33869928289845863,
#   0.34273322250298477,
#   0.346996393093863,
#   0.35197659837467266,
#   0.3573700173137281,
#   0.36289427182208134,
#   0.36720701770923314,
#   0.3721039620973603,
#   0.37687174651167465,
#   0.3826975026343158,
#   0.38749598019940723,
#   0.3925331378244631,
#   0.39741360017593785,
#   0.40307028820588764,
#   0.4079411713119506,
#   0.41357490344121095,
#   0.4181869901979254,
#   0.4226318172939484,
#   0.4280867515976847,
#   0.43197094248406476,
#   0.4364285776804192,
#   0.44060881808997954,
#   0.44657089801089456,
#   0.4523467547004536,
#   0.45619972033899714,
#   0.4606226605753665,
#   0.46304161355001583,
#   0.4678607620902947,
#   0.473486221927525,
#   0.47799093168004725,
#   0.4818521770331986,
#   0.48631636086275576,
#   0.4896696419219697,
#   0.49374292752277604,
#   0.49883236120840346,
#   0.5040074889193311,
#   0.5071412812212841,
#   0.5115804743060206,
#   0.5165208010460968,
#   0.5197998245210852,
#   0.5225329620846568,
#   0.5260725277549829,
#   0.5302365991644495,
#   0.5337250364269789,
#   0.5363634894866529,
#   0.5396771403072389,
#   0.5433977273467987,
#   0.546637781158447,
#   0.5492822284163665,
#   0.5526189415958929,
#   0.555152557142291,
#   0.5579701619753934,
#   0.5613421439079136,
#   0.5649203113115677,
#   0.5684099108568086,
#   0.570691225769999,
#   0.5726646953302713,
#   0.5763551307950863,
#   0.579557235337145,
#   0.5829282104021438,
#   0.5855290156747001,
#   0.5890820407626143,
#   0.5916598335802279,
#   0.594308731459005,
#   0.5971706858749457,
#   0.600444700179599,
#   0.6028432319914545,
#   0.6044515762719982,
#   0.607162297167797,
#   0.6090994253860285,
#   0.6106772171126764,
#   0.6131362325957821,
#   0.6153342102711871,
#   0.6165266268478166,
#   0.6185381890450561,
#   0.6211556653330821,
#   0.6244095499872733,
#   0.6262065719037027,
#   0.6278554686752572,
#   0.6295821337623766,
#   0.6313621467960142,
#   0.634466792084451,
#   0.6372003472776482,
#   0.6382307645205714,
#   0.6401143164941686,
#   0.641337952135011,
#   0.6430373566118497,
#   0.6442774495524526,
#   0.6455097856067329,
#   0.6479169532781083,
#   0.6491317907063313,
#   0.650141169637581,
#   0.6523784781433708,
#   0.6535881162660064,
#   0.6549672506207558,
#   0.6570915495765128,
#   0.6595060811501086,
#   0.6616835255473501,
#   0.6633839686470103,
#   0.6654061601408925,
#   0.6668696647215377,
#   0.6688442221028177,
#   0.6714872165024517,
#   0.672624090750791,
#   0.6741066701483387,
#   0.674887122439034,
#   0.676914979103307,
#   0.6781415884118513,
#   0.6807384471873383,
#   0.6814908448139712,
#   0.6829263143705802,
#   0.684795421016225,
#   0.6858391771417515,
#   0.687518120611535,
#   0.6879849958138884,
#   0.6888250829877908,
#   0.6897825050485483,
#   0.6922074812711427,
#   0.6926811304014593,
#   0.6942426870638245,
#   0.6959444738212038,
#   0.6982506022739976,
#   0.6986777934810151,
#   0.7008224442643143,
#   0.7018161132469427,
#   0.703383938732287,
#   0.7042013135312533,
#   0.7048469204268935,
#   0.7057231683889645,
#   0.706195978499689,
#   0.7081983618292312,
#   0.7094241554446409,
#   0.7106125052702139,
#   0.711875540758714,
#   0.7122496914181543,
#   0.7129090490815151,
#   0.7142011881043491,
#   0.7145306338458608,
#   0.7157852669767826,
#   0.7164388210469699,
#   0.718223360396217,
#   0.7194861204199623,
#   0.7202670134790559,
#   0.720525049734077,
#   0.7206198305020679,
#   0.7206111772754586,
#   0.7211459588957856,
#   0.721443131821575,
#   0.722564844049898,
#   0.7228896066301559,
#   0.7240023451127291,
#   0.7243286739760293,
#   0.7242395378705389,
#   0.724583120596941,
#   0.7248704737329263,
#   0.7250891494037924,
#   0.7255971689969103,
#   0.7260387132522219,
#   0.7264555399162487,
#   0.7269691200337508,
#   0.7274898708742126,
#   0.7281415656701914,
#   0.7291269788082189,
#   0.7297474920225531,
#   0.7309654435692305,
#   0.7310299813105627,
#   0.7317700876649396,
#   0.7323267428221575,
#   0.7330341949022046,
#   0.7338911222587545,
#   0.735091124054934,
#   0.7353008087165471,
#   0.735804153378806,
#   0.7358666417040148,
#   0.7357019874279835,
#   0.7359698576427713,
#   0.7362055606504376,
#   0.7369560328992957,
#   0.7376626693863872,
#   0.7373806833578389,
#   0.7384713753084051,
#   0.7385741840869181,
#   0.738718324695012,
#   0.73889843941768,
#   0.7394814074509011,
#   0.7402028665020967,
#   0.7405878797258275,
#   0.7405358109592882,
#   0.7414267066700426,
#   0.7419794048192518,
#   0.7418449662423017,
#   0.741612833230664,
#   0.741788475998697,
#   0.7427613929811678,
#   0.7432271953607323,
#   0.7435937083611687,
#   0.7436050814560988,
#   0.7441981011893088,
#   0.7447177332774372,
#   0.7456941562242406,
#   0.7462279744964981,
#   0.74667809491018,
#   0.7473250176651309,
#   0.747903061656351,
#   0.7481576668087971,
#   0.7484869600200339,
#   0.7489237166002987,
#   0.7489454866000795,
#   0.7494401551394526,
#   0.7497489709278992,
#   0.7500365739432873,
#   0.7499936984966693,
#   0.7501190223356596,
#   0.7502891793639876,
#   0.7502145453847997,
#   0.7505960770030903,
#   0.750082628740957,
#   0.7505915260849207,
#   0.7504773933973228,
#   0.7505252328263591,
#   0.7505546757652835,
#   0.7502103858506168,
#   0.7502484389102799,
#   0.7497425571541252,
#   0.7498629764440095,
#   0.7499859628996963,
#   0.750807400534639,
#   0.7508657406093672,
#   0.7508592131183367,
#   0.7513660456889073,
#   0.7522853497868136,
#   0.7520634376734587,
#   0.7522296843245238,
#   0.7528927534963155,
#   0.7531102481416275,
#   0.7530350596458384,
#   0.7531842175297044,
#   0.7533451673914419,
#   0.7530260151928093,
#   0.7529050564449709,
#   0.7531056320476188,
#   0.7530533962092897,
#   0.7534179917860874,
#   0.7531218497305225,
#   0.7532686071971144,
#   0.7529684903612514,
#   0.7529111313877379,
#   0.7534877332715679,
#   0.753795707009366,
#   0.7540947621888642,
#   0.7545802708491499,
#   0.7544628285244788,
#   0.7546442363827489,
#   0.7550481508302436,
#   0.7553277175270683,
#   0.755473557718026,
#   0.7556734274689383,
#   0.7556609374491727,
#   0.7557112075801166,
#   0.7559408335785199,
#   0.7557967964736299,
#   0.7556814028472074,
#   0.7562815129475452,
#   0.7560460546652481,
#   0.7560303568481803,
#   0.7560015374260473,
#   0.755717087360601,
#   0.7557548224907894,
#   0.7556977694859612,
#   0.7560453179565039,
#   0.7559586861381644,
#   0.7560415900597496,
#   0.7562801424199261,
#   0.7562159638199146,
#   0.7560292463285937,
#   0.7562280414998507,
#   0.7562561206168098,
#   0.7564770354121895,
#   0.75620266706477,
#   0.7564075168203513,
#   0.7564586057933723,
#   0.7563154755199195,
#   0.756453848248603,
#   0.7564969931147216,
#   0.7565102504952497,
#   0.7564867910923951,
#   0.7565604883930315,
#   0.7565865202161635,
#   0.7565096311499016,
#   0.7567021331111302,
#   0.7567440819694624,
#   0.7569067264348907,
#   0.7568822525090327,
#   0.756746851483287,
#   0.7566275183130964,
#   0.7565801154759054,
#   0.7562989154737714,
#   0.756381055890468,
#   0.7559865379874271,
#   0.7557077304261133,
#   0.755668839645559,
#   0.7560517675826361,
#   0.7559799690438781,
#   0.7558320577056018,
#   0.7560784915180744,
#   0.7557821738204101,
#   0.7556406837378737,
#   0.7557814206117885,
#   0.7557842278727261,
#   0.7559287318674205,
#   0.755741251563537,
#   0.7555977985923118,
#   0.755656936732102,
#   0.7555765493632507,
#   0.7555360494232046,
#   0.7556747515375548,
#   0.7558086941832615,
#   0.7557865805226598,
#   0.7557465684336184,
#   0.7558727294682914,
#   0.755878261959495,
#   0.7559635553446762,
#   0.755861529038578,
#   0.7556859421981399,
#   0.7556280670583312,
#   0.7557467560491083,
#   0.7557521633057034,
#   0.7558033473780599,
#   0.756104165162774,
#   0.7561995741696659,
#   0.756111498470527,
#   0.755923260580847,
#   0.7560035596637255,
#   0.7560206662891527,
#   0.7561123244610279,
#   0.7561950796137543,
#   0.7561699759791134,
#   0.7561806425133726,
#   0.7566617911756763,
#   0.7564958381344453,
#   0.7562587815056974,
#   0.7562017865788615,
#   0.7561840781934908,
#   0.7561632028483849,
#   0.7562360479845527,
#   0.7564690979316359,
#   0.7563526796277015,
#   0.7565896000233441,
#   0.7568776006573386,
#   0.7569339366797893,
#   0.7568138166350393,
#   0.7565574571294207,
#   0.7566174086301959,
#   0.7567324802577486,
#   0.7567941641151475,
#   0.7564657261892741,
#   0.7566482344005088,
#   0.7562537544807122,
#   0.7561449276017347,
#   0.7559131630752927,
#   0.7558509003734007,
#   0.7560048229308897,
#   0.7560208210547159,
#   0.7558476588180947,
#   0.7559712021626845,
#   0.7559379714615151,
#   0.7558737205627677,
#   0.7558848189381391,
#   0.7558168342100287,
#   0.7558292529365941,
#   0.7555138782320703,
#   0.755542544108996,
#   0.7554605891694215,
#   0.7553270401908332,
#   0.7551902224757986,
#   0.7550676601698655,
#   0.7549092504704973,
#   0.7548477403943104,
#   0.7546795344231791,
#   0.7545775514192474,
#   0.7545706554588612,
#   0.754787726586907,
#   0.7547800198991425,
#   0.7550671218083587,
#   0.7550431706991306,
#   0.75509729898001,
#   0.755322031314837,
#   0.7556169207174525,
#   0.7554755411839789,
#   0.7551143858582502,
#   0.7551092787469844,
#   0.7549823137393765,
#   0.7547903239305868,
#   0.754370046262703,
#   0.7545003027341086,
#   0.7546744801010854,
#   0.7544744980660705,
#   0.7543871525545973,
#   0.7545036327189077,
#   0.7544661959795498,
#   0.7544529086893016,
#   0.7544002276277576,
#   0.75437313615527,
#   0.7542457469554777,
#   0.7542411044799112,
#   0.7541277757159814,
#   0.7541203450947673,
#   0.7541208697627997,
#   0.7544381034155365,
#   0.7542454906798713,
#   0.7541325173370249,
#   0.7541798874921348,
#   0.7541762742743809,
#   0.7540129351834316,
#   0.7539536058099957,
#   0.7541896272003632,
#   0.754221004957439,
#   0.7542047876348887,
#   0.7540049179008947,
#   0.7540576897729834,
#   0.7537584257184462,
#   0.7537407043766137,
#   0.7534874204762138,
#   0.7531724349998474,
#   0.7532666503149167,
#   0.753229915405041,
#   0.7531235800698031,
#   0.7530522762228262,
#   0.7529452595629508,
#   0.7530177990252843,
#   0.7529698498987182,
#   0.753254459012158,
#   0.7532767853611483,
#   0.7533336762890049,
#   0.7535589004637234,
#   0.7535358564690946,
#   0.7535274844968843,
#   0.753545648548407,
#   0.7534294561069022,
#   0.753512504998277,
#   0.75361673060625,
#   0.7532781877476353,
#   0.7530337771600263,
#   0.7529080397870016,
#   0.7528989382730744,
#   0.7528647149803656,
#   0.7527718741838622,
#   0.7527473707260174,
#   0.7526283442288498,
#   0.7527961397065532,
#   0.7527359661235398,
#   0.7527663783641857,
#   0.7527070564559708,
#   0.7526762910624791,
#   0.7525302457725375,
#   0.7524492328672897,
#   0.752422770439738,
#   0.7522994181128141,
#   0.752078575947454,
#   0.7519399446774334,
#   0.751904996326185,
#   0.7517633746910601,
#   0.7516872867417699,
#   0.7516090980628558,
#   0.7515970870697963,
#   0.7517194981681166,
#   0.751622598903815,
#   0.7515218676420172,
#   0.7513319743560514,
#   0.7512830124413479,
#   0.7512380983905463,
#   0.7513509338944447,
#   0.7514039370070827,
#   0.7515495755654487,
#   0.751355980269002,
#   0.7511623387099147,
#   0.7510446021084455,
#   0.7509248804723142,
#   0.7511196540373887,
#   0.7511192242766543,
#   0.7510928242865225,
#   0.751107585619408,
#   0.7511661438095436,
#   0.7509570235294631,
#   0.750859147919158,
#   0.7509897934544236,
#   0.750873690988423,
#   0.7504045768262582,
#   0.7503610670519232,
#   0.7503099804641781,
#   0.7501791688609486,
#   0.7501207087383621,
#   0.749947819905397,
#   0.7502541396728349,
#   0.7498930198744654,
#   0.7497659758453603,
#   0.7497004701772595,
#   0.7495374522494219,
#   0.7492460357920669,
#   0.7488936598906137,
#   0.7488554264282332,
#   0.7488428276545522,
#   0.7486728097133655,
#   0.7484497630644947,
#   0.7483858098490245,
#   0.7483365904311563,
#   0.7485357668544472,
#   0.7485230086580481,
#   0.7483400251827962,
#   0.7480466405955428,
#   0.7481657055874347,
#   0.7479992205323867,
#   0.7478877985439463,
#   0.7478396745713161,
#   0.7477982658986951,
#   0.7476240665284699,
#   0.7475336621271309,
#   0.7475770168863094,
#   0.7475259285964717,
#   0.7474122780184671,
#   0.747231293091491,
#   0.7471296987036754,
#   0.7471415934131781,
#   0.7471337256793849,
#   0.7469984584015075,
#   0.74680384516072,
#   0.7467111170561231,
#   0.7466770412978456,
#   0.7468733331188546,
#   0.7467345818038051,
#   0.746886174285962,
#   0.7468090354694017,
#   0.7466688126216254,
#   0.7467242639869973,
#   0.7466557428657392,
#   0.7467091104848465,
#   0.7464468051382225,
#   0.7463294557618688,
#   0.7462113902422536,
#   0.7459521538481015,
#   0.7458532528232014,
#   0.7458074669671999,
#   0.7456893150389192,
#   0.7457553505831505,
#   0.7456577520255494,
#   0.7456408464619859,
#   0.7455856333878701,
#   0.7457597586548805,
#   0.7456637789043643,
#   0.7456088997157373,
#   0.7457202736023336,
#   0.7456251516211188,
#   0.7454732420375005,
#   0.7451788551715102,
#   0.7451414296371012,
#   0.7454662349568867,
#   0.7454570364294952,
#   0.7452826145904876,
#   0.7450349330264951,
#   0.7449183223857336,
#   0.7447994308241961,
#   0.7447889632974967,
#   0.7448600924653845,
#   0.7449817312018021,
#   0.7448645901992212,
#   0.7447765315496557,
#   0.7446583953653868,
#   0.7446109329693534,
#   0.7444770578470896,
#   0.7441823270837677,
#   0.7441234173328286,
#   0.7443657566824957,
#   0.7441485961458707,
#   0.7441771272549648,
#   0.7440951416704267,
#   0.743983827613568,
#   0.7438704977367521,
#   0.7439269917294975,
#   0.7436731102210221,
#   0.7436665895289873,
#   0.7436082778033721,
#   0.743663695565165,
#   0.7437509934080708,
#   0.7437226470164529,
#   0.7436488772903787,
#   0.7436641132674608,
#   0.7437463339322277,
#   0.7437325253138793,
#   0.7436237888912296,
#   0.7436234334364548,
#   0.7434110001558171,
#   0.7431932942676909,
#   0.7431163519979394,
#   0.7430819615917539,
#   0.7431517787894313,
#   0.7429024218939181,
#   0.7428908507688281,
#   0.7430228818781037,
#   0.742924022096745,
#   0.7426179336087977,
#   0.7423270915843427,
#   0.7425399687386518,
#   0.7424245493783245,
#   0.7423044795408764,
#   0.742163524675906,
#   0.7419544975381551,
#   0.7418943641615405,
#   0.7419260376261725,
#   0.7419079007753359,
#   0.7419223820505132,
#   0.741837083509054,
#   0.7419197289548312,
#   0.7421719782133404,
#   0.7423052866563646,
#   0.7423282262576796,
#   0.7422994855817405,
#   0.7423445770642574,
#   0.742463565926935,
#   0.742452788570407,
#   0.742275308522134,
#   0.7421272925830259,
#   0.742046469004088,
#   0.7420052985698269,
#   0.7420086799654934,
#   0.7418024251842028,
#   0.7415601374861295,
#   0.7415005341112334,
#   0.7414600600677161,
#   0.7414372335895478,
#   0.7414364163214404,
#   0.7415003413003972,
#   0.7413710695701636,
#   0.7412455009825372,
#   0.7410496325277901,
#   0.7409499562455817,
#   0.741011253433685,
#   0.740880056090119,
#   0.7410362881382964,
#   0.7411220963498577,
#   0.7411325996261406,
#   0.7410285716013032,
#   0.7409241552874486,
#   0.7408646601048428,
#   0.7407676015824378,
#   0.740582455628739,
#   0.7403267041118984,
#   0.7401516886884179,
#   0.7402390996152887,
#   0.7401847390688807,
#   0.7402132763251202,
#   0.7400763065737487,
#   0.7398211571282678,
#   0.7397335726387888,
#   0.7394349532247988,
#   0.7393906147022349,
#   0.739256599538681,
#   0.7392280576480832,
#   0.7391414292424461,
#   0.7390519391521055,
#   0.7389931471436255,
#   0.738758282531722,
#   0.7385084461538565,
#   0.7386133497329357,
#   0.7385240921115257,
#   0.7382553560967504,
#   0.7384606601788248,
#   0.7384258354572624,
#   0.7384333058151251,
#   0.7383233407185783,
#   0.7380326394180728,
#   0.7377358544203598,
#   0.737851172834967,
#   0.7376190348748712,
#   0.7376092903952709,
#   0.7377089635446469,
#   0.737714833892949,
#   0.7378388003511709,
#   0.7377052156420996,
#   0.7375929167650919,
#   0.7374895627249648,
#   0.7372435952350823,
#   0.7370756390535118,
#   0.7370926267633904,
#   0.737058902264234,
#   0.7369850676483365,
#   0.7370180982942807,
#   0.7369303322458469,
#   0.7369333256630206,
#   0.7368185120321834,
#   0.7367165232924765,
#   0.7365017744684559,
#   0.7365891552524759,
#   0.7363807693641393,
#   0.736356691332781,
#   0.7364194955953438,
#   0.7363057598920976,
#   0.73635472001258,
#   0.7363825646324273,
#   0.7365133469288067,
#   0.736453741085844,
#   0.7363473599114136,
#   0.7363369379764382,
#   0.7361252311030932,
#   0.7359441732719136,
#   0.7357682431257511,
#   0.7357363567280512,
#   0.7356391617603073,
#   0.7355235243705474,
#   0.7353751807778341,
#   0.7352181800800167,
#   0.735109062488049,
#   0.7351667203395372,
#   0.735150187414729,
#   0.7350662679075317,
#   0.735072265328751,
#   0.7349463616964567,
#   0.7348447530432066,
#   0.7347311734567452,
#   0.7347017811806241,
#   0.7345669331708331,
#   0.734458432717118,
#   0.7343838216686196,
#   0.7342637849624396,
#   0.7346018891546433,
#   0.7346094376131225,
#   0.7345849768809687,
#   0.7343895143451473,
#   0.734233313666573,
#   0.7340453310763639,
#   0.7338481049491204,
#   0.733663825851258,
#   0.7336566505549722,
#   0.7338892807916834,
#   0.7338136002538916,
#   0.7338207913195276,
#   0.7336045681571228,
#   0.7334901420865156,
#   0.7334260686034721,
#   0.7334951233554281,
#   0.7333599132618145,
#   0.733186524696157,
#   0.7330522256464148,
#   0.7330581349211169,
#   0.7328163342299354,
#   0.7329070571756431,
#   0.7328891796843602,
#   0.7327402949938863,
#   0.7325395274960185,
#   0.7326911468619932,
#   0.7325578389621429,
#   0.7325426970200597,
#   0.7325549050755344,
#   0.7325112756107908,
#   0.7324476501490637,
#   0.7325617372851196,
#   0.7325591348728346,
#   0.7325933811502163,
#   0.7324886771801222,
#   0.7323741354168715,
#   0.7322833397733357,
#   0.7321670081416839,
#   0.7322174074453399,
#   0.7321552975329231,
#   0.7321372780739264,
#   0.7320121695762425,
#   0.7319247557537003,
#   0.7320348505061959,
#   0.7320942853403967,
#   0.7320310102100895,
#   0.7320926145897135,
#   0.7320376074274936,
#   0.7318996722121254,
#   0.7318914266757699,
#   0.7319192852212683,
#   0.7319026146323591,
#   0.7318083751540518,
#   0.7317288729393763,
#   0.7317008077715833,
#   0.7316228422769524,
#   0.7316999908816506,
#   0.7317457284587373,
#   0.7317629012727238,
#   0.7317127052704555,
#   0.7315943050656797,
#   0.7314840718871529,
#   0.7315287834568389,
#   0.7313556624419875,
#   0.7310951618817039,
#   0.7308791842438338,
#   0.7306717106617554,
#   0.7307238180030027,
#   0.73086264782767,
#   0.7308774669036331,
#   0.7307606621088238,
#   0.7306129020986881,
#   0.730440681926259,
#   0.7301767159841958,
#   0.7301639384774458,
#   0.7300772507685149,
#   0.7300890206303162,
#   0.7299763429682267,
#   0.7298329639115582,
#   0.7296560434857662,
#   0.7296461072524958,
#   0.7294132366876036,
#   0.7293248707708548,
#   0.7291867384449274,
#   0.7291728191861422,
#   0.7291156007152255,
#   0.729063171150816,
#   0.7289330569967889,
#   0.7287977633983576,
#   0.7286955434938054,
#   0.7284392944263574,
#   0.7285392930881671,
#   0.728262791462617,
#   0.7282370173266609,
#   0.728171036697747,
#   0.7281412067374192,
#   0.7284017179231528,
#   0.7284082430929125,
#   0.72831946166304,
#   0.728191856879713,
#   0.7282597552010962,
#   0.7282050721563732,
#   0.7281164115616527,
#   0.7281702995423056,
#   0.7280409240680671,
#   0.7280910918646759,
#   0.727891611040063,
#   0.7277588416464188,
#   0.7276341571348974,
#   0.727671872823657,
#   0.7278251219371445,
#   0.7278010100362141,
#   0.7277341705348779,
#   0.7277229233181641,
#   0.7277509206595819,
#   0.7276051568730757,
#   0.7273679166369769,
#   0.7273230169191434,
#   0.7272260664146876,
#   0.727166094401959,
#   0.7270216622380449,
#   0.7270896495212332,
#   0.7270634780734764,
#   0.7274632323471364,
#   0.7272848815582718,
#   0.7272552675296527,
#   0.7272651992311987,
#   0.7272971593716583,
#   0.7272429145228763,
#   0.7272421259670558,
#   0.7273045962739677,
#   0.7275768624015284,
#   0.7275149225758446,
#   0.7274378709840602,
#   0.727659564798382,
#   0.7274538791685441,
#   0.7273418074769697,
#   0.7272010265947468,
#   0.7272442152585411,
#   0.7271685913257071,
#   0.7270441297521146,
#   0.7269122501565835,
#   0.7269178209706069,
#   0.7267332219398139,
#   0.7266501600425277,
#   0.7267044105671518,
#   0.7266155102319523,
#   0.7266850051183791,
#   0.7266606918722662,
#   0.7265499218886375,
#   0.7265120550413097,
#   0.7263311416405639,
#   0.7262056764359099,
#   0.7260477610269147,
#   0.7260979544824488,
#   0.725966725196243,
#   0.725778317715605,
#   0.7257413529319652,
#   0.7259702640319141,
#   0.725884019535413,
#   0.7259395797631649,
#   0.7257237595514896,
#   0.7257417836226367,
#   0.72574501558794,
#   0.7257450711562343,
#   0.7256929280899768,
#   0.7254933192031214,
#   0.725413666244903,
#   0.7254147337573051,
#   0.7254199721854988,
#   0.7252652197361964,
#   0.7251603371683191,
#   0.7251344194214688,
#   0.7250387982920343,
#   0.7251771439865904,
#   0.7250596730527963,
#   0.7250437933537848,
#   0.7250042352907191,
#   0.7249004958162923,
#   0.7249360991263691,
#   0.7250487115231365,
#   0.7249368325098127,
#   0.7248717339454207,
#   0.7247929661997425,
#   0.7247511845001203,
#   0.7245725540207827,
#   0.7245447471476953,
#   0.7244358556001556,
#   0.7243593855667156,
#   0.7243166509245071,
#   0.7244135577685036,
#   0.7243804431649081,
#   0.7244213991552675,
#   0.7244411016882772,
#   0.724469475922662,
#   0.7243526686090853,
#   0.7245654232836243,
#   0.7245225514701401,
#   0.7244453158664098,
#   0.7247458541986636,
#   0.7245739695032727,
#   0.7245284408573549,
#   0.7246546924945838,
#   0.72465486077761,
#   0.7248836851989988,
#   0.7249130565535675,
#   0.7251979640275824]}
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(data={'catboost_info': {'path': 'catboost_info', 'name': 'catboost_info', 'content': {'passed_iterations': 999, 'total_iterations': 1000, 'data': {'iterations': [{'iteration': 0, 'eval_dataset': [0.004788226751]}, {'iteration': 1, 'eval_dataset': [0.009492245243]}, {'iteration': 2, 'eval_dataset': [0.01351422387]}, {'iteration': 3, 'eval_dataset': [0.01791136681]}, {'iteration': 4, 'eval_dataset': [0.02051864573]}, {'iteration': 5, 'eval_dataset': [0.0257055702]}, {'iteration': 6, 'eval_dataset': [0.02959488014]}, {'iteration': 7, 'eval_dataset': [0.03485921172]}, {'iteration': 8, 'eval_dataset': [0.03715042457]}, {'iteration': 9, 'eval_dataset': [0.04234968878]}, {'iteration': 10, 'eval_dataset': [0.04286788715]}, {'iteration': 11, 'eval_dataset': [0.04906670952]}, {'iteration': 12, 'eval_dataset': [0.05482470853]}, {'iteration': 13, 'eval_dataset': [0.05941933945]}, {'iteration': 14, 'eval_dataset': [0.06249788123]}, {'iteration': 15, 'eval_dataset': [0.06811908249]}, {'iteration': 16, 'eval_dataset': [0.0744540127]}, {'iteration': 17, 'eval_dataset': [0.07950990618]}, {'iteration': 18, 'eval_dataset': [0.08485194876]}, {'iteration': 19, 'eval_dataset': [0.09031930141]}, {'iteration': 20, 'eval_dataset': [0.09571733583]}, {'iteration': 21, 'eval_dataset': [0.1011960225]}, {'iteration': 22, 'eval_dataset': [0.1068812114]}, {'iteration': 23, 'eval_dataset': [0.112393763]}, {'iteration': 24, 'eval_dataset': [0.1173128936]}, {'iteration': 25, 'eval_dataset': [0.1221162892]}, {'iteration': 26, 'eval_dataset': [0.1274185472]}, {'iteration': 27, 'eval_dataset': [0.1325357555]}, {'iteration': 28, 'eval_dataset': [0.1380523459]}, {'iteration': 29, 'eval_dataset': [0.1437913375]}, {'iteration': 30, 'eval_dataset': [0.1493132177]}, {'iteration': 31, 'eval_dataset': [0.1540804318]}, {'iteration': 32, 'eval_dataset': [0.159549519]}, {'iteration': 33, 'eval_dataset': [0.1648674715]}, {'iteration': 34, 'eval_dataset': [0.1687554849]}, {'iteration': 35, 'eval_dataset': [0.1748444936]}, {'iteration': 36, 'eval_dataset': [0.1783758697]}, {'iteration': 37, 'eval_dataset': [0.1823098573]}, {'iteration': 38, 'eval_dataset': [0.1875368261]}, {'iteration': 39, 'eval_dataset': [0.1912189712]}, {'iteration': 40, 'eval_dataset': [0.196160436]}, {'iteration': 41, 'eval_dataset': [0.2015436964]}, {'iteration': 42, 'eval_dataset': [0.2064642292]}, {'iteration': 43, 'eval_dataset': [0.211429861]}, {'iteration': 44, 'eval_dataset': [0.2167552498]}, {'iteration': 45, 'eval_dataset': [0.2182362551]}, {'iteration': 46, 'eval_dataset': [0.2235988789]}, {'iteration': 47, 'eval_dataset': [0.2288208135]}, {'iteration': 48, 'eval_dataset': [0.2339504681]}, {'iteration': 49, 'eval_dataset': [0.238562448]}, {'iteration': 50, 'eval_dataset': [0.243463306]}, {'iteration': 51, 'eval_dataset': [0.248456322]}, {'iteration': 52, 'eval_dataset': [0.2536402224]}, {'iteration': 53, 'eval_dataset': [0.2578756558]}, {'iteration': 54, 'eval_dataset': [0.2638912377]}, {'iteration': 55, 'eval_dataset': [0.2685142343]}, {'iteration': 56, 'eval_dataset': [0.2737526126]}, {'iteration': 57, 'eval_dataset': [0.2787261295]}, {'iteration': 58, 'eval_dataset': [0.2827926253]}, {'iteration': 59, 'eval_dataset': [0.2891862691]}, {'iteration': 60, 'eval_dataset': [0.2933049684]}, {'iteration': 61, 'eval_dataset': [0.2984536089]}, {'iteration': 62, 'eval_dataset': [0.3014844471]}, {'iteration': 63, 'eval_dataset': [0.3060466859]}, {'iteration': 64, 'eval_dataset': [0.3103955677]}, {'iteration': 65, 'eval_dataset': [0.3156699611]}, {'iteration': 66, 'eval_dataset': [0.3209942066]}, {'iteration': 67, 'eval_dataset': [0.3251149797]}, {'iteration': 68, 'eval_dataset': [0.3299261281]}, {'iteration': 69, 'eval_dataset': [0.3344587241]}, {'iteration': 70, 'eval_dataset': [0.3386992829]}, {'iteration': 71, 'eval_dataset': [0.3427332225]}, {'iteration': 72, 'eval_dataset': [0.3469963931]}, {'iteration': 73, 'eval_dataset': [0.3519765984]}, {'iteration': 74, 'eval_dataset': [0.357370 ...

# %%
Cat.score(X_testc,y_testc)
# Out:
# 528703.0217896649

# %% [markdown]
# #### Catboost (Testing changing inputs)

# %% [markdown]
# **...Don't think it makes a difference because full list just crunches down unecessary inputs.**

# %%
hm_model_ready2.columns

# %%
ycat2 = hm_model_ready2['GENERAL VOTES'] 
Xcat2 = hm_model_ready2[['Primary Winner','Primary Loser Vote','STATE','PARTY']]

# %%
X_trainc2, X_testc2, y_trainc2, y_testc2 = train_test_split(Xcat2, ycat2, test_size=0.2, random_state=42)

# %%
categorical_features_indices = np.where(X_trainc2.dtypes != np.float)[0]
train_pool = Pool(X_trainc2, y_trainc2, cat_features=categorical_features_indices)
test_pool = Pool(X_testc2, y_testc2, cat_features=categorical_features_indices)


Cat = Catset.fit(X_trainc2, y_trainc2, cat_features=categorical_features_indices);

# %%
Cat.score(X_testc2, y_testc2)

# %%
Cat.eval_metrics(data = test_pool, metrics =['R2'], plot = True)

# %% [markdown]
# #### Linear Regression

# %%
sns.pairplot(hm_model_ready, size = 1.2, aspect=1.5)

# %%
ylr = hm_model_ready['GENERAL VOTES'] 
Xlr = hm_model_ready[['Primary Winner','Primary Loser Vote','Party In House','(I)']]

# %%
Xlr

# %%
X_trainlr, X_testlr, y_trainlr, y_testlr = train_test_split(Xlr, ylr, test_size=0.3, random_state=42)

# %%
#Checking the predictability of the model with this alpha = 1
EN = ElasticNet(1, l1_ratio=.5)
LR = EN.fit(X_trainlr, y_trainlr)
rsq = LR.score(X_testlr, y_testlr)
adj_rsq = 1 - (1-rsq)*(len(ylr)-1)/(len(ylr)-Xlr.shape[1]-1)

preds = LR.predict(X_testlr)
rmse = np.sqrt(MSE(preds, y_testlr))

print(rsq)
print(adj_rsq)
print(rmse)

# %% [markdown]
# #### Linear Regression (Logged)

# %%
hm_model_log = hm_model_ready

hm_model_log['Primary Winner']=np.log(hm_model_log['Primary Winner'])
hm_model_log['Primary Loser Vote']=np.log(hm_model_log['Primary Loser Vote'])
hm_model_log['Third Party Votes']=np.log(hm_model_log['Third Party Votes'])
hm_model_log['GENERAL VOTES']=np.log(hm_model_log['GENERAL VOTES'])

# %%
ylr2 = hm_model_log['GENERAL VOTES'] 
Xlr2 = hm_model_log[['Primary Winner','Primary Loser Vote','Third Party Votes','Party In House','(I)']]

# %%
ylr2

# %%
Xlr2 = Xlr2.replace([np.inf, -np.inf], 0).fillna(0)

# %%
X_trainlr2, X_testlr2, y_trainlr2, y_testlr2 = train_test_split(Xlr2, ylr2, test_size=0.2, random_state=42)

# %%
#Checking the predictability of the model with this alpha = 1
EN = ElasticNet(1, l1_ratio=.5)
LR = EN.fit(X_trainlr2, y_trainlr2)
rsq = LR.score(X_testlr2, y_testlr2)
adj_rsq = 1 - (1-rsq)*(len(ylr2)-1)/(len(ylr2)-Xlr2.shape[1]-1)

preds = LR.predict(X_testlr2)
rmse = np.sqrt(MSE(preds, y_testlr2))

print(rsq)
print(adj_rsq)
print(rmse)

# %% [markdown]
# ### Modeling (Splitting by state-size)

# %% [markdown]
# *Didn't end up helping much. Let's just go back to the one with the full train set*
#
# **Grouped states by electoral college vote:**<br>
#
# **Smallest:** <br>
# - *3 Electoral votes:* Alaska, Delaware, Montana, North Dakota, South Dakota, Vermont, Wyoming
# - *4 Electoral votes:* Hawaii, Idaho, Maine, New Hampshire, Rhode Island
# - *5 Electoral votes:* Nebraska, New Mexico, West Virginia
#
# **Medium:** <br>
# - *6 Electoral votes:* Arkansas, Iowa ,Kansas, Mississippi, Nevada, Utah
# - *7 Electoral votes:* Connecticut, Oklahoma, Oregon
# - *8 Electoral votes:* Kentucky, Louisiana
# - *9 Electoral votes:* Alabama, Colorado, South Carolina
# - *10 Electoral votes:* Maryland, Minnesota, Missouri, Wisconsin
# - *11 Electoral votes:* Arizona, Indiana, Massachusetts, Tennessee
#
# **Medium-Large:** <br>
# - *12 Electoral votes:* Washington
# - *13 Electoral votes:* Virginia
# - *14 Electoral votes:* New Jersey
# - *15 Electoral votes:* North Carolina
# - *16 Electoral votes:* Georgia, Michigan
# - *18 Electoral votes:* Ohio
#
# **Large:** <br>
# - *20 Electoral votes:* Illinois, Pennsylvania
# - *29 Electoral votes:* Florida, New York
# - *38 Electoral votes:* Texas
# - *55 Electoral votes:* California

# %% [markdown]
# #### Small States

# %%
low_density = ['Alaska', 'Delaware', 'Montana', 'North Dakota', 'South Dakota', 'Vermont', 'Wyoming', 'Hawaii', 'Idaho', 'Maine', 'New Hampshire', 'Rhode Island', 'Nebraska', 'New Mexico', 'West Virginia']

small = hm_model_ready2[hm_model_ready2['STATE'].isin(low_density)].drop('Third Party Votes',axis = 1)

# %%
# small = small.drop(small[small['Primary Loser Vote'] < 1].index)

# %%
small.describe()

# %% [markdown]
# **Splitting X&y**

# %%
ysmall = small['GENERAL VOTES'] 
Xsmall = small.drop('GENERAL VOTES',axis = 1)

# %% [markdown]
# **Splitting for T-T-S**

# %%
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(Xsmall, ysmall, test_size=0.3)

# %% [markdown]
# **Running Catboost**

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_train_s.dtypes != np.float)[0]
train_pool = Pool(X_train_s, y_train_s, cat_features=categorical_features_indices)
test_pool = Pool(X_test_s, y_test_s, cat_features=categorical_features_indices)


Cat_s = Catset.fit(X_train_s, y_train_s, cat_features=categorical_features_indices , use_best_model=True);

# %%
#Would like to get it down to less than 20,000...
Cat_s.score(X_test_s, y_test_s)

# %%
## Checking out feature importance for this model. 

feature_importances = Cat_s.get_feature_importance(train_pool)
feature_names = X_train_s.columns
for score, name in sorted(zip(feature_importances, feature_names), reverse=True):
    print('{}: {}'.format(name, score))

# %%
Cat_s.eval_metrics(data = test_pool, metrics =['R2'], plot = True)

# %% [markdown]
# #### Medium States

# %%
med_density = ['Arkansas', 'Iowa', 'Kansas', 'Mississippi', 'Nevada', 'Utah', 'Connecticut', 'Oklahoma', 'Oregon','Kentucky', 'Louisiana','Alabama', 'Colorado', 'South Carolina', 'Maryland', 'Minnesota','Missouri', 'Wisconsin','Arizona','Indiana', 'Massachusetts', 'Tennessee']

med = hm_model_ready2[hm_model_ready2['STATE'].isin(med_density)].drop('Third Party Votes',axis = 1)

# %%
med.describe()

# %%
ymed = med['GENERAL VOTES'] 
Xmed = med.drop('GENERAL VOTES',axis = 1)

# %%
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(Xmed, ymed, test_size=0.3)

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_train_m.dtypes != np.float)[0]
train_pool = Pool(X_train_m, y_train_m, cat_features=categorical_features_indices)
test_pool = Pool(X_test_m, y_test_m, cat_features=categorical_features_indices)

Cat_m = Catset.fit(X_train_m, y_train_m, cat_features=categorical_features_indices , use_best_model=True);

# %%
#Would like to get it down to less than 20,000...
Cat_m.score(X_test_m, y_test_m)

# %% [markdown]
# #### Medium-Large State

# %%
medlar_density = ['Washington','Virginia','New Jersey','North Carolina','Georgia','Michigan','Ohio']

medlar = hm_model_ready2[hm_model_ready2['STATE'].isin(medlar_density)].drop('Third Party Votes',axis = 1)

# %%
medlar.describe()

# %%
ymedlar = medlar['GENERAL VOTES'] 
Xmedlar = medlar.drop('GENERAL VOTES',axis = 1)

# %%
X_train_ml, X_test_ml, y_train_ml, y_test_ml = train_test_split(Xmedlar, ymedlar, test_size=0.3)

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_train_m.dtypes != np.float)[0]
train_pool = Pool(X_train_ml, y_train_ml, cat_features=categorical_features_indices)
test_pool = Pool(X_test_m, y_test_m, cat_features=categorical_features_indices)

Cat_ml = Catset.fit(X_train_ml, y_train_ml, cat_features=categorical_features_indices , use_best_model=True);

# %%
Cat_ml.score(X_test_ml, y_test_ml)

# %%
Cat_ml.eval_metrics(data = test_pool, metrics =['R2'], plot = True)

# %% [markdown]
# ### Breaking down by average voter turnout of the past 10 years

# %%
voter_turnout = hm_model_ready2.groupby(['STATE']).mean().reset_index()
voter_turnout = voter_turnout.sort_values(by=['GENERAL VOTES'])

# %%
voter_turnout

# %%
plt.barh(voter_turnout['STATE'],voter_turnout['GENERAL VOTES'], color = '#1A62A5')
plt.ylabel('State', fontsize=14)
plt.xlabel('General Election Votes', fontsize=14)
plt.title('Voter Turnout Per State', fontsize=20)

# %% [markdown]
# **Grouped states by voter turnout from the past ten years:**<br>
#
# **Smallest:** <br>
# - Wyoming, Alaska, Vermont, Delaware, South Dakota, North Dakota, Hawaii, Rhode Island,
#
# **Medium:** <br>
# - *6 Electoral votes:* Arkansas, Iowa ,Kansas, Mississippi, Nevada, Utah
# - *7 Electoral votes:* Connecticut, Oklahoma, Oregon
# - *8 Electoral votes:* Kentucky, Louisiana
# - *9 Electoral votes:* Alabama, Colorado, South Carolina
# - *10 Electoral votes:* Maryland, Minnesota, Missouri, Wisconsin

# %%
low_turnout = ['Wyoming', 'Alaska', 'Vermont', 'Delaware', 'South Dakota', 'North Dakota', 'Hawaii', 'Rhode Island']

low = hm_model_ready2[hm_model_ready2['STATE'].isin(low_turnout)].drop('Third Party Votes',axis = 1)

# %%
low.describe()

# %% [markdown]
# **Splitting X&y**

# %%
ylow = low['GENERAL VOTES'] 
Xlow = low.drop('GENERAL VOTES',axis = 1)

# %% [markdown]
# **T-T-S**

# %%
X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(Xlow, ylow, test_size=0.3)

# %%
from catboost import CatBoostRegressor, Pool

categorical_features_indices = np.where(X_train_l.dtypes != np.float)[0]
train_pool = Pool(X_train_l, y_train_l, cat_features=categorical_features_indices)

Cat_l = Catset.fit(X_train_l, y_train_l, cat_features=categorical_features_indices , use_best_model=True);

# %%
#Would like to get it down to less than 20,000...
Cat_l.score(X_test_l, y_test_l)

# %% [markdown]
# ### Pipeline for Prediction

# %%
# submission = pd.DataFrame()
# submission['Item_Identifier'] = test['Item_Identifier']
# submission['Outlet_Identifier'] = test['Outlet_Identifier']
# submission['Item_Outlet_Sales'] = model.predict(test)
# submission.to_csv("Submission.csv")

# %%
# Used in prediction

hm_model_ready2

# %%
Cat.predict([['10000', '3', '1', 7000, 'Alaska','2014', 'R',3000,1]])

# %%
#Read in CSV
Primaries_2018 = pd.read_csv('Primary_Results_Predicting.csv')

# %%
#Assigning a year
Primaries_2018['YEAR'] = '2018'

# %%
#IDs to merge on later
Primaries_2018["ID"] = Primaries_2018["State"].map(str) + Primaries_2018["YEAR"] +Primaries_2018["Party"]

# %%
Primaries_party = Primaries_2018[Primaries_2018['Party'].isin(['R','D'])]

# %% [markdown]
# ** Totaling the Number of votes in primary **

# %%
primaries_partytotal = Primaries_party[['ID','Number of Votes']]

primaries_partytotal = primaries_partytotal.dropna()

primaries_partytotal["Number of Votes"]= primaries_partytotal["Number of Votes"].astype(float)

primaries_partytotal = primaries_partytotal.groupby(['ID']).sum().reset_index()

primaries_partytotal = primaries_partytotal.rename(columns = {'Number of Votes':'Total Party Votes'})

# %% [markdown]
# ** Counting the Number of Candidates **

# %%
NumRunning_p = Primaries_party.groupby(['ID']).count().reset_index()

NumRunning_p = NumRunning_p[['ID','Number of Votes','(I)']]

NumRunning_p['(I)'].value_counts()

NumRunning_p = NumRunning_p.rename(columns = {'Number of Votes':'Candidate Count'})

# %% [markdown]
# ** Max votes per party per state **

# %%
PartyWin_p = Primaries_party[['ID','Number of Votes','State','YEAR','Party']]

PartyWin_p = PartyWin_p.dropna()

PartyWin_p["Number of Votes"]= PartyWin_p["Number of Votes"].astype(float)

PartyWin_p = PartyWin_p.groupby(['ID']).max().reset_index()

PartyWin_p = PartyWin_p.rename(columns = {'Number of Votes':'Primary Winner'})

# %% [markdown]
# ** Merging columns back together **

# %%
votes_merged_p = primaries_partytotal.merge(NumRunning_p, left_on='ID', right_on='ID', how='left')

votes_merged_p = votes_merged_p.merge(PartyWin_p, left_on='ID', right_on='ID', how = 'left')

# %% [markdown]
# ** Counting total votes by loser **

# %%
votes_merged_p['Primary Loser Vote'] = votes_merged_p['Total Party Votes'] - votes_merged['Primary Winner']

# %%
votes_merged_p

# %% [markdown]
# ** Adding if party is in the white house **

# %%
OP2018 = []

for party in votes_merged_p['Party']:
    if party == 'R':
        OP2018.append(1)
        
    else:
        OP2018.append(0)
    
votes_merged_p['OFFICE PARTY'] = OP2018

# %% [markdown]
# ** Seperating out Unopposed **

# %%
Unopp2018 = votes_merged_p.drop(votes_merged_p[votes_merged_p['Primary Winner'] > 1].index)

# %%
Unopp2018

# %% [markdown]
# ** The races we can do estimates for **

# %%
fin2018 = votes_merged_p.drop(votes_merged_p[votes_merged_p['Primary Winner'] < 1].index)

# %%
fin2018

# %% [markdown]
# ** Running those estimates!!! ** <3

# %%
GENERAL VOTES	Total Party Votes	Candidate Count	(I)	Primary Winner	STATE	YEAR	PARTY	Primary Loser Vote	Party In House

# %%
fin2018 = fin2018.rename(index=str, columns={"State": "STATE", "Party": "PARTY","OFFICE PARTY":'Party In House'}).drop("ID",axis=1)

# fin2018['Total Party Votes'] = fin2018['Total Party Votes']
# fin2018['Candidate Count'] = fin2018['Candidate Count']
# fin2018['(I)'] = fin2018['(I)']
# fin2018['Primary Winner'] = fin2018['Primary Winner']
# fin2018['STATE'] = fin2018['State']
# fin2018['YEAR'] = fin2018['YEAR']
# fin2018['PARTY'] = fin2018['Party']
# fin2018['Primary Loser Vote'] = fin2018['Primary Loser Vote']
# fin2018['Party In House'] = fin2018['OFFICE PARTY']

# submission.to_csv("Submission.csv")


# fin2018['Predicted Turnout'] = Cat.predict(fin2018)
# submission.to_csv("Submission.csv")
# Cat.predict([['10000', '3', '1', 7000, 'Alaska','2014', 'R',3000,1]])

# %%
fin2018['Predicted Turnout'] = Cat.predict(fin2018)

# %%
fin2018

# %% [markdown]
# **Merging back with ID**
